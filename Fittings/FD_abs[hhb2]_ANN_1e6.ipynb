# %% [markdown]
# ## FD_abs[hhb2] ANN Fitting

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
! pip install pmcx
# Out:
# Collecting pmcx
#   Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 48.4 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.4.2

# %%
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Mounted at /content/drive

# %%
from FD_msNIRS_2layers import extract_freq as ef

# %% [markdown]
# ### Read Simulation data

# %%
import os
import pickle
import numpy as np

# %%
result_folder1 = '/content/drive/MyDrive/MCX_data/stage1_results/'
#result_folder2 = '/content/drive/MyDrive/MCX_data/result_folder/part2/'
#result_folder3 = '/content/drive/MyDrive/MCX_data/result_folder/part3/'
#result_folder4 = '/content/drive/MyDrive/MCX_data/result_folder/part4/'
#result_folder5 = '/content/drive/MyDrive/MCX_data/MCX_sim_data/1-4/Results/'
result_folders = [result_folder1]

# %%
def row_construct(dictt):
    re = np.zeros((1, 96))
    col = 0
    for k, v in dictt.items():  # four distances
        TPSF_list = v
        uac_i, udc_i, p1 = ef(1e6, TPSF_list, tend=1e-08, devf=1000)  # 8 wavelengths
        combined = []
        for i in range(8):
            combined.extend([uac_i[i], udc_i[i], p1[i]])  # Interleave the values
        re[0, col:col+24] = combined  # Each set contributes 24 values
        col += 24
    return re

# %%
import os
import pickle
import numpy as np
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

def extract_id_from_path(path):
    filename = os.path.basename(path)
    return int(filename.replace('.pkl', ''))

def load_and_construct(path):
    with open(path, 'rb') as f:
        dictt = pickle.load(f)
    return row_construct(dictt)

def load_and_process_all(result_folders):
    # Collect all file paths
    file_paths = []
    for folder in result_folders:
        for f in os.listdir(folder):
            if f.endswith('.pkl'):
                file_paths.append(os.path.join(folder, f))

    # Sort by numeric filename
    sorted_paths = sorted(file_paths, key=extract_id_from_path)
    sorted_ids = [extract_id_from_path(p) for p in sorted_paths]

    # Load and process in parallel (with progress bar)
    all_rows = []
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(load_and_construct, sorted_paths), total=len(sorted_paths), desc="Loading and processing files"))

    result_array = np.vstack(results)
    return result_array, sorted_ids

# %%
final_array, sorted_ids = load_and_process_all(result_folders)
# Out:
# Loading and processing files: 100%|██████████| 2000/2000 [00:56<00:00, 35.23it/s]

# %%
final_array.shape
# Out:
# (2000, 96)

# %%
# Save to CSV
output_csv_path = '/content/drive/MyDrive/MCX_data/stage1.csv'
pd.DataFrame(final_array).to_csv(output_csv_path, index=False, header=False)

# %%
final_array.shape
# Out:
# (2000, 96)

# %% [markdown]
# ### Read the saved CSV

# %%
import pandas as pd
import glob
import numpy as np
import sys
! pip install pmcx
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pickle
# Out:
# Collecting pmcx
#   Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 40.3 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.4.2
# Mounted at /content/drive

# %%
csv_path = '/content/drive/MyDrive/MCX_data/stage1.csv'
final_array = np.loadtxt(csv_path, delimiter=',')
print(final_array.shape)
X = final_array
# Out:
# (2000, 96)

# %% [markdown]
# ### GT

# %%
GT_folder = '/content/drive/MyDrive/MCX_data/stage1_csv/'

# %%
csv_files = glob.glob(os.path.join(GT_folder, '*.csv'))
GT_all = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# %%
GT_all.head()
# Out:
#         HBO1      HHB1       HBO2       HHB2    d1        a1        a2  \
# 0   8.801696  3.218081  29.967631  30.957545  11.0  3.171905  1.437481
# 1  16.301696  8.218081  44.967631  20.957545  16.0  6.171905  2.987481
# 2  14.426696  4.468081  48.717631  33.457545  20.0  5.421905  4.149981
# 3   6.926696  9.468081  33.717631  23.457545  15.0  2.421905  2.599981
# 4  18.176696  6.968081  41.217631  28.457545  12.0  0.921905  1.824981
#
#          b1        b2   ID
# 0  2.281948  1.083814  251
# 1  1.081948  2.583814  252
# 2  1.981948  1.458814  253
# 3  0.781948  2.958814  254
# 4  1.381948  0.708814  255

# %%
sorted_ids = [i+1 for i in range(2000)]

# %%
sorted_ids[-1]
# Out:
# 2000

# %%
# Ensure ID column is integer
GT_all['ID'] = GT_all['ID'].astype(int)

# Filter and sort GT_all to match the sorted_ids order
GT_filtered = GT_all[GT_all['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()

# Extract HHB2 as Y
Y = GT_filtered['HHB2'].values  # numpy array (n_samples,)
Y = Y.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Scale X
scaler_X = StandardScaler()
X = scaler_X.fit_transform(X)

# Scale Y
scaler_y = StandardScaler()
Y = scaler_y.fit_transform(Y)

# %%
X.shape
# Out:
# (2000, 96)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (1800, 96) (200, 96)

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.losses import Huber
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

model = Sequential([
    Input(shape=(96,)),
    Dense(1000, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(8192*2, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(2048, activation='relu'),
    Dropout(0.2),

    Dense(1024, activation='relu'),
    Dropout(0.2),

    Dense(512, activation='relu'),
    Dropout(0.1),

    Dense(256, activation='relu'),
    Dropout(0.1),

    Dense(64, activation='relu'),
    Dropout(0.1),

    Dense(32, activation='relu'),
    Dropout(0.0),

    Dense(1)  # Output layer for regression
])


# 1) Create a checkpoint callback that saves the best model:
checkpoint_cb = ModelCheckpoint(
    "best_model.keras",        # filepath to save to
    monitor="val_loss",     # quantity to monitor
    mode="min",             # we want to minimize val_loss
    save_best_only=True,    # only save when val_loss decreases
    save_weights_only=False # set True if you only want weights
)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer, loss="mse")

# 3) Fit with the checkpoint callback
history = model.fit(
    X_train, Y_train,
    epochs=300,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    callbacks=[checkpoint_cb]
)

# 4) Later on (or in a new script), load the best model:
model = tf.keras.models.load_model("best_model.keras")
# Out:
# Epoch 1/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - loss: 0.9943 - val_loss: 1.0239
# Epoch 2/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - loss: 1.0055 - val_loss: 1.0234
# Epoch 3/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9885 - val_loss: 1.0237
# Epoch 4/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 441ms/step - loss: 0.9992 - val_loss: 1.0208
# Epoch 5/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9724 - val_loss: 1.0211
# Epoch 6/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 440ms/step - loss: 1.0223 - val_loss: 1.0150
# Epoch 7/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.9774 - val_loss: 1.0184
# Epoch 8/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9732 - val_loss: 1.0245
# Epoch 9/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - loss: 0.9760 - val_loss: 1.0119
# Epoch 10/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 436ms/step - loss: 1.0019 - val_loss: 0.9854
# Epoch 11/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9515 - val_loss: 1.0007
# Epoch 12/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9236 - val_loss: 1.0192
# Epoch 13/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0072 - val_loss: 1.0351
# Epoch 14/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9488 - val_loss: 0.9930
# Epoch 15/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.9361 - val_loss: 0.9950
# Epoch 16/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 425ms/step - loss: 0.9765 - val_loss: 0.9144
# Epoch 17/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9201 - val_loss: 0.9248
# Epoch 18/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9153 - val_loss: 0.9393
# Epoch 19/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8727 - val_loss: 0.9361
# Epoch 20/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8759 - val_loss: 0.9181
# Epoch 21/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 442ms/step - loss: 0.8782 - val_loss: 0.8739
# Epoch 22/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 25s 491ms/step - loss: 0.8263 - val_loss: 0.8727
# Epoch 23/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 456ms/step - loss: 0.8837 - val_loss: 0.8579
# Epoch 24/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8796 - val_loss: 0.9031
# Epoch 25/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8008 - val_loss: 0.9065
# Epoch 26/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8569 - val_loss: 0.9205
# Epoch 27/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8506 - val_loss: 0.9098
# Epoch 28/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8148 - val_loss: 0.8587
# Epoch 29/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7785 - val_loss: 0.8917
# Epoch 30/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8303 - val_loss: 0.8924
# Epoch 31/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7877 - val_loss: 0.9622
# Epoch 32/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 451ms/step - loss: 0.7984 - val_loss: 0.8270
# Epoch 33/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 458ms/step - loss: 0.7599 - val_loss: 0.8131
# Epoch 34/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7857 - val_loss: 0.8172
# Epoch 35/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7843 - val_loss: 0.8721
# Epoch 36/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - loss: 0.7479 - val_loss: 0.7830
# Epoch 37/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7823 - val_loss: 0.7923
# Epoch 38/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7250 - val_loss: 0.8043
# Epoch 39/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7526 - val_loss: 0.8781
# Epoch 40/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7973 - val_loss: 0.8074
# Epoch 41/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7800 - val_loss: 0.8458
# Epoch 42/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7785 - val_loss: 0.8230
# Epoch 43/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7780 - val_loss: 0.7837
# Epoch 44/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7159 - val_loss: 0.9705
# Epoch 45/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8226 - val_loss: 0.8147
# Epoch 46/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 433ms/step - loss: 0.6927 - val_loss: 0.7813
# Epoch 47/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7236 - val_loss: 0.8198
# Epoch 48/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.7288 - val_loss: 0.8103
# Epoch 49/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - loss: 0.7154 - val_loss: 0.7624
# Epoch 50/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.6912 - val_loss: 0.7713
# Epoch 51/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.7431 - val_loss: 0.7830
# Epoch 52/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7593 - val_loss: 0.7637
# Epoch 53/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6886 - val_loss: 0.8713
# Epoch 54/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7087 - val_loss: 0.8580
# Epoch 55/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7062 - val_loss: 0.8115
# Epoch 56/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 24s 486ms/step - loss: 0.7074 - val_loss: 0.7471
# Epoch 57/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6823 - val_loss: 0.8290
# Epoch 58/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7464 - val_loss: 0.8108
# Epoch 59/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 417ms/step - loss: 0.6918 - val_loss: 0.6932
# Epoch 60/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6794 - val_loss: 0.8089
# Epoch 61/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6629 - val_loss: 0.7407
# Epoch 62/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6784 - val_loss: 0.7847
# Epoch 63/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7061 - val_loss: 0.7055
# Epoch 64/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6467 - val_loss: 0.7612
# Epoch 65/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6552 - val_loss: 0.7622
# Epoch 66/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6458 - val_loss: 0.7807
# Epoch 67/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6239 - val_loss: 0.7008
# Epoch 68/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6271 - val_loss: 0.7205
# Epoch 69/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6240 - val_loss: 0.7263
# Epoch 70/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.6396 - val_loss: 0.7105
# Epoch 71/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6326 - val_loss: 0.7944
# Epoch 72/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7029 - val_loss: 0.7126
# Epoch 73/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - loss: 0.5960 - val_loss: 0.6673
# Epoch 74/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6223 - val_loss: 0.6932
# Epoch 75/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6057 - val_loss: 0.7704
# Epoch 76/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5881 - val_loss: 0.7236
# Epoch 77/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5873 - val_loss: 0.7053
# Epoch 78/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6191 - val_loss: 0.6776
# Epoch 79/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - loss: 0.5888 - val_loss: 0.6408
# Epoch 80/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5462 - val_loss: 0.7647
# Epoch 81/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5825 - val_loss: 0.6528
# Epoch 82/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6063 - val_loss: 0.6724
# Epoch 83/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 413ms/step - loss: 0.6138 - val_loss: 0.5669
# Epoch 84/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 435ms/step - loss: 0.5415 - val_loss: 0.5662
# Epoch 85/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - loss: 0.5978 - val_loss: 0.5405
# Epoch 86/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5625 - val_loss: 0.7707
# Epoch 87/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6130 - val_loss: 0.6531
# Epoch 88/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5484 - val_loss: 0.6370
# Epoch 89/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5224 - val_loss: 0.6610
# Epoch 90/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5372 - val_loss: 0.6548
# Epoch 91/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5431 - val_loss: 0.5986
# Epoch 92/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5016 - val_loss: 0.6137
# Epoch 93/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5428 - val_loss: 0.7942
# Epoch 94/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6067 - val_loss: 0.7118
# Epoch 95/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5492 - val_loss: 0.5766
# Epoch 96/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 434ms/step - loss: 0.4832 - val_loss: 0.5195
# Epoch 97/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4845 - val_loss: 0.5957
# Epoch 98/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5517 - val_loss: 0.7340
# Epoch 99/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5154 - val_loss: 0.5782
# Epoch 100/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5132 - val_loss: 0.6072
# Epoch 101/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4511 - val_loss: 0.6051
# Epoch 102/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4876 - val_loss: 0.5704
# Epoch 103/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4551 - val_loss: 0.5616
# Epoch 104/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4719 - val_loss: 0.6058
# Epoch 105/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4507 - val_loss: 0.5774
# Epoch 106/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4864 - val_loss: 0.5787
# Epoch 107/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4645 - val_loss: 0.5796
# Epoch 108/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4408 - val_loss: 0.5939
# Epoch 109/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4207 - val_loss: 0.5630
# Epoch 110/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4080 - val_loss: 0.5895
# Epoch 111/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4543 - val_loss: 0.5742
# Epoch 112/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4410 - val_loss: 0.6049
# Epoch 113/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4140 - val_loss: 0.5639
# Epoch 114/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 439ms/step - loss: 0.4441 - val_loss: 0.5063
# Epoch 115/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4004 - val_loss: 0.6044
# Epoch 116/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4345 - val_loss: 0.5671
# Epoch 117/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4261 - val_loss: 0.5740
# Epoch 118/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4574 - val_loss: 0.6278
# Epoch 119/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4031 - val_loss: 0.5547
# Epoch 120/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3843 - val_loss: 0.5502
# Epoch 121/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4163 - val_loss: 0.6057
# Epoch 122/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4251 - val_loss: 0.5312
# Epoch 123/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3618 - val_loss: 0.5373
# Epoch 124/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3935 - val_loss: 0.6729
# Epoch 125/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4616 - val_loss: 0.5603
# Epoch 126/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4089 - val_loss: 0.6503
# Epoch 127/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4037 - val_loss: 0.5498
# Epoch 128/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3813 - val_loss: 0.5682
# Epoch 129/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3872 - val_loss: 0.5534
# Epoch 130/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4099 - val_loss: 0.5706
# Epoch 131/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3956 - val_loss: 0.6057
# Epoch 132/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4230 - val_loss: 0.5456
# Epoch 133/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3776 - val_loss: 0.6060
# Epoch 134/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3732 - val_loss: 0.5108
# Epoch 135/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3425 - val_loss: 0.5868
# Epoch 136/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3724 - val_loss: 0.5382
# Epoch 137/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3496 - val_loss: 0.5496
# Epoch 138/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3481 - val_loss: 0.5668
# Epoch 139/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3615 - val_loss: 0.5287
# Epoch 140/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3454 - val_loss: 0.5464
# Epoch 141/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3415 - val_loss: 0.5293
# Epoch 142/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4089 - val_loss: 0.5933
# Epoch 143/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3486 - val_loss: 0.5612
# Epoch 144/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3185 - val_loss: 0.6086
# Epoch 145/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3375 - val_loss: 0.6161
# Epoch 146/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3197 - val_loss: 0.5587
# Epoch 147/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3298 - val_loss: 0.5447
# Epoch 148/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3071 - val_loss: 0.5676
# Epoch 149/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3101 - val_loss: 0.5629
# Epoch 150/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3382 - val_loss: 0.5160
# Epoch 151/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3487 - val_loss: 0.5691
# Epoch 152/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3226 - val_loss: 0.6308
# Epoch 153/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3136 - val_loss: 0.5923
# Epoch 154/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2875 - val_loss: 0.6083
# Epoch 155/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3163 - val_loss: 0.6380
# Epoch 156/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3289 - val_loss: 0.5362
# Epoch 157/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2806 - val_loss: 0.5116
# Epoch 158/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2716 - val_loss: 0.5455
# Epoch 159/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3194 - val_loss: 0.5235
# Epoch 160/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3085 - val_loss: 0.6105
# Epoch 161/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2824 - val_loss: 0.6070
# Epoch 162/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2744 - val_loss: 0.6045
# Epoch 163/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3238 - val_loss: 0.5863
# Epoch 164/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2943 - val_loss: 0.6234
# Epoch 165/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 437ms/step - loss: 0.2654 - val_loss: 0.4746
# Epoch 166/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3471 - val_loss: 0.6270
# Epoch 167/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2941 - val_loss: 0.6474
# Epoch 168/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2898 - val_loss: 0.6186
# Epoch 169/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2909 - val_loss: 0.5620
# Epoch 170/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2626 - val_loss: 0.5349
# Epoch 171/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2509 - val_loss: 0.6170
# Epoch 172/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2411 - val_loss: 0.6349
# Epoch 173/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2772 - val_loss: 0.5115
# Epoch 174/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2451 - val_loss: 0.5178
# Epoch 175/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2780 - val_loss: 0.5201
# Epoch 176/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2757 - val_loss: 0.6405
# Epoch 177/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2562 - val_loss: 0.6056
# Epoch 178/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2559 - val_loss: 0.5366
# Epoch 179/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2205 - val_loss: 0.5550
# Epoch 180/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2221 - val_loss: 0.6426
# Epoch 181/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3065 - val_loss: 0.5612
# Epoch 182/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2544 - val_loss: 0.5742
# Epoch 183/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2398 - val_loss: 0.6181
# Epoch 184/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2593 - val_loss: 0.6178
# Epoch 185/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2217 - val_loss: 0.5906
# Epoch 186/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2347 - val_loss: 0.6904
# Epoch 187/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2395 - val_loss: 0.5809
# Epoch 188/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2049 - val_loss: 0.5713
# Epoch 189/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1990 - val_loss: 0.5650
# Epoch 190/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2280 - val_loss: 0.5682
# Epoch 191/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1939 - val_loss: 0.8256
# Epoch 192/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3656 - val_loss: 0.5728
# Epoch 193/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2511 - val_loss: 0.6260
# Epoch 194/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2245 - val_loss: 0.5272
# Epoch 195/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2378 - val_loss: 0.6358
# Epoch 196/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2488 - val_loss: 0.5646
# Epoch 197/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2055 - val_loss: 0.6736
# Epoch 198/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2776 - val_loss: 0.5935
# Epoch 199/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2263 - val_loss: 0.6526
# Epoch 200/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1884 - val_loss: 0.6087
# Epoch 201/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2207 - val_loss: 0.6609
# Epoch 202/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2295 - val_loss: 0.6155
# Epoch 203/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1805 - val_loss: 0.6125
# Epoch 204/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1659 - val_loss: 0.6546
# Epoch 205/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1869 - val_loss: 0.6722
# Epoch 206/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2460 - val_loss: 0.6713
# Epoch 207/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2107 - val_loss: 0.6064
# Epoch 208/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1567 - val_loss: 0.6753
# Epoch 209/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1880 - val_loss: 0.6639
# Epoch 210/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1653 - val_loss: 0.6441
# Epoch 211/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1831 - val_loss: 0.6551
# Epoch 212/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2795 - val_loss: 0.6067
# Epoch 213/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2093 - val_loss: 0.6409
# Epoch 214/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2015 - val_loss: 0.6803
# Epoch 215/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2542 - val_loss: 0.7459
# Epoch 216/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2367 - val_loss: 0.7342
# Epoch 217/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3143 - val_loss: 0.6322
# Epoch 218/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1868 - val_loss: 0.8244
# Epoch 219/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2054 - val_loss: 0.6972
# Epoch 220/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2397 - val_loss: 0.6804
# Epoch 221/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2000 - val_loss: 0.7852
# Epoch 222/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2992 - val_loss: 0.6857
# Epoch 223/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2190 - val_loss: 0.6693
# Epoch 224/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1752 - val_loss: 0.6103
# Epoch 225/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1229 - val_loss: 0.6305
# Epoch 226/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1620 - val_loss: 0.6397
# Epoch 227/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1344 - val_loss: 0.6190
# Epoch 228/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1159 - val_loss: 0.6893
# Epoch 229/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1301 - val_loss: 0.6040
# Epoch 230/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1268 - val_loss: 0.7136
# Epoch 231/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1789 - val_loss: 0.5999
# Epoch 232/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1360 - val_loss: 0.6632
# Epoch 233/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1230 - val_loss: 0.6475
# Epoch 234/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1502 - val_loss: 0.6115
# Epoch 235/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1483 - val_loss: 0.5898
# Epoch 236/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1293 - val_loss: 0.6542
# Epoch 237/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1492 - val_loss: 0.6322
# Epoch 238/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1692 - val_loss: 0.6671
# Epoch 239/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3138 - val_loss: 0.6965
# Epoch 240/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2072 - val_loss: 0.6545
# Epoch 241/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2014 - val_loss: 0.6901
# Epoch 242/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1663 - val_loss: 0.6409
# Epoch 243/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1573 - val_loss: 0.6495
# Epoch 244/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1491 - val_loss: 0.6783
# Epoch 245/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1364 - val_loss: 0.7404
# Epoch 246/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1573 - val_loss: 0.6770
# Epoch 247/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2131 - val_loss: 0.7488
# Epoch 248/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3011 - val_loss: 0.6418
# Epoch 249/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.4946 - val_loss: 0.6794
# Epoch 250/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3150 - val_loss: 0.6869
# Epoch 251/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2135 - val_loss: 0.6908
# Epoch 252/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1630 - val_loss: 0.9012
# Epoch 253/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2331 - val_loss: 0.6154
# Epoch 254/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1592 - val_loss: 0.7181
# Epoch 255/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1324 - val_loss: 0.7953
# Epoch 256/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2810 - val_loss: 0.6429
# Epoch 257/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2552 - val_loss: 0.7462
# Epoch 258/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1940 - val_loss: 0.7654
# Epoch 259/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2121 - val_loss: 0.6769
# Epoch 260/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1815 - val_loss: 0.6065
# Epoch 261/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1157 - val_loss: 0.6740
# Epoch 262/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1794 - val_loss: 0.6412
# Epoch 263/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1072 - val_loss: 0.6247
# Epoch 264/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1363 - val_loss: 0.7115
# Epoch 265/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2477 - val_loss: 0.6561
# Epoch 266/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1393 - val_loss: 0.6900
# Epoch 267/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1170 - val_loss: 0.5802
# Epoch 268/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1655 - val_loss: 0.7269
# Epoch 269/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1247 - val_loss: 0.6346
# Epoch 270/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1077 - val_loss: 0.6374
# Epoch 271/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1116 - val_loss: 0.6180
# Epoch 272/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1242 - val_loss: 0.7371
# Epoch 273/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2151 - val_loss: 0.6553
# Epoch 274/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1573 - val_loss: 0.6751
# Epoch 275/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2575 - val_loss: 0.6815
# Epoch 276/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1658 - val_loss: 0.6698
# Epoch 277/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1880 - val_loss: 0.7409
# Epoch 278/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1469 - val_loss: 0.6597
# Epoch 279/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1260 - val_loss: 0.6152
# Epoch 280/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1622 - val_loss: 0.6812
# Epoch 281/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1830 - val_loss: 0.6921
# Epoch 282/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1100 - val_loss: 0.6776
# Epoch 283/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1536 - val_loss: 0.6812
# Epoch 284/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1472 - val_loss: 0.6609
# Epoch 285/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0982 - val_loss: 0.6818
# Epoch 286/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1665 - val_loss: 0.8283
# Epoch 287/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1442 - val_loss: 0.6463
# Epoch 288/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1047 - val_loss: 0.6283
# Epoch 289/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0851 - val_loss: 0.6828
# Epoch 290/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1047 - val_loss: 0.7201
# Epoch 291/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1358 - val_loss: 0.7591
# Epoch 292/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1595 - val_loss: 0.8007
# Epoch 293/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1657 - val_loss: 0.7666
# Epoch 294/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1696 - val_loss: 0.7219
# Epoch 295/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1289 - val_loss: 0.6605
# Epoch 296/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1194 - val_loss: 0.7496
# Epoch 297/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0949 - val_loss: 0.7447
# Epoch 298/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1266 - val_loss: 0.6949
# Epoch 299/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2621 - val_loss: 0.6487
# Epoch 300/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1808 - val_loss: 0.8189

# %%
# Predict and evaluate
y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)
print(f"Test MSE: {mse:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# Test MSE: 0.6539

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │        97,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │     4,100,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8192)           │    33,562,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16384)          │   134,234,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8192)           │   134,225,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4096)           │    33,558,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2048)           │     8,390,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,103,169,341 (4.11 GB)
#  Trainable params: 367,723,113 (1.37 GB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 735,446,228 (2.74 GB)

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Randomly select 100 indices
import matplotlib.pyplot as plt
indices = np.random.choice(len(Y_test), size=100, replace=False)
indices = np.sort(indices)

y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
y_test_rescaled = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
print(f"Test MSE: {mse:.4f}")


# Extract corresponding values
y_test_sampled = y_test_rescaled[indices]
y_pred_sampled = y_pred_rescaled[indices]

# Plot with circular markers
plt.figure(figsize=(16, 8))
plt.plot(y_test_sampled, 'r-o', label='Ground Truth (HHB2)', linewidth=2, markersize=5)
plt.plot(y_pred_sampled, 'b--o', label='Predicted (HHB2)', linewidth=2, markersize=5)
plt.xlabel('Random Sample Index')
plt.ylabel('HHB2')
plt.title('Randomly Sampled Predictions vs Ground Truth')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE: 21.7992

# %%
# Inverse-transform predictions and ground truth
y_pred_orig = scaler_y.inverse_transform(y_pred)       # shape (n, 1)
y_test_orig = scaler_y.inverse_transform(Y_test)     # shape (n, 1)

# Compute residuals in original scale
residuals = y_pred_orig - y_test_orig

mse_rescaled = mean_squared_error(y_test_orig, y_pred_orig)
print(f"Test MSE (original scale): {mse_rescaled:.4f}")

# Plot residuals
plt.figure(figsize=(16, 8))
plt.scatter(range(len(residuals)), residuals, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.title("Residuals (Predicted - Ground Truth)")
plt.ylabel("Residual")
plt.ylim(-10, 10)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE (original scale): 21.7992

# %%
# Inverse-transform predictions and ground truth
y_pred_orig = scaler_y.inverse_transform(y_pred)       # shape (n, 1)
y_test_orig = scaler_y.inverse_transform(Y_test)     # shape (n, 1)

# Compute relative error (percentage)
relative_error = ((y_pred_orig - y_test_orig) / y_test_orig) * 100

# Plot relative error
plt.figure(figsize=(16, 8))
plt.scatter(range(len(relative_error)), relative_error, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.ylabel("Relative Error (%)")
plt.ylim(-100, 100)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Prepare DataFrame for seaborn
df_plot = pd.DataFrame({
    'Relative Error (%)': relative_error.flatten()
})

plt.figure(figsize=(10, 10))
sns.violinplot(data=df_plot, y='Relative Error (%)', inner=None, linewidth=1.2)
sns.stripplot(data=df_plot, y='Relative Error (%)', color='black', alpha=0.4, jitter=0.2, size=3)

plt.axhline(0, color='r', linestyle='--', linewidth=1)
plt.ylim(-100, 100)
plt.title('Distribution of Relative Error (%)')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
relative_error = relative_error.squeeze()

plt.figure(figsize=(10, 6))
sns.boxplot(y=relative_error, color='lightgray', width=0.3)
sns.stripplot(y=relative_error, color='black', alpha=0.03, jitter=0.4, size=1.5)

plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.title('Relative Error Distribution (%)')
plt.ylabel('Relative Error (%)')
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(10, 6))
sns.violinplot(y=relative_error, inner=None, color='skyblue', cut=0)
sns.stripplot(y=relative_error, color='black', alpha=0.05, jitter=0.3, size=2)

plt.axhline(0, color='red', linestyle='--', linewidth=1.2)
plt.title('Distribution of Relative Error (%)')
plt.ylabel('Relative Error (%)')
plt.grid()
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(relative_error, kde=True, bins=1000, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Histogram + KDE of Relative Error (%)")
plt.xlabel("Relative Error (%)")
plt.ylabel("Frequency")
plt.grid()
plt.xlim(-100, 100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

# Subplot 1: Ground truth
plt.subplot(1, 2, 1)
sns.histplot(np.asarray(y_test_orig).ravel(), kde=True, bins=100, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Ground Truth (Y_test) Distribution")
plt.xlabel("Y_test")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

# Subplot 2: Prediction
plt.subplot(1, 2, 2)
sns.histplot( np.asarray(y_pred_orig).ravel(), kde=True, bins=100, color='darkorange', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Prediction (Y_pred) Distribution")
plt.xlabel("Y_pred")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# Ensure y_true and y_pred are 1D numpy arrays
y_true = np.asarray(y_test_orig).ravel()
y_pred =np.asarray(y_pred_orig).ravel()

# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# Plot
plt.figure(figsize=(10, 10))
plt.hist2d(y_true, y_pred, bins=100, cmap='Blues', cmin=1)

# Plot identity line
plt.plot([min(y_true), max(y_true)],
         [min(y_true), max(y_true)],
         'k--', lw=1)

# Labels and title
plt.xlabel('Expected $\Delta[HHB2]$')
plt.ylabel('Predicted $\Delta[HHB2]$')
plt.title(r'$S$')

# Annotate RMSE
plt.text(0.05, 0.95, f'RMSE: {rmse:.2e}', color='darkred',
         fontsize=14, transform=plt.gca().transAxes, va='top')

plt.colorbar(label='Density')
plt.tight_layout()
plt.show()

# %%
# Small epsilon to avoid division by zero
eps = 1e-8

# Relative error (%)
relative_error = (y_pred - y_true) / (y_true + eps) * 100
absolute_relative_error = np.abs(relative_error)

# Compute metrics
mre = np.mean(relative_error)
mape = np.mean(absolute_relative_error)

# Print
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 15.7719%
