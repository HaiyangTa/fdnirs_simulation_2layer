# %% [markdown]
# ## FD_abs[hhb2] ANN Fitting

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
! pip install pmcx
# Out:
# Collecting pmcx
#   Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 87.6 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.4.2

# %%
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Mounted at /content/drive

# %%
from FD_msNIRS_2layers import extract_freq as ef

# %% [markdown]
# ### Read Simulation data

# %%
import os
import pickle
import numpy as np

# %%
result_folder1 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part1/'
result_folder2 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part2/'
result_folder3 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part3/'
result_folder4 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part4/'
result_folder5 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part5/'
result_folder6 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part6/'
result_folder7 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part7/'
result_folder8 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part8/'
result_folder9 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part9/'
result_folder10 = '/content/drive/MyDrive/MCX_data/result_folder/stage2/part10/'
result_folders = [result_folder1, result_folder2, result_folder3, result_folder4, result_folder5, result_folder6, result_folder7, result_folder8, result_folder9, result_folder10]

# %%
def row_construct(dictt):
    re = np.zeros((1, 192))
    col = 0
    for k, v in dictt.items():  # four distances
        TPSF_list = v
        uac_i, udc_i, p1 = ef(1e4, TPSF_list, tend=1e-08, devf=1000)  # 8 wavelengths
        combined = []
        for i in range(8):
            combined.extend([uac_i[i], udc_i[i], p1[i]])  # Interleave the values
        re[0, col:col+24] = combined  # Each set contributes 24 values
        col += 24
    return re

# %%
import os
import pickle
import numpy as np
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

def extract_id_from_path(path):
    filename = os.path.basename(path)
    return int(filename.replace('.pkl', ''))

def load_and_construct(path):
    with open(path, 'rb') as f:
        dictt = pickle.load(f)
    return row_construct(dictt)

def load_and_process_all(result_folders):
    # Collect all file paths
    file_paths = []
    for folder in result_folders:
        for f in os.listdir(folder):
            if f.endswith('.pkl'):
                file_paths.append(os.path.join(folder, f))

    # Sort by numeric filename
    sorted_paths = sorted(file_paths, key=extract_id_from_path)
    sorted_ids = [extract_id_from_path(p) for p in sorted_paths]

    # Load and process in parallel (with progress bar)
    all_rows = []
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(load_and_construct, sorted_paths), total=len(sorted_paths), desc="Loading and processing files"))

    result_array = np.vstack(results)
    return result_array, sorted_ids

# %%
final_array, sorted_ids = load_and_process_all(result_folders)
# Out:
# Loading and processing files: 100%|██████████| 5000/5000 [07:22<00:00, 11.29it/s]

# %%
final_array.shape
# Out:
# (5000, 192)

# %%
# Save to CSV
output_csv_path = '/content/drive/MyDrive/MCX_data/stage2.csv'
pd.DataFrame(final_array).to_csv(output_csv_path, index=False, header=False)

# %%
final_array.shape
# Out:
# (5000, 192)

# %% [markdown]
# ### Read the saved CSV

# %%
import pandas as pd
import glob
import numpy as np
import sys
! pip install pmcx
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pickle
# Out:
# Collecting pmcx
#   Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 68.6 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.4.2
# Mounted at /content/drive

# %%
csv_path = '/content/drive/MyDrive/MCX_data/stage2.csv'
final_array = np.loadtxt(csv_path, delimiter=',')
print(final_array.shape)
X = final_array
# Out:
# (5000, 192)

# %% [markdown]
# ### GT

# %%
GT_folder = '/content/drive/MyDrive/MCX_data/stage2_csv/'

# %%
csv_files = glob.glob(os.path.join(GT_folder, '*.csv'))
GT_all = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# %%
GT_all.head()
# Out:
#         HBO1       HHB1       HBO2       HHB2    d1        a1        a2  \
# 0  14.209716   6.363222  45.917948  19.337672  13.0  6.766997  1.181103
# 1   6.709716  11.363222  30.917948  29.337672  18.0  3.766997  2.731103
# 2  10.459716   3.863222  53.417948  24.337672  11.0  5.266997  1.956103
# 3  17.959716   8.863222  38.417948  34.337672  16.0  2.266997  3.506103
# 4  16.084716   2.613222  27.167948  21.837672  20.0  3.016997  3.893603
#
#          b1        b2    ID
# 0  1.939614  2.599744  9001
# 1  0.739614  1.099744  9002
# 2  1.339614  0.349744  9003
# 3  0.139614  1.849744  9004
# 4  0.439614  2.224744  9005

# %%
sorted_ids = [i+1 for i in range(5000)]

# %%
sorted_ids[-1]
# Out:
# 5000

# %%
# Ensure ID column is integer
GT_all['ID'] = GT_all['ID'].astype(int)

# Filter and sort GT_all to match the sorted_ids order
GT_filtered = GT_all[GT_all['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()

# Extract HHB2 as Y
Y = GT_filtered['HHB2'].values  # numpy array (n_samples,)
Y = Y.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Scale X
scaler_X = StandardScaler()
X = scaler_X.fit_transform(X)

# Scale Y
scaler_y = StandardScaler()
Y = scaler_y.fit_transform(Y)

# %%
X.shape
# Out:
# (5000, 192)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (4500, 192) (500, 192)

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.losses import Huber
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint


model = Sequential([
    Input(shape=(192,)),
    Dense(1000, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(8192*2, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(2048, activation='relu'),
    Dropout(0.2),

    Dense(1024, activation='relu'),
    Dropout(0.2),

    Dense(512, activation='relu'),
    Dropout(0.1),

    Dense(256, activation='relu'),
    Dropout(0.1),

    Dense(64, activation='relu'),
    Dropout(0.1),

    Dense(32, activation='relu'),
    Dropout(0.0),

    Dense(1)  # Output layer for regression
])


# 1) Create a checkpoint callback that saves the best model:
checkpoint_cb = ModelCheckpoint(
    "best_model.keras",        # filepath to save to
    monitor="val_loss",     # quantity to monitor
    mode="min",             # we want to minimize val_loss
    save_best_only=True,    # only save when val_loss decreases
    save_weights_only=False # set True if you only want weights
)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer, loss="mse")

# 3) Fit with the checkpoint callback
history = model.fit(
    X_train, Y_train,
    epochs=300,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    callbacks=[checkpoint_cb]
)

# 4) Later on (or in a new script), load the best model:
model = tf.keras.models.load_model("best_model.keras")
# Out:
# Epoch 1/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 74s 491ms/step - loss: 1.0188 - val_loss: 0.9812
# Epoch 2/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 251ms/step - loss: 1.0115 - val_loss: 0.9749
# Epoch 3/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 31s 249ms/step - loss: 1.0006 - val_loss: 0.9645
# Epoch 4/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 250ms/step - loss: 0.9781 - val_loss: 0.9144
# Epoch 5/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 33s 260ms/step - loss: 0.9775 - val_loss: 0.8574
# Epoch 6/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 33s 262ms/step - loss: 0.8985 - val_loss: 0.7957
# Epoch 7/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.8608 - val_loss: 0.8171
# Epoch 8/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 266ms/step - loss: 0.8368 - val_loss: 0.7703
# Epoch 9/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 33s 258ms/step - loss: 0.8641 - val_loss: 0.7300
# Epoch 10/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.8011 - val_loss: 0.7753
# Epoch 11/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 33s 259ms/step - loss: 0.7948 - val_loss: 0.7259
# Epoch 12/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 253ms/step - loss: 0.7962 - val_loss: 0.6926
# Epoch 13/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.7409 - val_loss: 0.7070
# Epoch 14/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.7620 - val_loss: 0.7014
# Epoch 15/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.7482 - val_loss: 0.7516
# Epoch 16/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 250ms/step - loss: 0.7278 - val_loss: 0.6399
# Epoch 17/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 33s 260ms/step - loss: 0.6639 - val_loss: 0.5365
# Epoch 18/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.6793 - val_loss: 0.6204
# Epoch 19/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.6240 - val_loss: 0.5889
# Epoch 20/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.6526 - val_loss: 0.5712
# Epoch 21/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 257ms/step - loss: 0.6268 - val_loss: 0.4944
# Epoch 22/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 256ms/step - loss: 0.5837 - val_loss: 0.4810
# Epoch 23/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.5599 - val_loss: 0.8139
# Epoch 24/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.6914 - val_loss: 0.4814
# Epoch 25/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 253ms/step - loss: 0.5563 - val_loss: 0.4688
# Epoch 26/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.5345 - val_loss: 0.4980
# Epoch 27/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.5853 - val_loss: 0.5419
# Epoch 28/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 251ms/step - loss: 0.5322 - val_loss: 0.4428
# Epoch 29/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 269ms/step - loss: 0.5091 - val_loss: 0.3711
# Epoch 30/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.4882 - val_loss: 0.4250
# Epoch 31/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.4820 - val_loss: 0.4289
# Epoch 32/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.4410 - val_loss: 0.3929
# Epoch 33/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.4408 - val_loss: 0.3782
# Epoch 34/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.4263 - val_loss: 0.4184
# Epoch 35/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 255ms/step - loss: 0.4990 - val_loss: 0.3339
# Epoch 36/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.4284 - val_loss: 0.3820
# Epoch 37/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.4398 - val_loss: 0.3772
# Epoch 38/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3999 - val_loss: 0.4614
# Epoch 39/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3985 - val_loss: 0.3844
# Epoch 40/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 265ms/step - loss: 0.4135 - val_loss: 0.3283
# Epoch 41/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 265ms/step - loss: 0.3787 - val_loss: 0.3199
# Epoch 42/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 255ms/step - loss: 0.3565 - val_loss: 0.3167
# Epoch 43/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3719 - val_loss: 0.3421
# Epoch 44/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3986 - val_loss: 0.3805
# Epoch 45/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3935 - val_loss: 0.3576
# Epoch 46/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3911 - val_loss: 0.3558
# Epoch 47/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3719 - val_loss: 0.3229
# Epoch 48/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3973 - val_loss: 0.3170
# Epoch 49/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3545 - val_loss: 0.4366
# Epoch 50/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3529 - val_loss: 0.3345
# Epoch 51/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 266ms/step - loss: 0.3535 - val_loss: 0.3088
# Epoch 52/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3294 - val_loss: 0.4326
# Epoch 53/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.4301 - val_loss: 0.3119
# Epoch 54/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3337 - val_loss: 0.3448
# Epoch 55/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3585 - val_loss: 0.3110
# Epoch 56/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3154 - val_loss: 0.3271
# Epoch 57/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 250ms/step - loss: 0.3335 - val_loss: 0.2886
# Epoch 58/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2843 - val_loss: 0.4661
# Epoch 59/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3877 - val_loss: 0.2903
# Epoch 60/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2944 - val_loss: 0.3089
# Epoch 61/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 33s 257ms/step - loss: 0.3159 - val_loss: 0.2621
# Epoch 62/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3050 - val_loss: 0.2737
# Epoch 63/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2796 - val_loss: 0.2805
# Epoch 64/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2888 - val_loss: 0.4099
# Epoch 65/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3084 - val_loss: 0.3053
# Epoch 66/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3080 - val_loss: 0.4214
# Epoch 67/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3155 - val_loss: 0.2844
# Epoch 68/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2903 - val_loss: 0.3552
# Epoch 69/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2777 - val_loss: 0.3767
# Epoch 70/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2687 - val_loss: 0.2858
# Epoch 71/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3242 - val_loss: 0.2787
# Epoch 72/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2994 - val_loss: 0.3813
# Epoch 73/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2923 - val_loss: 0.2731
# Epoch 74/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2455 - val_loss: 0.4184
# Epoch 75/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 252ms/step - loss: 0.3560 - val_loss: 0.2446
# Epoch 76/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2676 - val_loss: 0.2825
# Epoch 77/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2566 - val_loss: 0.3073
# Epoch 78/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2911 - val_loss: 0.3025
# Epoch 79/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2781 - val_loss: 0.2844
# Epoch 80/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2679 - val_loss: 0.3285
# Epoch 81/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2551 - val_loss: 0.2729
# Epoch 82/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2671 - val_loss: 0.3575
# Epoch 83/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2644 - val_loss: 0.2779
# Epoch 84/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2490 - val_loss: 0.2583
# Epoch 85/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2474 - val_loss: 0.3906
# Epoch 86/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2606 - val_loss: 0.2771
# Epoch 87/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2301 - val_loss: 0.3781
# Epoch 88/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2646 - val_loss: 0.3042
# Epoch 89/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2253 - val_loss: 0.2947
# Epoch 90/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2489 - val_loss: 0.4040
# Epoch 91/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2912 - val_loss: 0.3101
# Epoch 92/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2997 - val_loss: 0.3713
# Epoch 93/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2839 - val_loss: 0.2996
# Epoch 94/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2359 - val_loss: 0.2964
# Epoch 95/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2439 - val_loss: 0.3172
# Epoch 96/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2375 - val_loss: 0.2670
# Epoch 97/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2486 - val_loss: 0.3372
# Epoch 98/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2533 - val_loss: 0.3387
# Epoch 99/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2125 - val_loss: 0.3348
# Epoch 100/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2457 - val_loss: 0.3186
# Epoch 101/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2317 - val_loss: 0.3238
# Epoch 102/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2168 - val_loss: 0.2953
# Epoch 103/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2277 - val_loss: 0.2900
# Epoch 104/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2563 - val_loss: 0.2785
# Epoch 105/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2602 - val_loss: 0.3683
# Epoch 106/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2707 - val_loss: 0.2586
# Epoch 107/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2161 - val_loss: 0.3432
# Epoch 108/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2178 - val_loss: 0.3283
# Epoch 109/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2202 - val_loss: 0.2526
# Epoch 110/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2102 - val_loss: 0.3205
# Epoch 111/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2296 - val_loss: 0.2873
# Epoch 112/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1954 - val_loss: 0.2697
# Epoch 113/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2758 - val_loss: 0.2667
# Epoch 114/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2043 - val_loss: 0.3268
# Epoch 115/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2217 - val_loss: 0.3044
# Epoch 116/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1955 - val_loss: 0.3146
# Epoch 117/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 271ms/step - loss: 0.2444 - val_loss: 0.2437
# Epoch 118/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2134 - val_loss: 0.2892
# Epoch 119/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2009 - val_loss: 0.3253
# Epoch 120/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1867 - val_loss: 0.3076
# Epoch 121/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1796 - val_loss: 0.2589
# Epoch 122/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1803 - val_loss: 0.2620
# Epoch 123/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1928 - val_loss: 0.3079
# Epoch 124/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1966 - val_loss: 0.3226
# Epoch 125/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1947 - val_loss: 0.4049
# Epoch 126/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2277 - val_loss: 0.3326
# Epoch 127/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2153 - val_loss: 0.3726
# Epoch 128/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2053 - val_loss: 0.2816
# Epoch 129/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1883 - val_loss: 0.3013
# Epoch 130/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1935 - val_loss: 0.3178
# Epoch 131/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1936 - val_loss: 0.2854
# Epoch 132/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1886 - val_loss: 0.3025
# Epoch 133/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1982 - val_loss: 0.2902
# Epoch 134/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2063 - val_loss: 0.2593
# Epoch 135/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1729 - val_loss: 0.2682
# Epoch 136/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1695 - val_loss: 0.2816
# Epoch 137/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1844 - val_loss: 0.2872
# Epoch 138/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1774 - val_loss: 0.3473
# Epoch 139/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2906 - val_loss: 0.2709
# Epoch 140/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1921 - val_loss: 0.2640
# Epoch 141/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1792 - val_loss: 0.2791
# Epoch 142/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1600 - val_loss: 0.2687
# Epoch 143/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1669 - val_loss: 0.2896
# Epoch 144/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1578 - val_loss: 0.3575
# Epoch 145/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1775 - val_loss: 0.2947
# Epoch 146/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1762 - val_loss: 0.3294
# Epoch 147/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1757 - val_loss: 0.2741
# Epoch 148/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1597 - val_loss: 0.3048
# Epoch 149/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1690 - val_loss: 0.3540
# Epoch 150/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2189 - val_loss: 0.2926
# Epoch 151/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1523 - val_loss: 0.4353
# Epoch 152/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1708 - val_loss: 0.2751
# Epoch 153/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1792 - val_loss: 0.3282
# Epoch 154/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1825 - val_loss: 0.3343
# Epoch 155/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2282 - val_loss: 0.2849
# Epoch 156/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1962 - val_loss: 0.4303
# Epoch 157/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1800 - val_loss: 0.2694
# Epoch 158/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1490 - val_loss: 0.2778
# Epoch 159/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1762 - val_loss: 0.2932
# Epoch 160/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1738 - val_loss: 0.3205
# Epoch 161/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2103 - val_loss: 0.2822
# Epoch 162/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1389 - val_loss: 0.3112
# Epoch 163/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1445 - val_loss: 0.2891
# Epoch 164/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1670 - val_loss: 0.3283
# Epoch 165/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1871 - val_loss: 0.2855
# Epoch 166/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1585 - val_loss: 0.2849
# Epoch 167/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1885 - val_loss: 0.3340
# Epoch 168/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1800 - val_loss: 0.3237
# Epoch 169/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1831 - val_loss: 0.3228
# Epoch 170/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1670 - val_loss: 0.2699
# Epoch 171/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1724 - val_loss: 0.3054
# Epoch 172/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1486 - val_loss: 0.3093
# Epoch 173/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1492 - val_loss: 0.2982
# Epoch 174/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1878 - val_loss: 0.2848
# Epoch 175/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1726 - val_loss: 0.2905
# Epoch 176/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1767 - val_loss: 0.2711
# Epoch 177/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1310 - val_loss: 0.3243
# Epoch 178/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1625 - val_loss: 0.3033
# Epoch 179/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1754 - val_loss: 0.3240
# Epoch 180/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1743 - val_loss: 0.3643
# Epoch 181/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1525 - val_loss: 0.3188
# Epoch 182/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1281 - val_loss: 0.2884
# Epoch 183/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1625 - val_loss: 0.3420
# Epoch 184/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1299 - val_loss: 0.3977
# Epoch 185/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1670 - val_loss: 0.3317
# Epoch 186/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1498 - val_loss: 0.3479
# Epoch 187/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1779 - val_loss: 0.3359
# Epoch 188/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1506 - val_loss: 0.3334
# Epoch 189/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1446 - val_loss: 0.3869
# Epoch 190/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1598 - val_loss: 0.3672
# Epoch 191/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1722 - val_loss: 0.3426
# Epoch 192/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3632 - val_loss: 0.2920
# Epoch 193/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1870 - val_loss: 0.3070
# Epoch 194/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1449 - val_loss: 0.3240
# Epoch 195/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1458 - val_loss: 0.3282
# Epoch 196/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1495 - val_loss: 0.4560
# Epoch 197/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2352 - val_loss: 0.3686
# Epoch 198/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1923 - val_loss: 0.3487
# Epoch 199/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1609 - val_loss: 0.3048
# Epoch 200/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1882 - val_loss: 0.3855
# Epoch 201/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1568 - val_loss: 0.3203
# Epoch 202/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1199 - val_loss: 0.2950
# Epoch 203/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1415 - val_loss: 0.3345
# Epoch 204/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1387 - val_loss: 0.3859
# Epoch 205/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1524 - val_loss: 0.3245
# Epoch 206/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1559 - val_loss: 0.3086
# Epoch 207/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1295 - val_loss: 0.3488
# Epoch 208/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1831 - val_loss: 0.3472
# Epoch 209/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2073 - val_loss: 0.4356
# Epoch 210/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2040 - val_loss: 0.3621
# Epoch 211/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1669 - val_loss: 0.7252
# Epoch 212/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.5367 - val_loss: 0.3322
# Epoch 213/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2733 - val_loss: 0.3836
# Epoch 214/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2040 - val_loss: 0.3863
# Epoch 215/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1696 - val_loss: 0.3577
# Epoch 216/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1803 - val_loss: 0.3636
# Epoch 217/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1367 - val_loss: 0.4239
# Epoch 218/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1412 - val_loss: 0.3461
# Epoch 219/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2458 - val_loss: 0.3587
# Epoch 220/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2018 - val_loss: 0.3282
# Epoch 221/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1478 - val_loss: 0.3335
# Epoch 222/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1369 - val_loss: 0.5503
# Epoch 223/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1878 - val_loss: 0.3416
# Epoch 224/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1338 - val_loss: 0.3290
# Epoch 225/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1024 - val_loss: 0.3226
# Epoch 226/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1088 - val_loss: 0.3518
# Epoch 227/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1097 - val_loss: 0.3377
# Epoch 228/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1321 - val_loss: 0.3691
# Epoch 229/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1840 - val_loss: 0.3771
# Epoch 230/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2287 - val_loss: 0.3221
# Epoch 231/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1575 - val_loss: 0.3704
# Epoch 232/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1513 - val_loss: 0.3298
# Epoch 233/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1305 - val_loss: 0.3159
# Epoch 234/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1063 - val_loss: 0.4380
# Epoch 235/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2319 - val_loss: 0.2970
# Epoch 236/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1075 - val_loss: 0.3663
# Epoch 237/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1196 - val_loss: 0.4311
# Epoch 238/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1440 - val_loss: 0.3480
# Epoch 239/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1018 - val_loss: 0.3548
# Epoch 240/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1370 - val_loss: 0.4458
# Epoch 241/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1168 - val_loss: 0.3371
# Epoch 242/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1010 - val_loss: 0.3481
# Epoch 243/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.0914 - val_loss: 0.3618
# Epoch 244/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1081 - val_loss: 0.3665
# Epoch 245/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1315 - val_loss: 0.3938
# Epoch 246/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1723 - val_loss: 0.3994
# Epoch 247/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1416 - val_loss: 0.5043
# Epoch 248/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2619 - val_loss: 0.3934
# Epoch 249/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1209 - val_loss: 0.3507
# Epoch 250/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1440 - val_loss: 0.3122
# Epoch 251/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.3200 - val_loss: 0.3577
# Epoch 252/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1616 - val_loss: 0.3771
# Epoch 253/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1098 - val_loss: 0.3798
# Epoch 254/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1125 - val_loss: 0.3286
# Epoch 255/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.0862 - val_loss: 0.3522
# Epoch 256/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.0809 - val_loss: 0.4384
# Epoch 257/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.0978 - val_loss: 0.3652
# Epoch 258/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1666 - val_loss: 0.3672
# Epoch 259/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1614 - val_loss: 0.3936
# Epoch 260/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1811 - val_loss: 0.3273
# Epoch 261/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1296 - val_loss: 0.4015
# Epoch 262/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2652 - val_loss: 0.3448
# Epoch 263/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1309 - val_loss: 0.4075
# Epoch 264/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1120 - val_loss: 0.3798
# Epoch 265/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1061 - val_loss: 0.4602
# Epoch 266/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.5668 - val_loss: 0.4432
# Epoch 267/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2459 - val_loss: 0.4474
# Epoch 268/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2096 - val_loss: 0.4314
# Epoch 269/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1607 - val_loss: 0.3642
# Epoch 270/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1698 - val_loss: 0.3168
# Epoch 271/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1129 - val_loss: 0.3546
# Epoch 272/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1138 - val_loss: 0.4011
# Epoch 273/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1311 - val_loss: 0.3423
# Epoch 274/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1062 - val_loss: 0.3662
# Epoch 275/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1275 - val_loss: 0.3480
# Epoch 276/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1039 - val_loss: 0.4381
# Epoch 277/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1853 - val_loss: 0.4641
# Epoch 278/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1324 - val_loss: 0.3609
# Epoch 279/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.0952 - val_loss: 0.4662
# Epoch 280/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1537 - val_loss: 0.4086
# Epoch 281/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1807 - val_loss: 0.5226
# Epoch 282/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2104 - val_loss: 0.4833
# Epoch 283/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1592 - val_loss: 0.4210
# Epoch 284/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2179 - val_loss: 0.3892
# Epoch 285/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1507 - val_loss: 0.3457
# Epoch 286/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1195 - val_loss: 0.3559
# Epoch 287/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1517 - val_loss: 0.4739
# Epoch 288/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.2466 - val_loss: 0.3418
# Epoch 289/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1365 - val_loss: 0.4579
# Epoch 290/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1993 - val_loss: 0.3286
# Epoch 291/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1202 - val_loss: 0.5027
# Epoch 292/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1383 - val_loss: 0.3194
# Epoch 293/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1125 - val_loss: 0.3804
# Epoch 294/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1138 - val_loss: 0.5150
# Epoch 295/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1441 - val_loss: 0.4026
# Epoch 296/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1336 - val_loss: 0.3611
# Epoch 297/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.0888 - val_loss: 0.4262
# Epoch 298/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1089 - val_loss: 0.3810
# Epoch 299/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1360 - val_loss: 0.4806
# Epoch 300/300
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 0.1795 - val_loss: 0.3935

# %%
# Predict and evaluate
y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)
print(f"Test MSE: {mse:.4f}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 15s 840ms/step
# Test MSE: 0.2561

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │       193,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │     4,100,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8192)           │    33,562,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16384)          │   134,234,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8192)           │   134,225,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4096)           │    33,558,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2048)           │     8,390,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,103,457,341 (4.11 GB)
#  Trainable params: 367,819,113 (1.37 GB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 735,638,228 (2.74 GB)

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Randomly select 100 indices
import matplotlib.pyplot as plt
indices = np.random.choice(len(Y_test), size=100, replace=False)
indices = np.sort(indices)

y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
y_test_rescaled = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
print(f"Test MSE: {mse:.4f}")


# Extract corresponding values
y_test_sampled = y_test_rescaled[indices]
y_pred_sampled = y_pred_rescaled[indices]

# Plot with circular markers
plt.figure(figsize=(16, 8))
plt.plot(y_test_sampled, 'r-o', label='Ground Truth (HHB2)', linewidth=2, markersize=5)
plt.plot(y_pred_sampled, 'b--o', label='Predicted (HHB2)', linewidth=2, markersize=5)
plt.xlabel('Random Sample Index')
plt.ylabel('HHB2')
plt.title('Randomly Sampled Predictions vs Ground Truth')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE: 8.5380

# %%
# Inverse-transform predictions and ground truth
y_pred_orig = scaler_y.inverse_transform(y_pred)       # shape (n, 1)
y_test_orig = scaler_y.inverse_transform(Y_test)     # shape (n, 1)

# Compute residuals in original scale
residuals = y_pred_orig - y_test_orig

mse_rescaled = mean_squared_error(y_test_orig, y_pred_orig)
print(f"Test MSE (original scale): {mse_rescaled:.4f}")

# Plot residuals
plt.figure(figsize=(16, 8))
plt.scatter(range(len(residuals)), residuals, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.title("Residuals (Predicted - Ground Truth)")
plt.ylabel("Residual")
plt.ylim(-10, 10)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE (original scale): 8.5380

# %%
# Inverse-transform predictions and ground truth
y_pred_orig = scaler_y.inverse_transform(y_pred)       # shape (n, 1)
y_test_orig = scaler_y.inverse_transform(Y_test)     # shape (n, 1)

# Compute relative error (percentage)
relative_error = ((y_pred_orig - y_test_orig) / y_test_orig) * 100

# Plot relative error
plt.figure(figsize=(16, 8))
plt.scatter(range(len(relative_error)), relative_error, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.ylabel("Relative Error (%)")
plt.ylim(-100, 100)
plt.yticks(np.arange(-100, 101, 10))
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Prepare DataFrame for seaborn
df_plot = pd.DataFrame({
    'Relative Error (%)': relative_error.flatten()
})

plt.figure(figsize=(10, 10))
sns.violinplot(data=df_plot, y='Relative Error (%)', inner=None, linewidth=1.2)
sns.stripplot(data=df_plot, y='Relative Error (%)', color='black', alpha=0.4, jitter=0.2, size=3)

plt.axhline(0, color='r', linestyle='--', linewidth=1)
plt.ylim(-100, 100)
plt.title('Distribution of Relative Error (%)')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_percentage_error

plt.figure(figsize=(10,10))
plt.scatter(y_test_rescaled, y_pred_rescaled, alpha=0.6)
lims = [min(y_test_rescaled.min(), y_pred_rescaled.min()),
        max(y_test_rescaled.max(), y_pred_rescaled.max())]
plt.plot(lims, lims, 'k--')              # identity line
plt.xlabel('Ground-truth HHB2'); plt.ylabel('Predicted HHB2')
plt.title('Parity plot')
plt.axis('square'); plt.xlim(lims); plt.ylim(lims)
plt.grid()
print("R² =", r2_score(y_test_rescaled, y_pred_rescaled))
print("MAPE =", mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)*100, "%")
plt.show()
# Out:
# R² = 0.7400403566143032
# MAPE = 9.341647359057188 %

# %%
|relative_error = relative_error.squeeze()

plt.figure(figsize=(10, 6))
sns.boxplot(y=relative_error, color='lightgray', width=0.3)
sns.stripplot(y=relative_error, color='black', alpha=0.03, jitter=0.4, size=1.5)

plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.title('Relative Error Distribution (%)')
plt.ylabel('Relative Error (%)')
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(10, 6))
sns.violinplot(y=relative_error, inner=None, color='skyblue', cut=0)
sns.stripplot(y=relative_error, color='black', alpha=0.05, jitter=0.3, size=2)

plt.axhline(0, color='red', linestyle='--', linewidth=1.2)
plt.title('Distribution of Relative Error (%)')
plt.ylabel('Relative Error (%)')
plt.grid()
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# ── Sort by ground-truth values (ascending) ───────────────────────────────
sorted_idx       = np.argsort(y_test_rescaled)         # indices that sort y_test
y_test_sorted    = y_test_rescaled[sorted_idx]
y_pred_sorted    = y_pred_rescaled[sorted_idx]

# ── Plot both curves with matching order ──────────────────────────────────
plt.figure(figsize=(16, 8))
plt.plot(y_test_sorted, 'r-o',  label='Ground Truth (HHB2)', linewidth=2, markersize=5)
plt.plot(y_pred_sorted, 'b--o', label='Predicted (HHB2)',   linewidth=2, markersize=5)
plt.xlabel('Sample (sorted by ground-truth HHB2)')
plt.ylabel('HHB2')
plt.title('Predictions vs Ground Truth (sorted by HHB2)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(relative_error, kde=True, bins=1000, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Histogram + KDE of Relative Error (%)")
plt.xlabel("Relative Error (%)")
plt.ylabel("Frequency")
plt.grid()
plt.xlim(-100, 100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

# Subplot 1: Ground truth
plt.subplot(1, 2, 1)
sns.histplot(np.asarray(y_test_orig).ravel(), kde=True, bins=100, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Ground Truth (Y_test) Distribution")
plt.xlabel("Y_test")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

# Subplot 2: Prediction
plt.subplot(1, 2, 2)
sns.histplot( np.asarray(y_pred_orig).ravel(), kde=True, bins=100, color='darkorange', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Prediction (Y_pred) Distribution")
plt.xlabel("Y_pred")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# Ensure y_true and y_pred are 1D numpy arrays
y_true = np.asarray(y_test_orig).ravel()
y_pred =np.asarray(y_pred_orig).ravel()

# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# Plot
plt.figure(figsize=(10, 10))
plt.hist2d(y_true, y_pred, bins=100, cmap='Blues', cmin=1)

# Plot identity line
plt.plot([min(y_true), max(y_true)],
         [min(y_true), max(y_true)],
         'k--', lw=1)

# Labels and title
plt.xlabel('Expected $HHB2$')
plt.ylabel('Predicted $HHB2$')
plt.title(r'$S$')

# Annotate RMSE
plt.text(0.05, 0.95, f'RMSE: {rmse:.2e}', color='darkred',
         fontsize=14, transform=plt.gca().transAxes, va='top')

plt.colorbar(label='Density')
plt.tight_layout()
plt.show()

# %%
# Small epsilon to avoid division by zero
eps = 1e-8

# Relative error (%)
relative_error = (y_pred - y_true) / (y_true + eps) * 100
absolute_relative_error = np.abs(relative_error)

# Compute metrics
mre = np.mean(relative_error)
mape = np.mean(absolute_relative_error)

# Print
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 9.3416%

# %%
lower, upper = np.percentile(relative_error, [16, 84])
print(f"68% CI of HHb₂ % error: {lower:.2f}% to {upper:.2f}%")
# Out:
# 68% CI of HHb₂ % error: -11.06% to 11.68%
