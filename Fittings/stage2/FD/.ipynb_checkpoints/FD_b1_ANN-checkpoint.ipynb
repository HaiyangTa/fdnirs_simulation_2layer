# %% [markdown]
# ## FD b1 ANN Fitting

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Mounted at /content/drive

# %%
target = 'b1'

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
import pickle
from tqdm import tqdm
! pip install pmcx
from concurrent.futures import ThreadPoolExecutor
from sklearn.preprocessing import StandardScaler
# Out:
# Collecting pmcx
#   Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 41.8 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.4.2

# %% [markdown]
# ### Read the saved CSV

# %%
import pandas as pd
import glob
import numpy as np
import sys
! pip install pmcx
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pickle
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_path = '/content/drive/MyDrive/MCX_data/stage2_train.csv'
final_array = np.loadtxt(csv_path, delimiter=',')
print(final_array.shape)
X_train = final_array
#
csv_path_test = '/content/drive/MyDrive/MCX_data/stage2_test.csv'
final_array = np.loadtxt(csv_path_test, delimiter=',')
print(final_array.shape)
X_test = final_array
# Out:
# (10000, 192)
# (1000, 192)

# %% [markdown]
# ### GT

# %%
GT_folder_train = '/content/drive/MyDrive/MCX_data/stage2_csv/'
GT_folder_test = '/content/drive/MyDrive/MCX_data/test_csv/'

# %%
csv_files_train = glob.glob(os.path.join(GT_folder_train, '*.csv'))
GT_all_train = pd.concat([pd.read_csv(f) for f in csv_files_train], ignore_index=True)
csv_files_test = glob.glob(os.path.join(GT_folder_test, '*.csv'))
GT_all_test = pd.concat([pd.read_csv(f) for f in csv_files_test], ignore_index=True)

# %%
sorted_ids = [i+1 for i in range(10000)]
GT_all_train['ID'] = GT_all_train['ID'].astype(int)

GT_filtered = GT_all_train[GT_all_train['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()

Y = GT_filtered[target].values
y_train = Y.reshape(-1, 1)

# %%
sorted_ids = [i+1 for i in range(1000)]
GT_all_test['ID'] = GT_all_test['ID'].astype(int)

GT_filtered = GT_all_test[GT_all_test['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()

Y = GT_filtered[target].values
y_test = Y.reshape(-1, 1)

# %%
scaler_X = StandardScaler().fit(X_train)
scaler_y = StandardScaler().fit(y_train)

X_train = scaler_X.transform(X_train)
X_test  = scaler_X.transform(X_test)
Y_train = scaler_y.transform(y_train)
Y_test = scaler_y.transform(y_test)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (10000, 192) (1000, 192) (10000, 1) (1000, 1)

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.losses import Huber
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from pathlib import Path
import joblib, tensorflow as tf
WEIGHT_DIR = Path("/content/drive/MyDrive/MCX_data/weights")

model = Sequential([
    Input(shape=(192,)),
    Dense(1000, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(8192*2, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(2048, activation='relu'),
    Dropout(0.2),

    Dense(1024, activation='relu'),
    Dropout(0.2),

    Dense(512, activation='relu'),
    Dropout(0.1),

    Dense(256, activation='relu'),
    Dropout(0.1),

    Dense(64, activation='relu'),
    Dropout(0.1),

    Dense(32, activation='relu'),
    Dropout(0.0),

    Dense(1)
])



checkpoint_cb = ModelCheckpoint(
    f"FD_{target}_ANN.keras",        # filepath to save to
    monitor="val_loss",     # quantity to monitor
    mode="min",             # we want to minimize val_loss
    save_best_only=True,    # only save when val_loss decreases
    save_weights_only=False # set True if you only want weights
)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer, loss="mse")

history = model.fit(
    X_train, Y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    callbacks=[checkpoint_cb]
)

# 4) Later on (or in a new script), load the best model:
model = tf.keras.models.load_model(f"FD_{target}_ANN.keras")
# Out:
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 66s 196ms/step - loss: 0.6044 - val_loss: 0.0595
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1221 - val_loss: 0.0963
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0889 - val_loss: 0.0842
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0671 - val_loss: 0.0625
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.0574 - val_loss: 0.0417
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.0502 - val_loss: 0.0301
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0541 - val_loss: 0.0373
# Epoch 8/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0400 - val_loss: 0.0780
# Epoch 9/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0435 - val_loss: 0.0724
# Epoch 10/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0382 - val_loss: 0.0490
# Epoch 11/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0375 - val_loss: 0.0674
# Epoch 12/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0338 - val_loss: 0.0564
# Epoch 13/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0317 - val_loss: 0.0678
# Epoch 14/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0317 - val_loss: 0.0517
# Epoch 15/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0308 - val_loss: 0.0450
# Epoch 16/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0311 - val_loss: 0.0441
# Epoch 17/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0290 - val_loss: 0.0954
# Epoch 18/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0312 - val_loss: 0.0665
# Epoch 19/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0257 - val_loss: 0.0458
# Epoch 20/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0249 - val_loss: 0.0576
# Epoch 21/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0265 - val_loss: 0.0428
# Epoch 22/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0256 - val_loss: 0.0815
# Epoch 23/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0232 - val_loss: 0.0431
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0225 - val_loss: 0.0351
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0249 - val_loss: 0.0485
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0235 - val_loss: 0.0604
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0220 - val_loss: 0.0570
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0229 - val_loss: 0.0495
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0233 - val_loss: 0.1016
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0253 - val_loss: 0.0682
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0208 - val_loss: 0.0450
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0191 - val_loss: 0.0916
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0211 - val_loss: 0.0616
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0188 - val_loss: 0.0570
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0195 - val_loss: 0.0534
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0200 - val_loss: 0.0412
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0191 - val_loss: 0.0434
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0180 - val_loss: 0.0384
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0182 - val_loss: 0.0542
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0171 - val_loss: 0.0346
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0196 - val_loss: 0.0392
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0166 - val_loss: 0.0419
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0188 - val_loss: 0.0432
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0190 - val_loss: 0.0486
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0165 - val_loss: 0.0413
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0180 - val_loss: 0.0337
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0154 - val_loss: 0.0304
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0154 - val_loss: 0.0484
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0150 - val_loss: 0.0329
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0156 - val_loss: 0.0399
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0166 - val_loss: 0.0436
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0160 - val_loss: 0.0687
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0178 - val_loss: 0.0466
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0132 - val_loss: 0.0532
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0152 - val_loss: 0.0402
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0143 - val_loss: 0.0382
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0133 - val_loss: 0.0425
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.0136 - val_loss: 0.0298
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0149 - val_loss: 0.0388
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0134 - val_loss: 0.0330
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.0148 - val_loss: 0.0280
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0137 - val_loss: 0.0283
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0131 - val_loss: 0.0389
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0124 - val_loss: 0.0366
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 87ms/step - loss: 0.0142 - val_loss: 0.0278
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0124 - val_loss: 0.0328
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0118 - val_loss: 0.0345
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0129 - val_loss: 0.0313
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0126 - val_loss: 0.0380
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0129 - val_loss: 0.0372
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0116 - val_loss: 0.0330
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0126 - val_loss: 0.0355
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0126 - val_loss: 0.0427
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0120 - val_loss: 0.0270
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0121 - val_loss: 0.0373
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0110 - val_loss: 0.0279
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0131 - val_loss: 0.0338
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0119 - val_loss: 0.0243
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0108 - val_loss: 0.0342
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0162 - val_loss: 0.0319
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0138 - val_loss: 0.0288
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0127 - val_loss: 0.0275
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.0121 - val_loss: 0.0227
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0121 - val_loss: 0.0199
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0115 - val_loss: 0.0329
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0106 - val_loss: 0.0337
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0105 - val_loss: 0.0173
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0127 - val_loss: 0.0202
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0098 - val_loss: 0.0235
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0104 - val_loss: 0.0271
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0113 - val_loss: 0.0297
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0109 - val_loss: 0.0215
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0108 - val_loss: 0.0243
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0109 - val_loss: 0.0263
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0098 - val_loss: 0.0221
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0097 - val_loss: 0.0242
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0100 - val_loss: 0.0212
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0105 - val_loss: 0.0226
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0124 - val_loss: 0.0261
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0101 - val_loss: 0.0289
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0092 - val_loss: 0.0201
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0093 - val_loss: 0.0268
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0096 - val_loss: 0.0239
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0094 - val_loss: 0.0206
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0094 - val_loss: 0.0397
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0102 - val_loss: 0.0287
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0089 - val_loss: 0.0251
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0098 - val_loss: 0.0271
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0085 - val_loss: 0.0225
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0088 - val_loss: 0.0456
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0104 - val_loss: 0.0280
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0090 - val_loss: 0.0236
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0101 - val_loss: 0.0284
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0089 - val_loss: 0.0222
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0094 - val_loss: 0.0292
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.0093 - val_loss: 0.0167
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0085 - val_loss: 0.0337
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0085 - val_loss: 0.0195
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0091 - val_loss: 0.0229
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0090 - val_loss: 0.0217
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0083 - val_loss: 0.0224
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0097 - val_loss: 0.0210
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0085 - val_loss: 0.0243
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0091 - val_loss: 0.0173
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0083 - val_loss: 0.0284
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0092 - val_loss: 0.0193
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0079 - val_loss: 0.0158
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0079 - val_loss: 0.0208
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0079 - val_loss: 0.0198
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0099 - val_loss: 0.0217
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0078 - val_loss: 0.0181
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0083 - val_loss: 0.0217
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0076 - val_loss: 0.0264
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0089 - val_loss: 0.0189
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0082 - val_loss: 0.0278
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0073 - val_loss: 0.0274
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0077 - val_loss: 0.0232
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0081 - val_loss: 0.0223
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0081 - val_loss: 0.0225
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0077 - val_loss: 0.0233
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0079 - val_loss: 0.0199
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0068 - val_loss: 0.0253
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0074 - val_loss: 0.0256
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0201
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0090 - val_loss: 0.0290
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0090 - val_loss: 0.0241
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0074 - val_loss: 0.0242
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0076 - val_loss: 0.0213
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0073 - val_loss: 0.0315
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0090 - val_loss: 0.0199
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0074 - val_loss: 0.0215
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0082 - val_loss: 0.0196
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0072 - val_loss: 0.0245
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0271
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0079 - val_loss: 0.0263
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0068 - val_loss: 0.0238
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0067 - val_loss: 0.0257
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0083 - val_loss: 0.0228
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0065 - val_loss: 0.0186
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0063 - val_loss: 0.0211
# Epoch 161/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0237
# Epoch 162/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0070 - val_loss: 0.0222
# Epoch 163/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0064 - val_loss: 0.0174
# Epoch 164/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0068 - val_loss: 0.0312
# Epoch 165/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0077 - val_loss: 0.0196
# Epoch 166/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0068 - val_loss: 0.0292
# Epoch 167/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0080 - val_loss: 0.0228
# Epoch 168/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0078 - val_loss: 0.0185
# Epoch 169/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0061 - val_loss: 0.0172
# Epoch 170/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0066 - val_loss: 0.0194
# Epoch 171/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0072 - val_loss: 0.0259
# Epoch 172/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0076 - val_loss: 0.0252
# Epoch 173/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0071 - val_loss: 0.0188
# Epoch 174/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0079 - val_loss: 0.0206
# Epoch 175/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0061 - val_loss: 0.0142
# Epoch 176/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0070 - val_loss: 0.0187
# Epoch 177/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0086 - val_loss: 0.0227
# Epoch 178/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0076 - val_loss: 0.0209
# Epoch 179/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0067 - val_loss: 0.0208
# Epoch 180/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0065 - val_loss: 0.0193
# Epoch 181/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0062 - val_loss: 0.0164
# Epoch 182/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0069 - val_loss: 0.0147
# Epoch 183/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0062 - val_loss: 0.0683
# Epoch 184/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0177 - val_loss: 0.0199
# Epoch 185/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0087 - val_loss: 0.0218
# Epoch 186/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0134 - val_loss: 0.0223
# Epoch 187/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0107 - val_loss: 0.0199
# Epoch 188/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0082 - val_loss: 0.0214
# Epoch 189/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0081 - val_loss: 0.0233
# Epoch 190/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0074 - val_loss: 0.0193
# Epoch 191/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0068 - val_loss: 0.0186
# Epoch 192/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0071 - val_loss: 0.0174
# Epoch 193/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0063 - val_loss: 0.0177
# Epoch 194/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0081 - val_loss: 0.0191
# Epoch 195/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0067 - val_loss: 0.0168
# Epoch 196/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0065 - val_loss: 0.0187
# Epoch 197/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0065 - val_loss: 0.0178
# Epoch 198/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0065 - val_loss: 0.0193
# Epoch 199/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0065 - val_loss: 0.0238
# Epoch 200/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0060 - val_loss: 0.0188

# %%
WEIGHT_DIR = Path("/content/drive/MyDrive/MCX_data/weights")
WEIGHT_DIR.mkdir(parents=True, exist_ok=True)

model_path = WEIGHT_DIR / f"FD_{target}_ANN.keras"
model.save(model_path)

joblib.dump(scaler_X, WEIGHT_DIR / f"X_FD_{target}_ANN.pkl")
joblib.dump(scaler_y, WEIGHT_DIR / f"Y_FD_{target}_ANN.pkl")

print("model file exists:", model_path.exists(),
      "size =", model_path.stat().st_size/1e6, "MB")
# Out:
# model file exists: True size = 4413.937482 MB

# %%
y_pred = model.predict(X_test)
y_pred = np.clip(y_pred, scaler_y.transform(np.array([[0.1]]))[0][0], scaler_y.transform(np.array([[2.5]]))[0][0])
mse = mean_squared_error(Y_test, y_pred)
print(f"Test MSE: {mse:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test MSE: 0.0118

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │       193,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │     4,100,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8192)           │    33,562,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16384)          │   134,234,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8192)           │   134,225,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4096)           │    33,558,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2048)           │     8,390,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,103,457,341 (4.11 GB)
#  Trainable params: 367,819,113 (1.37 GB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 735,638,228 (2.74 GB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
indices = np.random.choice(len(Y_test), size=100, replace=False)
indices = np.sort(indices)

y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
y_test_rescaled = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
print(f"Test MSE: {mse:.4f}")


# Extract corresponding values
y_test_sampled = y_test_rescaled[indices]
y_pred_sampled = y_pred_rescaled[indices]

# Plot with circular markers
plt.figure(figsize=(16, 8))
plt.plot(y_test_sampled, 'r-o', label=f'Ground Truth ({target})', linewidth=2, markersize=5)
plt.plot(y_pred_sampled, 'b--o', label=f'Predicted ({target})', linewidth=2, markersize=5)
plt.xlabel('Random Sample Index')
plt.ylabel('HHB2')
plt.title('Randomly Sampled Predictions vs Ground Truth')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE: 0.0056

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = np.asarray(y_pred_rescaled).ravel()
y_true = np.asarray(y_test_rescaled).ravel()

# residuals
residuals = y_pred - y_true
mae = mean_absolute_error(y_true, y_pred)
mare = np.mean(np.abs(residuals) / np.abs(y_true)) * 100
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)
bias = np.mean(residuals)
sd   = np.std(residuals, ddof=1)   
print(f"MAE (μm):          {mae:.4f}")
print(f"MARE (%):          {mare:.4f}")
print(f"RMSE (μm):         {rmse:.4f}")
print(f"R²:                {r2:.4f}")
print(f"Bias ± SD (μm):    {bias:.4f} ± {sd:.4f}")
# Out:
# MAE (μm):          0.0583
# MARE (%):          11.3974
# RMSE (μm):         0.0751
# R²:                0.9882
# Bias ± SD (μm):    0.0103 ± 0.0745

# %%
residuals = y_pred_rescaled - y_test_rescaled
mse_rescaled = mean_squared_error(y_pred_rescaled, y_test_rescaled)
print(f"Test MSE (original scale): {mse_rescaled:.4f}")
plt.figure(figsize=(16, 8))
plt.scatter(range(len(residuals)), residuals, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.title("Residuals (Predicted - Ground Truth)")
plt.ylabel("Residual")
plt.ylim(-10, 10)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE (original scale): 0.0056

# %%
relative_error = ((y_pred_rescaled - y_test_rescaled) / y_test_rescaled) * 100
plt.figure(figsize=(16, 8))
plt.scatter(range(len(relative_error)), relative_error, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.ylabel("Relative Error (%)")
plt.ylim(-100, 100)
plt.yticks(np.arange(-100, 101, 10))
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd

df_plot = pd.DataFrame({
    'Relative Error (%)': relative_error.flatten()
})

plt.figure(figsize=(10, 10))
sns.violinplot(data=df_plot, y='Relative Error (%)', inner=None, linewidth=1.2)
sns.stripplot(data=df_plot, y='Relative Error (%)', color='black', alpha=0.4, jitter=0.2, size=3)

plt.axhline(0, color='r', linestyle='--', linewidth=1)
plt.ylim(-100, 100)
plt.title('Distribution of Relative Error (%)')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score, mean_absolute_percentage_error
plt.figure(figsize=(10,10))
plt.scatter(y_test_rescaled, y_pred_rescaled, alpha=0.6)
lims = [min(y_test_rescaled.min(), y_pred_rescaled.min()),
        max(y_test_rescaled.max(), y_pred_rescaled.max())]
plt.plot(lims, lims, 'k--')              # identity line
plt.xlabel(f'Ground-truth {target}'); plt.ylabel(f'Predicted {target}')
plt.axis('square'); plt.xlim(lims); plt.ylim(lims)
plt.grid()
print("R² =", r2_score(y_test_rescaled, y_pred_rescaled))
print("MAPE =", mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)*100, "%")
plt.show()
# Out:
# R² = 0.9882374817676473
# MAPE = 11.397414172686782 %

# %%
relative_error = relative_error.squeeze()

plt.figure(figsize=(10, 6))
sns.boxplot(y=relative_error, color='lightgray', width=0.3)
sns.stripplot(y=relative_error, color='black', alpha=0.03, jitter=0.4, size=1.5)

plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.title('Relative Error Distribution (%)')
plt.ylabel('Relative Error (%)')
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(10, 6))
sns.violinplot(y=relative_error, inner=None, color='skyblue', cut=0)
sns.stripplot(y=relative_error, color='black', alpha=0.05, jitter=0.3, size=2)

plt.axhline(0, color='red', linestyle='--', linewidth=1.2)
plt.title('Distribution of Relative Error (%)')
plt.ylabel('Relative Error (%)')
plt.grid()
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

sorted_idx       = np.argsort(y_test_rescaled)         # indices that sort y_test
y_test_sorted    = y_test_rescaled[sorted_idx]
y_pred_sorted    = y_pred_rescaled[sorted_idx]

plt.figure(figsize=(16, 8))
plt.plot(y_test_sorted, 'r-o',  label=f'Ground Truth {target}', linewidth=2, markersize=5)
plt.plot(y_pred_sorted, 'b--o', label=f'Predicted {target}',   linewidth=2, markersize=5)
plt.xlabel(f'Sample (sorted by ground-truth {target})')
plt.ylabel(f'{target}')
plt.title(f'Predictions vs Ground Truth (sorted by {target})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(relative_error, kde=True, bins=1000, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Histogram + KDE of Relative Error (%)")
plt.xlabel("Relative Error (%)")
plt.ylabel("Frequency")
plt.grid()
plt.xlim(-100, 100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

# Subplot 1: Ground truth
plt.subplot(1, 2, 1)
sns.histplot(np.asarray(y_test_rescaled).ravel(), kde=True, bins=100, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Ground Truth (Y_test) Distribution")
plt.xlabel("Y_test")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

# Subplot 2: Prediction
plt.subplot(1, 2, 2)
sns.histplot( np.asarray(y_pred_rescaled).ravel(), kde=True, bins=100, color='darkorange', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Prediction (Y_pred) Distribution")
plt.xlabel("Y_pred")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# Ensure y_true and y_pred are 1D numpy arrays
y_true = np.asarray(y_test_rescaled).ravel()
y_pred =np.asarray(y_pred_rescaled).ravel()

# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# Plot
plt.figure(figsize=(10, 10))
plt.hist2d(y_true, y_pred, bins=100, cmap='Blues', cmin=1)

# Plot identity line
plt.plot([min(y_true), max(y_true)],
         [min(y_true), max(y_true)],
         'k--', lw=1)

# Labels and title
plt.xlabel(f'Expected ${target}$')
plt.ylabel(f'Predicted ${target}$')
plt.title(r'$S$')

# Annotate RMSE
plt.text(0.05, 0.95, f'RMSE: {rmse:.2e}', color='darkred',
         fontsize=14, transform=plt.gca().transAxes, va='top')

plt.colorbar(label='Density')
plt.tight_layout()
plt.show()

# %%
# Small epsilon to avoid division by zero
eps = 1e-8

# Relative error (%)
relative_error = (y_pred - y_true) / (y_true + eps) * 100
absolute_relative_error = np.abs(relative_error)

# Compute metrics
mre = np.mean(relative_error)
mape = np.mean(absolute_relative_error)

# Print
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 11.3974%

# %%
lower, upper = np.percentile(relative_error, [16, 84])
print(f"68% CI of HHb₂ % error: {lower:.2f}% to {upper:.2f}%")
# Out:
# 68% CI of HHb₂ % error: -2.94% to 16.08%
