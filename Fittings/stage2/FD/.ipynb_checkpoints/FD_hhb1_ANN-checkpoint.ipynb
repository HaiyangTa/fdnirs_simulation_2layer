# %% [markdown]
# ## FD_abs[hbo2] ANN Fitting

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
import pickle
from tqdm import tqdm
! pip install pmcx
from concurrent.futures import ThreadPoolExecutor
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)

# %% [markdown]
# ### Read the saved CSV

# %%
import pandas as pd
import glob
import numpy as np
import sys
! pip install pmcx
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pickle
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_path = '/content/drive/MyDrive/MCX_data/stage2_train.csv'
final_array = np.loadtxt(csv_path, delimiter=',')
print(final_array.shape)
X_train = final_array
#
csv_path_test = '/content/drive/MyDrive/MCX_data/stage2_test.csv'
final_array = np.loadtxt(csv_path_test, delimiter=',')
print(final_array.shape)
X_test = final_array
# Out:
# (10000, 192)
# (1000, 192)

# %% [markdown]
# ### GT

# %%
GT_folder_train = '/content/drive/MyDrive/MCX_data/stage2_csv/'
GT_folder_test = '/content/drive/MyDrive/MCX_data/test_csv/'

# %%
csv_files_train = glob.glob(os.path.join(GT_folder_train, '*.csv'))
GT_all_train = pd.concat([pd.read_csv(f) for f in csv_files_train], ignore_index=True)
csv_files_test = glob.glob(os.path.join(GT_folder_test, '*.csv'))
GT_all_test = pd.concat([pd.read_csv(f) for f in csv_files_test], ignore_index=True)

# %%
sorted_ids = [i+1 for i in range(10000)]
GT_all_train['ID'] = GT_all_train['ID'].astype(int)
GT_filtered = GT_all_train[GT_all_train['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()
Y = GT_filtered['HHB1'].values
y_train = Y.reshape(-1, 1)

# %%
sorted_ids = [i+1 for i in range(1000)]
GT_all_test['ID'] = GT_all_test['ID'].astype(int)
GT_filtered = GT_all_test[GT_all_test['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()
Y = GT_filtered['HHB1'].values
y_test = Y.reshape(-1, 1)

# %%
scaler_X = StandardScaler().fit(X_train)
scaler_y = StandardScaler().fit(y_train)
X_train = scaler_X.transform(X_train)
X_test  = scaler_X.transform(X_test)
Y_train = scaler_y.transform(y_train)
Y_test = scaler_y.transform(y_test)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (10000, 192) (1000, 192) (10000, 1) (1000, 1)

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.losses import Huber
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from pathlib import Path
import joblib, tensorflow as tf
WEIGHT_DIR = Path("/content/drive/MyDrive/MCX_data/weights")

model = Sequential([
    Input(shape=(192,)),
    Dense(1000, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(8192*2, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(2048, activation='relu'),
    Dropout(0.2),

    Dense(1024, activation='relu'),
    Dropout(0.2),

    Dense(512, activation='relu'),
    Dropout(0.1),

    Dense(256, activation='relu'),
    Dropout(0.1),

    Dense(64, activation='relu'),
    Dropout(0.1),

    Dense(32, activation='relu'),
    Dropout(0.0),

    Dense(1) 
])

checkpoint_cb = ModelCheckpoint(
    "FD_hhb1_ANN.keras",        # filepath to save to
    monitor="val_loss",     # quantity to monitor
    mode="min",             # we want to minimize val_loss
    save_best_only=True,    # only save when val_loss decreases
    save_weights_only=False # set True if you only want weights
)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer, loss="mse")

history = model.fit(
    X_train, Y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    callbacks=[checkpoint_cb]
)

model = tf.keras.models.load_model("FD_hhb1_ANN.keras")
# Out:
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 66s 198ms/step - loss: 0.9852 - val_loss: 0.6424
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.5233 - val_loss: 0.3502
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4059 - val_loss: 0.3746
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3318 - val_loss: 0.3504
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 27s 98ms/step - loss: 0.3188 - val_loss: 0.3029
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.2867 - val_loss: 0.2463
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.2602 - val_loss: 0.2336
# Epoch 8/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.2572 - val_loss: 0.2053
# Epoch 9/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.2434 - val_loss: 0.2226
# Epoch 10/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2285 - val_loss: 0.2207
# Epoch 11/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1906 - val_loss: 0.2312
# Epoch 12/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 29s 103ms/step - loss: 0.1979 - val_loss: 0.1842
# Epoch 13/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1862 - val_loss: 0.1867
# Epoch 14/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.1644 - val_loss: 0.2362
# Epoch 15/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.1727 - val_loss: 0.1552
# Epoch 16/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.1642 - val_loss: 0.1779
# Epoch 17/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1670 - val_loss: 0.1987
# Epoch 18/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.1530 - val_loss: 0.1352
# Epoch 19/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.1452 - val_loss: 0.1289
# Epoch 20/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1359 - val_loss: 0.1300
# Epoch 21/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1239 - val_loss: 0.1537
# Epoch 22/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1245 - val_loss: 0.1449
# Epoch 23/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1257 - val_loss: 0.1914
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - loss: 0.1294 - val_loss: 0.1138
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1146 - val_loss: 0.1374
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1217 - val_loss: 0.1179
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1195 - val_loss: 0.1359
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1129 - val_loss: 0.1391
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1115 - val_loss: 0.1240
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.1038 - val_loss: 0.1062
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.1101 - val_loss: 0.1926
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1110 - val_loss: 0.1371
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1125 - val_loss: 0.1316
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0956 - val_loss: 0.1214
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1115 - val_loss: 0.1133
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1115 - val_loss: 0.1164
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0975 - val_loss: 0.1086
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.0896 - val_loss: 0.1001
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.1023 - val_loss: 0.1398
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1114 - val_loss: 0.1065
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1011 - val_loss: 0.1239
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0973 - val_loss: 0.1382
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.0885 - val_loss: 0.0928
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0968 - val_loss: 0.1167
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0967 - val_loss: 0.1178
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0969 - val_loss: 0.1211
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0939 - val_loss: 0.1508
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0878 - val_loss: 0.0859
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0857 - val_loss: 0.0926
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.0945 - val_loss: 0.0819
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0791 - val_loss: 0.1760
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0835 - val_loss: 0.1102
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0843 - val_loss: 0.0982
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0730 - val_loss: 0.0970
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0821 - val_loss: 0.1098
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0881 - val_loss: 0.0912
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0751 - val_loss: 0.1080
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0795 - val_loss: 0.1052
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0835 - val_loss: 0.1356
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0913 - val_loss: 0.1188
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0844 - val_loss: 0.1149
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0785 - val_loss: 0.1216
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0850 - val_loss: 0.1351
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0943 - val_loss: 0.1019
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0815 - val_loss: 0.0942
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0754 - val_loss: 0.1148
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0734 - val_loss: 0.0964
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0696 - val_loss: 0.1043
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0801 - val_loss: 0.0769
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0715 - val_loss: 0.1088
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0706 - val_loss: 0.0963
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0704 - val_loss: 0.0698
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0729 - val_loss: 0.1030
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0796 - val_loss: 0.0826
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0707 - val_loss: 0.1207
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0700 - val_loss: 0.0985
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0711 - val_loss: 0.0858
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0650 - val_loss: 0.1256
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0760 - val_loss: 0.0865
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0656 - val_loss: 0.1069
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0740 - val_loss: 0.0794
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0663 - val_loss: 0.0884
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0757 - val_loss: 0.0847
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0685 - val_loss: 0.1523
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0833 - val_loss: 0.0784
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0761 - val_loss: 0.0843
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0669 - val_loss: 0.0926
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0598 - val_loss: 0.0865
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0739 - val_loss: 0.0931
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0684 - val_loss: 0.0835
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0685 - val_loss: 0.0921
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0707 - val_loss: 0.0973
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0717 - val_loss: 0.0713
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0620 - val_loss: 0.1145
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0785 - val_loss: 0.0883
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0624 - val_loss: 0.0946
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0686 - val_loss: 0.0878
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0686 - val_loss: 0.0957
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.0645 - val_loss: 0.0643
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0652 - val_loss: 0.0786
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0618 - val_loss: 0.0713
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0653 - val_loss: 0.0833
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0570 - val_loss: 0.0698
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0693 - val_loss: 0.0749
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0664 - val_loss: 0.0788
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0594 - val_loss: 0.0813
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0609 - val_loss: 0.0813
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0530 - val_loss: 0.0847
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0627 - val_loss: 0.0741
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0655 - val_loss: 0.1280
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0690 - val_loss: 0.0885
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0575 - val_loss: 0.1031
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0693 - val_loss: 0.0669
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0565 - val_loss: 0.1177
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0605 - val_loss: 0.0697
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0609 - val_loss: 0.0898
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0546 - val_loss: 0.0843
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0533 - val_loss: 0.0748
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0641 - val_loss: 0.0668
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0557 - val_loss: 0.0783
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0613 - val_loss: 0.0849
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0721 - val_loss: 0.1124
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0690 - val_loss: 0.0787
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0493 - val_loss: 0.0764
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0560 - val_loss: 0.0765
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0549 - val_loss: 0.0734
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0526 - val_loss: 0.0694
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0539 - val_loss: 0.0820
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0595 - val_loss: 0.0942
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0630 - val_loss: 0.0697
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0566 - val_loss: 0.0750
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.0562 - val_loss: 0.0593
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0468 - val_loss: 0.0873
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0779 - val_loss: 0.0650
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0626 - val_loss: 0.0854
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0710 - val_loss: 0.0866
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0472 - val_loss: 0.0772
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0533 - val_loss: 0.0760
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0476 - val_loss: 0.0691
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0615 - val_loss: 0.1070
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0572 - val_loss: 0.0777
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.0714 - val_loss: 0.0579
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0461 - val_loss: 0.0627
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0451 - val_loss: 0.0747
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0481 - val_loss: 0.0827
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0441 - val_loss: 0.0995
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0614 - val_loss: 0.0636
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1202 - val_loss: 0.0812
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.0623 - val_loss: 0.0873
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0633 - val_loss: 0.0679
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0579 - val_loss: 0.1351
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0676 - val_loss: 0.0621
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0478 - val_loss: 0.0743
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0512 - val_loss: 0.0669
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0459 - val_loss: 0.0610
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0479 - val_loss: 0.0770
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1036 - val_loss: 0.0893
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0642 - val_loss: 0.0644
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0514 - val_loss: 0.0769
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0486 - val_loss: 0.0661
# Epoch 161/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0606 - val_loss: 0.1402
# Epoch 162/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0765 - val_loss: 0.0896
# Epoch 163/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0567 - val_loss: 0.0859
# Epoch 164/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0480 - val_loss: 0.0699
# Epoch 165/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0474 - val_loss: 0.0736
# Epoch 166/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0463 - val_loss: 0.0636
# Epoch 167/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0442 - val_loss: 0.0861
# Epoch 168/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0537 - val_loss: 0.0911
# Epoch 169/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0476 - val_loss: 0.0708
# Epoch 170/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0530 - val_loss: 0.0715
# Epoch 171/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0490 - val_loss: 0.0820
# Epoch 172/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0532 - val_loss: 0.0761
# Epoch 173/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.0537 - val_loss: 0.0564
# Epoch 174/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0440 - val_loss: 0.0604
# Epoch 175/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0560 - val_loss: 0.0848
# Epoch 176/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0458 - val_loss: 0.0614
# Epoch 177/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0448 - val_loss: 0.0658
# Epoch 178/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0608 - val_loss: 0.0800
# Epoch 179/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0538 - val_loss: 0.0627
# Epoch 180/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0486 - val_loss: 0.0783
# Epoch 181/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0446 - val_loss: 0.1534
# Epoch 182/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0621 - val_loss: 0.0967
# Epoch 183/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0517 - val_loss: 0.0701
# Epoch 184/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0441 - val_loss: 0.0795
# Epoch 185/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0675 - val_loss: 0.0644
# Epoch 186/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0469 - val_loss: 0.0897
# Epoch 187/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0462 - val_loss: 0.0667
# Epoch 188/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0472 - val_loss: 0.0739
# Epoch 189/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0607 - val_loss: 0.0737
# Epoch 190/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0461 - val_loss: 0.0642
# Epoch 191/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0489 - val_loss: 0.0749
# Epoch 192/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0460 - val_loss: 0.0808
# Epoch 193/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0504 - val_loss: 0.0730
# Epoch 194/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0631 - val_loss: 0.1146
# Epoch 195/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0854 - val_loss: 0.1010
# Epoch 196/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0701 - val_loss: 0.0928
# Epoch 197/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0535 - val_loss: 0.0854
# Epoch 198/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0602 - val_loss: 0.0746
# Epoch 199/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0499 - val_loss: 0.0695
# Epoch 200/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0492 - val_loss: 0.0707

# %%
WEIGHT_DIR = Path("/content/drive/MyDrive/MCX_data/weights")
WEIGHT_DIR.mkdir(parents=True, exist_ok=True)
model_path = WEIGHT_DIR / "FD_hhb1_ANN.keras"
model.save(model_path)
joblib.dump(scaler_X, WEIGHT_DIR / "X_FD_hhb1_ANN.pkl")
joblib.dump(scaler_y, WEIGHT_DIR / "Y_FD_hhb1_ANN.pkl")
print("model file exists:", model_path.exists(),
      "size =", model_path.stat().st_size/1e6, "MB")
# Out:
# model file exists: True size = 4413.93751 MB

# %%
y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)
print(f"Test MSE: {mse:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step
# Test MSE: 0.0404

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                │ (None, 1000)           │       193,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 4096)           │     4,100,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 8192)           │    33,562,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 16384)          │   134,234,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 8192)           │   134,225,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 4096)           │    33,558,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 2048)           │     8,390,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_24 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_25 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,103,457,341 (4.11 GB)
#  Trainable params: 367,819,113 (1.37 GB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 735,638,228 (2.74 GB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
indices = np.random.choice(len(Y_test), size=100, replace=False)
indices = np.sort(indices)

y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
y_test_rescaled = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
print(f"Test MSE: {mse:.4f}")
y_test_sampled = y_test_rescaled[indices]
y_pred_sampled = y_pred_rescaled[indices]

plt.figure(figsize=(16, 8))
plt.plot(y_test_sampled, 'r-o', label='Ground Truth (HHB2)', linewidth=2, markersize=5)
plt.plot(y_pred_sampled, 'b--o', label='Predicted (HHB2)', linewidth=2, markersize=5)
plt.xlabel('Random Sample Index')
plt.ylabel('HHB2')
plt.title('Randomly Sampled Predictions vs Ground Truth')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE: 0.3367

# %%
y_pred_orig = scaler_y.inverse_transform(y_pred)    
y_test_orig = scaler_y.inverse_transform(Y_test)   
residuals = y_pred_orig - y_test_orig

mse_rescaled = mean_squared_error(y_test_orig, y_pred_orig)
print(f"Test MSE (original scale): {mse_rescaled:.4f}")

# Plot residuals
plt.figure(figsize=(16, 8))
plt.scatter(range(len(residuals)), residuals, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.title("Residuals (Predicted - Ground Truth)")
plt.ylabel("Residual")
plt.ylim(-10, 10)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE (original scale): 0.3367

# %%
y_pred_orig = scaler_y.inverse_transform(y_pred)       # shape (n, 1)
y_test_orig = scaler_y.inverse_transform(Y_test)     # shape (n, 1)
relative_error = ((y_pred_orig - y_test_orig) / y_test_orig) * 100
plt.figure(figsize=(16, 8))
plt.scatter(range(len(relative_error)), relative_error, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.ylabel("Relative Error (%)")
plt.ylim(-100, 100)
plt.yticks(np.arange(-100, 101, 10))
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
df_plot = pd.DataFrame({
    'Relative Error (%)': relative_error.flatten()
})

plt.figure(figsize=(10, 10))
sns.violinplot(data=df_plot, y='Relative Error (%)', inner=None, linewidth=1.2)
sns.stripplot(data=df_plot, y='Relative Error (%)', color='black', alpha=0.4, jitter=0.2, size=3)

plt.axhline(0, color='r', linestyle='--', linewidth=1)
plt.ylim(-100, 100)
plt.title('Distribution of Relative Error (%)')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score, mean_absolute_percentage_error
plt.figure(figsize=(10,10))
plt.scatter(y_test_rescaled, y_pred_rescaled, alpha=0.6)
lims = [min(y_test_rescaled.min(), y_pred_rescaled.min()),
        max(y_test_rescaled.max(), y_pred_rescaled.max())]
plt.plot(lims, lims, 'k--')              # identity line
plt.xlabel('Ground-truth Hb1'); plt.ylabel('Predicted Hb1')
plt.axis('square'); plt.xlim(lims); plt.ylim(lims)
plt.grid()
print("R² =", r2_score(y_test_rescaled, y_pred_rescaled))
print("MAPE =", mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)*100, "%")
plt.show()
# Out:
# R² = 0.9595999175262546
# MAPE = 7.604543621498319 %

# %%
relative_error = relative_error.squeeze()
plt.figure(figsize=(10, 6))
sns.boxplot(y=relative_error, color='lightgray', width=0.3)
sns.stripplot(y=relative_error, color='black', alpha=0.03, jitter=0.4, size=1.5)

plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.title('Relative Error Distribution (%)')
plt.ylabel('Relative Error (%)')
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.figure(figsize=(10, 6))
sns.violinplot(y=relative_error, inner=None, color='skyblue', cut=0)
sns.stripplot(y=relative_error, color='black', alpha=0.05, jitter=0.3, size=2)

plt.axhline(0, color='red', linestyle='--', linewidth=1.2)
plt.title('Distribution of Relative Error (%)')
plt.ylabel('Relative Error (%)')
plt.grid()
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

sorted_idx       = np.argsort(y_test_rescaled)         # indices that sort y_test
y_test_sorted    = y_test_rescaled[sorted_idx]
y_pred_sorted    = y_pred_rescaled[sorted_idx]

plt.figure(figsize=(16, 8))
plt.plot(y_test_sorted, 'r-o',  label='Ground Truth (Hb1)', linewidth=2, markersize=5)
plt.plot(y_pred_sorted, 'b--o', label='Predicted (Hb1)',   linewidth=2, markersize=5)
plt.xlabel('Sample (sorted by ground-truth Hb1)')
plt.ylabel('HHB2')
plt.title('Predictions vs Ground Truth (sorted by Hb1)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(relative_error, kde=True, bins=1000, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Histogram + KDE of Relative Error (%)")
plt.xlabel("Relative Error (%)")
plt.ylabel("Frequency")
plt.grid()
plt.xlim(-100, 100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(np.asarray(y_test_orig).ravel(), kde=True, bins=100, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Ground Truth (Y_test) Distribution")
plt.xlabel("Y_test")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

plt.subplot(1, 2, 2)
sns.histplot( np.asarray(y_pred_orig).ravel(), kde=True, bins=100, color='darkorange', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Prediction (Y_pred) Distribution")
plt.xlabel("Y_pred")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
y_true = np.asarray(y_test_orig).ravel()
y_pred =np.asarray(y_pred_orig).ravel()
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
plt.figure(figsize=(10, 10))
plt.hist2d(y_true, y_pred, bins=100, cmap='Blues', cmin=1)
plt.plot([min(y_true), max(y_true)],
         [min(y_true), max(y_true)],
         'k--', lw=1)
plt.xlabel('Expected $Hb1$')
plt.ylabel('Predicted $Hb1$')
plt.title(r'$S$')
plt.text(0.05, 0.95, f'RMSE: {rmse:.2e}', color='darkred',
         fontsize=14, transform=plt.gca().transAxes, va='top')
plt.colorbar(label='Density')
plt.tight_layout()
plt.show()

# %%
from matplotlib.colors import LogNorm
from mpl_toolkits.axes_grid1 import make_axes_locatable

x = y_test_rescaled.ravel()
y = y_pred_rescaled.ravel()
fig, ax = plt.subplots(figsize=(10, 10), dpi=300)
hb = ax.hexbin(
        x, y, gridsize=120,
        cmap="viridis",
        norm=LogNorm(vmin=1, vmax=1e4)
      )

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="4.5%", pad=0.05)  # width, gap
cb = fig.colorbar(hb, cax=cax)
cb.set_label("Pixel counts", rotation=270, labelpad=12)
lims = [min(x.min(), y.min()), max(x.max(), y.max())]
ax.plot(lims, lims, 'k--', linewidth=0.8)
ax.set_xlim(lims); ax.set_ylim(lims)
ax.set_aspect('equal', adjustable='box')
ax.set_xlabel(r"$Hb1_gt$")
ax.set_ylabel(r"$fHb1_pred$")
ax.grid(False)
fig.tight_layout()
plt.show()

# %%
eps = 1e-8
relative_error = (y_pred - y_true) / (y_true + eps) * 100
absolute_relative_error = np.abs(relative_error)
mre = np.mean(relative_error)
mape = np.mean(absolute_relative_error)
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 7.6045%

# %%
lower, upper = np.percentile(relative_error, [16, 84])
print(f"68% CI of HHb₂ % error: {lower:.2f}% to {upper:.2f}%")
# Out:
# 68% CI of HHb₂ % error: -5.83% to 10.85%
