# %% [markdown]
# ## FD a1 ANN Fitting

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Mounted at /content/drive

# %%
target = 'a1'

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
import pickle
from tqdm import tqdm
! pip install pmcx
from concurrent.futures import ThreadPoolExecutor
from sklearn.preprocessing import StandardScaler
# Out:
# Collecting pmcx
#   Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 41.6 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.4.2

# %% [markdown]
# ### Read the saved CSV

# %%
import pandas as pd
import glob
import numpy as np
import sys
! pip install pmcx
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pickle
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_path = '/content/drive/MyDrive/MCX_data/stage2_train.csv'
final_array = np.loadtxt(csv_path, delimiter=',')
print(final_array.shape)
X_train = final_array
#
csv_path_test = '/content/drive/MyDrive/MCX_data/stage2_test.csv'
final_array = np.loadtxt(csv_path_test, delimiter=',')
print(final_array.shape)
X_test = final_array
# Out:
# (10000, 192)
# (1000, 192)

# %% [markdown]
# ### GT

# %%
GT_folder_train = '/content/drive/MyDrive/MCX_data/stage2_csv/'
GT_folder_test = '/content/drive/MyDrive/MCX_data/test_csv/'

# %%
csv_files_train = glob.glob(os.path.join(GT_folder_train, '*.csv'))
GT_all_train = pd.concat([pd.read_csv(f) for f in csv_files_train], ignore_index=True)
csv_files_test = glob.glob(os.path.join(GT_folder_test, '*.csv'))
GT_all_test = pd.concat([pd.read_csv(f) for f in csv_files_test], ignore_index=True)

# %%
sorted_ids = [i+1 for i in range(10000)]
GT_all_train['ID'] = GT_all_train['ID'].astype(int)
GT_filtered = GT_all_train[GT_all_train['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()
Y = GT_filtered[target].values
y_train = Y.reshape(-1, 1)

# %%
sorted_ids = [i+1 for i in range(1000)]
GT_all_test['ID'] = GT_all_test['ID'].astype(int)
GT_filtered = GT_all_test[GT_all_test['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()
Y = GT_filtered[target].values
y_test = Y.reshape(-1, 1)

# %%
scaler_X = StandardScaler().fit(X_train)
scaler_y = StandardScaler().fit(y_train)
X_train = scaler_X.transform(X_train)
X_test  = scaler_X.transform(X_test)
Y_train = scaler_y.transform(y_train)
Y_test = scaler_y.transform(y_test)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (10000, 192) (1000, 192) (10000, 1) (1000, 1)

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.losses import Huber
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
import joblib, tensorflow as tf
from pathlib import Path
WEIGHT_DIR = Path("/content/drive/MyDrive/MCX_data/weights")

model = Sequential([
    Input(shape=(192,)),
    Dense(1000, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(8192*2, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(2048, activation='relu'),
    Dropout(0.2),

    Dense(1024, activation='relu'),
    Dropout(0.2),

    Dense(512, activation='relu'),
    Dropout(0.1),

    Dense(256, activation='relu'),
    Dropout(0.1),

    Dense(64, activation='relu'),
    Dropout(0.1),

    Dense(32, activation='relu'),
    Dropout(0.0),

    Dense(1) 
])


checkpoint_cb = ModelCheckpoint(
    f"FD_{target}_ANN.keras",        # filepath to save to
    monitor="val_loss",     # quantity to monitor
    mode="min",             # we want to minimize val_loss
    save_best_only=True,    # only save when val_loss decreases
    save_weights_only=False # set True if you only want weights
)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer, loss="mse")
history = model.fit(
    X_train, Y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    callbacks=[checkpoint_cb]
)
model = tf.keras.models.load_model(f"FD_{target}_ANN.keras")
# Out:
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 66s 196ms/step - loss: 0.3974 - val_loss: 0.0616
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0707 - val_loss: 0.0709
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0594 - val_loss: 0.0225
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0469 - val_loss: 0.0457
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0393 - val_loss: 0.0275
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0352 - val_loss: 0.0722
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0320 - val_loss: 0.0326
# Epoch 8/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0281 - val_loss: 0.0338
# Epoch 9/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0271 - val_loss: 0.0548
# Epoch 10/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0269 - val_loss: 0.0482
# Epoch 11/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0267 - val_loss: 0.0632
# Epoch 12/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0262 - val_loss: 0.0571
# Epoch 13/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0234 - val_loss: 0.0628
# Epoch 14/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0212 - val_loss: 0.0376
# Epoch 15/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0201 - val_loss: 0.0336
# Epoch 16/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0206 - val_loss: 0.0432
# Epoch 17/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0191 - val_loss: 0.0672
# Epoch 18/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0192 - val_loss: 0.0612
# Epoch 19/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0168 - val_loss: 0.0610
# Epoch 20/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0194 - val_loss: 0.0621
# Epoch 21/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0175 - val_loss: 0.0657
# Epoch 22/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0164 - val_loss: 0.0436
# Epoch 23/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0154 - val_loss: 0.0332
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0151 - val_loss: 0.0608
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0154 - val_loss: 0.0377
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0150 - val_loss: 0.0413
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0129 - val_loss: 0.0460
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0140 - val_loss: 0.0481
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0132 - val_loss: 0.0405
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0123 - val_loss: 0.0350
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0128 - val_loss: 0.0312
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0125 - val_loss: 0.0230
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0131 - val_loss: 0.0491
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 27s 94ms/step - loss: 0.0125 - val_loss: 0.0201
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0128 - val_loss: 0.0476
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0103 - val_loss: 0.0238
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0118 - val_loss: 0.0310
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0118 - val_loss: 0.0289
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0111 - val_loss: 0.0350
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0108 - val_loss: 0.0185
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0110 - val_loss: 0.0449
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0106 - val_loss: 0.0362
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0103 - val_loss: 0.0417
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0108 - val_loss: 0.0219
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0106 - val_loss: 0.0266
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0090 - val_loss: 0.0232
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0098 - val_loss: 0.0359
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0093 - val_loss: 0.0333
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0088 - val_loss: 0.0284
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0089 - val_loss: 0.0298
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0084 - val_loss: 0.0251
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0085 - val_loss: 0.0238
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0088 - val_loss: 0.0297
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0089 - val_loss: 0.0263
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0079 - val_loss: 0.0386
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0084 - val_loss: 0.0197
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0260
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0218
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0231
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0078 - val_loss: 0.0209
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0254
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0185
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0071 - val_loss: 0.0189
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0074 - val_loss: 0.0217
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0077 - val_loss: 0.0243
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0068 - val_loss: 0.0351
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0075 - val_loss: 0.0284
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0074 - val_loss: 0.0244
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0067 - val_loss: 0.0232
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 87ms/step - loss: 0.0071 - val_loss: 0.0169
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0068 - val_loss: 0.0211
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 27s 96ms/step - loss: 0.0061 - val_loss: 0.0158
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0067 - val_loss: 0.0231
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0066 - val_loss: 0.0167
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0063 - val_loss: 0.0193
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0064 - val_loss: 0.0201
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0056 - val_loss: 0.0167
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0064 - val_loss: 0.0250
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0058 - val_loss: 0.0181
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0062 - val_loss: 0.0222
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0057 - val_loss: 0.0236
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0060 - val_loss: 0.0203
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0057 - val_loss: 0.0209
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0063 - val_loss: 0.0156
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0061 - val_loss: 0.0206
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0059 - val_loss: 0.0148
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0057 - val_loss: 0.0218
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0056 - val_loss: 0.0231
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0059 - val_loss: 0.0161
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0057 - val_loss: 0.0186
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0055 - val_loss: 0.0187
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0053 - val_loss: 0.0298
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.0057 - val_loss: 0.0129
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0058 - val_loss: 0.0154
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0048 - val_loss: 0.0137
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0053 - val_loss: 0.0160
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0050 - val_loss: 0.0201
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0051 - val_loss: 0.0207
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0054 - val_loss: 0.0154
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0052 - val_loss: 0.0173
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0049 - val_loss: 0.0184
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0046 - val_loss: 0.0188
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0048 - val_loss: 0.0144
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0048 - val_loss: 0.0223
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0053 - val_loss: 0.0216
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0048 - val_loss: 0.0148
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0047 - val_loss: 0.0169
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.0047 - val_loss: 0.0104
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0050 - val_loss: 0.0135
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0049 - val_loss: 0.0143
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0048 - val_loss: 0.0185
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0051 - val_loss: 0.0252
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0048 - val_loss: 0.0210
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0046 - val_loss: 0.0204
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0048 - val_loss: 0.0120
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0046 - val_loss: 0.0172
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0045 - val_loss: 0.0155
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0043 - val_loss: 0.0136
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0046 - val_loss: 0.0190
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0044 - val_loss: 0.0166
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0052 - val_loss: 0.0142
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0044 - val_loss: 0.0220
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0052 - val_loss: 0.0142
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0044 - val_loss: 0.0177
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0043 - val_loss: 0.0132
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0042 - val_loss: 0.0141
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0042 - val_loss: 0.0130
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0050 - val_loss: 0.0146
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0042 - val_loss: 0.0153
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0039 - val_loss: 0.0149
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0044 - val_loss: 0.0138
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0044 - val_loss: 0.0172
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0048 - val_loss: 0.0149
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0046 - val_loss: 0.0126
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0039 - val_loss: 0.0124
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0041 - val_loss: 0.0171
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0042 - val_loss: 0.0150
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0039 - val_loss: 0.0144
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0042 - val_loss: 0.0127
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0040 - val_loss: 0.0185
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0039 - val_loss: 0.0135
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0041 - val_loss: 0.0151
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0044 - val_loss: 0.0125
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0040 - val_loss: 0.0177
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0038 - val_loss: 0.0126
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0037 - val_loss: 0.0146
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0036 - val_loss: 0.0154
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0038 - val_loss: 0.0166
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0039 - val_loss: 0.0199
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0038 - val_loss: 0.0169
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0049 - val_loss: 0.0166
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0061 - val_loss: 0.0132
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0053 - val_loss: 0.0172
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0046 - val_loss: 0.0156
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0041 - val_loss: 0.0128
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0038 - val_loss: 0.0138
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0037 - val_loss: 0.0178
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0037 - val_loss: 0.0156
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0040 - val_loss: 0.0157
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0040 - val_loss: 0.0167
# Epoch 161/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0037 - val_loss: 0.0135
# Epoch 162/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0037 - val_loss: 0.0154
# Epoch 163/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0035 - val_loss: 0.0162
# Epoch 164/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0036 - val_loss: 0.0170
# Epoch 165/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0177
# Epoch 166/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0039 - val_loss: 0.0137
# Epoch 167/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0035 - val_loss: 0.0132
# Epoch 168/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0035 - val_loss: 0.0154
# Epoch 169/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.0036 - val_loss: 0.0092
# Epoch 170/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0040 - val_loss: 0.0123
# Epoch 171/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0037 - val_loss: 0.0121
# Epoch 172/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0150
# Epoch 173/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0142
# Epoch 174/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0033 - val_loss: 0.0141
# Epoch 175/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0140
# Epoch 176/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0033 - val_loss: 0.0146
# Epoch 177/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0033 - val_loss: 0.0139
# Epoch 178/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0174
# Epoch 179/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0040 - val_loss: 0.0145
# Epoch 180/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0115
# Epoch 181/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0127
# Epoch 182/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0035 - val_loss: 0.0114
# Epoch 183/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0032 - val_loss: 0.0131
# Epoch 184/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0035 - val_loss: 0.0155
# Epoch 185/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0035 - val_loss: 0.0114
# Epoch 186/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0036 - val_loss: 0.0150
# Epoch 187/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0035 - val_loss: 0.0115
# Epoch 188/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0107
# Epoch 189/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0137
# Epoch 190/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0031 - val_loss: 0.0171
# Epoch 191/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0035 - val_loss: 0.0177
# Epoch 192/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0033 - val_loss: 0.0149
# Epoch 193/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0033 - val_loss: 0.0139
# Epoch 194/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0033 - val_loss: 0.0133
# Epoch 195/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0032 - val_loss: 0.0111
# Epoch 196/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0030 - val_loss: 0.0159
# Epoch 197/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0033 - val_loss: 0.0122
# Epoch 198/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0034 - val_loss: 0.0135
# Epoch 199/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0029 - val_loss: 0.0140
# Epoch 200/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.0031 - val_loss: 0.0114

# %%
WEIGHT_DIR = Path("/content/drive/MyDrive/MCX_data/weights")
WEIGHT_DIR.mkdir(parents=True, exist_ok=True)

model_path = WEIGHT_DIR / f"FD_{target}_ANN.keras"
model.save(model_path)

joblib.dump(scaler_X, WEIGHT_DIR / f"X_FD_{target}_ANN.pkl")
joblib.dump(scaler_y, WEIGHT_DIR / f"Y_FD_{target}_ANN.pkl")

print("model file exists:", model_path.exists(),
      "size =", model_path.stat().st_size/1e6, "MB")
# Out:
# model file exists: True size = 4413.937482 MB

# %%
y_pred = model.predict(X_test)
y_pred = np.clip(y_pred, scaler_y.transform(np.array([[0.9]]))[0][0], scaler_y.transform(np.array([[6.9]]))[0][0])
mse = mean_squared_error(Y_test, y_pred)
print(f"Test MSE: {mse:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test MSE: 0.0086

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │       193,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │     4,100,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8192)           │    33,562,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16384)          │   134,234,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8192)           │   134,225,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4096)           │    33,558,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2048)           │     8,390,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,103,457,341 (4.11 GB)
#  Trainable params: 367,819,113 (1.37 GB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 735,638,228 (2.74 GB)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
indices = np.random.choice(len(Y_test), size=100, replace=False)
indices = np.sort(indices)

y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
y_test_rescaled = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
print(f"Test MSE: {mse:.4f}")
y_test_sampled = y_test_rescaled[indices]
y_pred_sampled = y_pred_rescaled[indices]

plt.figure(figsize=(16, 8))
plt.plot(y_test_sampled, 'r-o', label=f'Ground Truth ({target})', linewidth=2, markersize=5)
plt.plot(y_pred_sampled, 'b--o', label=f'Predicted ({target})', linewidth=2, markersize=5)
plt.xlabel('Random Sample Index')
plt.ylabel('HHB2')
plt.title('Randomly Sampled Predictions vs Ground Truth')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE: 0.0257

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
y_pred = np.asarray(y_pred_rescaled).ravel()
y_true = np.asarray(y_test_rescaled).ravel()
residuals = y_pred - y_true
mae = mean_absolute_error(y_true, y_pred)
mare = np.mean(np.abs(residuals) / np.abs(y_true)) * 100
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)
bias = np.mean(residuals)
sd   = np.std(residuals, ddof=1)   # sample standard deviation
print(f"MAE (μm):          {mae:.4f}")
print(f"MARE (%):          {mare:.4f}")
print(f"RMSE (μm):         {rmse:.4f}")
print(f"R²:                {r2:.4f}")
print(f"Bias ± SD (μm):    {bias:.4f} ± {sd:.4f}")
# Out:
# MAE (μm):          0.1227
# MARE (%):          5.3233
# RMSE (μm):         0.1603
# R²:                0.9914
# Bias ± SD (μm):    0.0204 ± 0.1591

# %%
residuals = y_pred_rescaled - y_test_rescaled

mse_rescaled = mean_squared_error(y_test_rescaled, y_pred_rescaled)
print(f"Test MSE (original scale): {mse_rescaled:.4f}")
plt.figure(figsize=(16, 8))
plt.scatter(range(len(residuals)), residuals, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.title("Residuals (Predicted - Ground Truth)")
plt.ylabel("Residual")
plt.ylim(-10, 10)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE (original scale): 0.0257

# %%
relative_error = ((y_pred_rescaled - y_test_rescaled) / y_test_rescaled) * 100
plt.figure(figsize=(16, 8))
plt.scatter(range(len(relative_error)), relative_error, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.ylabel("Relative Error (%)")
plt.ylim(-100, 100)
plt.yticks(np.arange(-100, 101, 10))
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
df_plot = pd.DataFrame({
    'Relative Error (%)': relative_error.flatten()
})

plt.figure(figsize=(10, 10))
sns.violinplot(data=df_plot, y='Relative Error (%)', inner=None, linewidth=1.2)
sns.stripplot(data=df_plot, y='Relative Error (%)', color='black', alpha=0.4, jitter=0.2, size=3)

plt.axhline(0, color='r', linestyle='--', linewidth=1)
plt.ylim(-100, 100)
plt.title('Distribution of Relative Error (%)')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score, mean_absolute_percentage_error

plt.figure(figsize=(10,10))
plt.scatter(y_test_rescaled, y_pred_rescaled, alpha=0.6)
lims = [min(y_test_rescaled.min(), y_pred_rescaled.min()),
        max(y_test_rescaled.max(), y_pred_rescaled.max())]
plt.plot(lims, lims, 'k--')              # identity line
plt.xlabel(f'Ground-truth {target}'); plt.ylabel(f'Predicted {target}')
plt.axis('square'); plt.xlim(lims); plt.ylim(lims)
plt.grid()
print("R² =", r2_score(y_test_rescaled, y_pred_rescaled))
print("MAPE =", mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)*100, "%")
plt.show()
# Out:
# R² = 0.9914336201645463
# MAPE = 5.323294355120439 %

# %%
relative_error = relative_error.squeeze()

plt.figure(figsize=(10, 6))
sns.boxplot(y=relative_error, color='lightgray', width=0.3)
sns.stripplot(y=relative_error, color='black', alpha=0.03, jitter=0.4, size=1.5)

plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.title('Relative Error Distribution (%)')
plt.ylabel('Relative Error (%)')
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.violinplot(y=relative_error, inner=None, color='skyblue', cut=0)
sns.stripplot(y=relative_error, color='black', alpha=0.05, jitter=0.3, size=2)
plt.axhline(0, color='red', linestyle='--', linewidth=1.2)
plt.title('Distribution of Relative Error (%)')
plt.ylabel('Relative Error (%)')
plt.grid()
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_squared_error

sorted_idx       = np.argsort(y_test_rescaled)         # indices that sort y_test
y_test_sorted    = y_test_rescaled[sorted_idx]
y_pred_sorted    = y_pred_rescaled[sorted_idx]
plt.figure(figsize=(16, 8))
plt.plot(y_test_sorted, 'r-o',  label=f'Ground Truth {target}', linewidth=2, markersize=5)
plt.plot(y_pred_sorted, 'b--o', label=f'Predicted {target}',   linewidth=2, markersize=5)
plt.xlabel(f'Sample (sorted by ground-truth {target})')
plt.ylabel(f'{target}')
plt.title(f'Predictions vs Ground Truth (sorted by {target})')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(relative_error, kde=True, bins=1000, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Histogram + KDE of Relative Error (%)")
plt.xlabel("Relative Error (%)")
plt.ylabel("Frequency")
plt.grid()
plt.xlim(-100, 100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
sns.histplot(np.asarray(y_test_rescaled).ravel(), kde=True, bins=100, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Ground Truth (Y_test) Distribution")
plt.xlabel("Y_test")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

plt.subplot(1, 2, 2)
sns.histplot( np.asarray(y_pred_rescaled).ravel(), kde=True, bins=100, color='darkorange', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Prediction (Y_pred) Distribution")
plt.xlabel("Y_pred")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# Ensure y_true and y_pred are 1D numpy arrays
y_true = np.asarray(y_test_rescaled).ravel()
y_pred =np.asarray(y_pred_rescaled).ravel()

# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# Plot
plt.figure(figsize=(10, 10))
plt.hist2d(y_true, y_pred, bins=100, cmap='Blues', cmin=1)

# Plot identity line
plt.plot([min(y_true), max(y_true)],
         [min(y_true), max(y_true)],
         'k--', lw=1)

# Labels and title
plt.xlabel(f'Expected ${target}$')
plt.ylabel(f'Predicted ${target}$')
plt.title(r'$S$')

# Annotate RMSE
plt.text(0.05, 0.95, f'RMSE: {rmse:.2e}', color='darkred',
         fontsize=14, transform=plt.gca().transAxes, va='top')

plt.colorbar(label='Density')
plt.tight_layout()
plt.show()

# %%
# Small epsilon to avoid division by zero
eps = 1e-8

# Relative error (%)
relative_error = (y_pred - y_true) / (y_true + eps) * 100
absolute_relative_error = np.abs(relative_error)

# Compute metrics
mre = np.mean(relative_error)
mape = np.mean(absolute_relative_error)

# Print
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 5.3233%

# %%
lower, upper = np.percentile(relative_error, [16, 84])
print(f"68% CI of HHb₂ % error: {lower:.2f}% to {upper:.2f}%")
# Out:
# 68% CI of HHb₂ % error: -2.35% to 10.51%
