# %% [markdown]
# ## TD 2 distance

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
! pip install pmcx
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import pickle
import numpy as np
from pathlib import Path
import os, re
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
from FD_msNIRS_2layers import extract_freq as ef
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### GT

# %%
train_sorted_ids = [i+1 for i in range(10000)]
GT_folder_train = '/content/drive/MyDrive/MCX_data/stage2_csv/'
csv_files = glob.glob(os.path.join(GT_folder_train, '*.csv'))
GT_all_train = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# Ensure ID column is integer
GT_all_train['ID'] = GT_all_train['ID'].astype(int)

# Filter and sort GT_all to match the sorted_ids order
GT_filtered = GT_all_train[GT_all_train['ID'].isin(train_sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[train_sorted_ids].reset_index()

# Extract HHB2 as Y
Y_train = GT_filtered['HHB2'].values  # numpy array (n_samples,)
Y_train = Y_train.reshape(-1, 1)
print(Y_train.shape)
# Out:
# (10000, 1)

# %%
test_sorted_ids = [i+1 for i in range(1000)]
GT_folder_test = '/content/drive/MyDrive/MCX_data/test_csv/'
csv_files = glob.glob(os.path.join(GT_folder_test, '*.csv'))
GT_all_test = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

GT_all_test['ID'] = GT_all_test['ID'].astype(int)

GT_filtered = GT_all_test[GT_all_test['ID'].isin(test_sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[test_sorted_ids].reset_index()

Y_test = GT_filtered['HHB2'].values  # numpy array (n_samples,)
Y_test = Y_test.reshape(-1, 1)
print(Y_test.shape)
# Out:
# (1000, 1)

# %% [markdown]
# #### scale X and Y

# %%
from sklearn.preprocessing import StandardScaler
import joblib

scaler_y  = StandardScaler()
Y_train = scaler_y.fit_transform(Y_train.reshape(-1, 1)).ravel()
Y_test  = scaler_y.transform(Y_test.reshape(-1, 1)).ravel()

# %%
pth = '/content/drive/MyDrive/MCX_data/weights_td/'
joblib.dump(scaler_y, pth+"TD_thickness_CNN_scaler_y.pkl")
SAVE_DIR = Path("/content/drive/MyDrive/MCX_data/splits")
data    = np.load(SAVE_DIR / "train_test_split.npz", allow_pickle=False)
X_train = data["X_train"]
X_test  = data["X_test"]

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (10000, 64, 1000) (1000, 64, 1000) (10000,) (1000,)

# %% [markdown]
# ### Create Seperations

# %%
import numpy as np
import itertools
from typing import Dict, List

def split_distance_pairs(
        X_train: np.ndarray,   # (N_train, 64, 1000)
        X_test : np.ndarray    # (N_test , 64, 1000)
) -> Dict[int, List[np.ndarray]]:
    """
    Build a dictionary of *all* 2-distance combinations (8 choose 2 = 28).

    Key format
    ----------
    12  → distances 1 & 2 concatenated
    13  → distances 1 & 3
    …
    78  → distances 7 & 8

    Returns
    -------
    pair_dict[key] = [ X_train_pair , X_test_pair ]
        where each pair has shape (N, 16, 1000)
    """
    if X_train.shape[1] != 64 or X_test.shape[1] != 64:
        raise ValueError("Second dimension must be 64 (= 8 distances × 8 λ).")

    # --- pre-slice each single distance: (N, 8, 1000) ----------------
    single: Dict[int, List[np.ndarray]] = {}
    for d in range(1, 9):
        s, e = (d - 1) * 8, d * 8          # column indices
        single[d] = [X_train[:, s:e, :],    # train block
                     X_test[:,  s:e, :]]    # test  block

    # --- build all 28 two-distance combinations ----------------------
    pair_dict: Dict[int, List[np.ndarray]] = {}
    for a, b in itertools.combinations(range(1, 9), 2):
        key = int(f"{a}{b}")               # e.g. 12, 13, …, 78
        pair_train = np.concatenate([single[a][0], single[b][0]], axis=1)  # (N,16,1000)
        pair_test  = np.concatenate([single[a][1], single[b][1]], axis=1)  # (N,16,1000)
        pair_dict[key] = [pair_train, pair_test]

    return pair_dict


# ── usage ────────────────────────────────────────────────────────────
# X_train.shape == (10000, 64, 1000)
# X_test .shape == (1000 , 64, 1000)

distance_data = split_distance_pairs(X_train, X_test)

# Example:
# distance_pairs[12][0] → training block for distances 1+2  (shape 10000×16×1000)
# distance_pairs[12][1] → test     block for distances 1+2  (shape  1000×16×1000)
# len(distance_pairs) == 28

# %%
distance_data.keys()
# Out:
# dict_keys([12, 13, 14, 15, 16, 17, 18, 23, 24, 25, 26, 27, 28, 34, 35, 36, 37, 38, 45, 46, 47, 48, 56, 57, 58, 67, 68, 78])

# %%
len(distance_data)
# Out:
# 28

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Add,
    MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
)
from pathlib import Path
import joblib, tensorflow as tf


def residual_block(x, filters, kernel_size=(5, 5), downsample=False, dropout_rate=0.0):
    shortcut = x

    # First conv
    x = Conv2D(filters, kernel_size, padding='same', strides=(2, 2) if downsample else (1, 1))(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    # Second conv
    x = Conv2D(filters, kernel_size, padding='same')(x)

    # Shortcut path
    if downsample or shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, (1, 1), strides=(2, 2) if downsample else (1, 1), padding='same')(shortcut)

    # Merge
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# Input
input_tensor = Input(shape=(16, 1000, 1))

# Initial Conv Layer
x = Conv2D(32, (3, 3), padding='same', activation='relu')(input_tensor)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Residual Blocks
x = residual_block(x, 128, downsample=True, dropout_rate=0.0)
x = residual_block(x, 128)

x = residual_block(x, 128, downsample=True, dropout_rate=0.0)
x = residual_block(x, 128)

x = residual_block(x, 256, downsample=True, dropout_rate=0.0)
x = residual_block(x, 256)

# Global Average Pooling
x = GlobalAveragePooling2D()(x)

# Dense Head
x = Dense(128, activation='relu')(x)
x = Dropout(0.0)(x)
x = Dense(64, activation='relu')(x)
x = Dense(1)(x)

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
Path = '/content/drive/MyDrive/MCX_data/distance_2/'
for k, v in distance_data.items():
     resnet_model = Model(inputs=input_tensor, outputs=x)
     checkpoint_cb = ModelCheckpoint(
        "TD_hhb2_CNN.keras",        # filepath to save to
        monitor="val_loss",     # quantity to monitor
        mode="min",             # we want to minimize val_loss
        save_best_only=True,    # only save when val_loss decreases
        save_weights_only=False # set True if you only want weights
     )
     optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
     resnet_model.compile(optimizer=optimizer, loss="mse")
     history = resnet_model.fit( v[0], Y_train, epochs=200, batch_size=32, validation_split=0.1, verbose=1, callbacks=[checkpoint_cb])
     resnet_model = tf.keras.models.load_model("TD_hhb2_CNN.keras")
     y_pred = resnet_model.predict(v[1])
     y_pred = np.clip(y_pred, scaler_y.transform(np.array([[15]]))[0][0], scaler_y.transform(np.array([[35]]))[0][0])
     ###
     y_pred = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
     y_test = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()
     mse = mean_squared_error(y_test, y_pred)
     print(f"MSE for distance {k}: {mse}")
     print(f"RMSE for distance {k}: {np.sqrt(mse)}")
     df = pd.DataFrame({
        "y_test" : y_test,
        "y_pred" : y_pred
    })
     df.to_csv(Path + f"distance_{k}_hhb2_TD.csv", index=False)
# Out:
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 27s 47ms/step - loss: 0.9385 - val_loss: 0.5240
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.5288 - val_loss: 0.4394
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.4346 - val_loss: 0.4476
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.3496 - val_loss: 0.3338
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2859 - val_loss: 0.3457
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2735 - val_loss: 0.2168
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.2145 - val_loss: 0.3126
# Epoch 8/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.2057 - val_loss: 0.1803
# Epoch 9/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1670 - val_loss: 0.1936
# Epoch 10/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1525 - val_loss: 0.1740
# Epoch 11/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1384 - val_loss: 0.1592
# Epoch 12/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1391 - val_loss: 0.2333
# Epoch 13/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1292 - val_loss: 0.1732
# Epoch 14/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1178 - val_loss: 0.1576
# Epoch 15/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1197 - val_loss: 0.2310
# Epoch 16/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1259 - val_loss: 0.1509
# Epoch 17/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1060 - val_loss: 0.1688
# Epoch 18/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1050 - val_loss: 0.1715
# Epoch 19/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1171 - val_loss: 0.1574
# Epoch 20/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0957 - val_loss: 0.1440
# Epoch 21/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0899 - val_loss: 0.1678
# Epoch 22/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.1034 - val_loss: 0.1494
# Epoch 23/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0880 - val_loss: 0.1456
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0806 - val_loss: 0.1560
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0907 - val_loss: 0.1577
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0813 - val_loss: 0.1576
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0805 - val_loss: 0.1430
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0792 - val_loss: 0.1414
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0913 - val_loss: 0.1473
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0754 - val_loss: 0.1496
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0701 - val_loss: 0.1295
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0637 - val_loss: 0.1254
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0719 - val_loss: 0.1519
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0687 - val_loss: 0.1983
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0686 - val_loss: 0.1279
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0620 - val_loss: 0.1391
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0717 - val_loss: 0.1489
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0607 - val_loss: 0.1364
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0594 - val_loss: 0.1305
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0556 - val_loss: 0.1285
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0721 - val_loss: 0.1381
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0508 - val_loss: 0.1376
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0539 - val_loss: 0.1244
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0570 - val_loss: 0.1366
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0471 - val_loss: 0.1387
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0488 - val_loss: 0.1619
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0549 - val_loss: 0.1272
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0473 - val_loss: 0.1337
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0506 - val_loss: 0.1256
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0454 - val_loss: 0.1274
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0467 - val_loss: 0.1464
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0483 - val_loss: 0.1284
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0422 - val_loss: 0.1324
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0520 - val_loss: 0.1518
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0488 - val_loss: 0.1562
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0387 - val_loss: 0.1383
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0401 - val_loss: 0.1369
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0438 - val_loss: 0.1332
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0432 - val_loss: 0.1463
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0410 - val_loss: 0.1348
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0399 - val_loss: 0.1331
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0422 - val_loss: 0.1273
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0363 - val_loss: 0.1291
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0419 - val_loss: 0.1576
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0400 - val_loss: 0.1387
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0365 - val_loss: 0.1409
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0380 - val_loss: 0.1292
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0345 - val_loss: 0.1395
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0354 - val_loss: 0.1354
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0311 - val_loss: 0.1272
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0398 - val_loss: 0.1297
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0332 - val_loss: 0.1337
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0317 - val_loss: 0.1308
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0285 - val_loss: 0.1250
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0327 - val_loss: 0.1253
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0283 - val_loss: 0.1326
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0303 - val_loss: 0.1309
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0320 - val_loss: 0.1352
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0280 - val_loss: 0.1280
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0297 - val_loss: 0.1209
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0257 - val_loss: 0.1458
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0281 - val_loss: 0.1375
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0305 - val_loss: 0.1297
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0258 - val_loss: 0.1604
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0284 - val_loss: 0.1346
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0259 - val_loss: 0.1306
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0252 - val_loss: 0.1308
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0254 - val_loss: 0.1427
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0299 - val_loss: 0.1249
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0249 - val_loss: 0.1465
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0305 - val_loss: 0.1272
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0241 - val_loss: 0.1328
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0235 - val_loss: 0.1257
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0203 - val_loss: 0.1236
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0223 - val_loss: 0.1602
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0255 - val_loss: 0.1352
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0256 - val_loss: 0.1281
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0181 - val_loss: 0.1295
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0215 - val_loss: 0.1264
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0199 - val_loss: 0.1352
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0223 - val_loss: 0.1264
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0196 - val_loss: 0.1396
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0243 - val_loss: 0.1328
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0174 - val_loss: 0.1458
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0195 - val_loss: 0.1296
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0183 - val_loss: 0.1430
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0195 - val_loss: 0.1302
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0189 - val_loss: 0.1296
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0169 - val_loss: 0.1289
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0161 - val_loss: 0.1306
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0167 - val_loss: 0.1340
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0203 - val_loss: 0.1261
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0152 - val_loss: 0.1425
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0196 - val_loss: 0.1318
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0175 - val_loss: 0.1312
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0129 - val_loss: 0.1323
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0134 - val_loss: 0.1375
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0216 - val_loss: 0.1323
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0143 - val_loss: 0.1382
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0149 - val_loss: 0.1378
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0129 - val_loss: 0.1369
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0126 - val_loss: 0.1353
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0136 - val_loss: 0.1528
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0149 - val_loss: 0.1321
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0152 - val_loss: 0.1347
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0137 - val_loss: 0.1399
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0114 - val_loss: 0.1359
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0109 - val_loss: 0.1328
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0125 - val_loss: 0.1373
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0110 - val_loss: 0.1309
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0124 - val_loss: 0.1306
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0111 - val_loss: 0.1330
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0105 - val_loss: 0.1478
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0160 - val_loss: 0.1324
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0098 - val_loss: 0.1335
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0102 - val_loss: 0.1520
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0128 - val_loss: 0.1328
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0162 - val_loss: 0.1375
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0112 - val_loss: 0.1401
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0091 - val_loss: 0.1359
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0122 - val_loss: 0.1342
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0083 - val_loss: 0.1338
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0102 - val_loss: 0.1342
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0096 - val_loss: 0.1476
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0155 - val_loss: 0.1345
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0086 - val_loss: 0.1359
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0097 - val_loss: 0.1361
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0078 - val_loss: 0.1359
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0096 - val_loss: 0.1368
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0117 - val_loss: 0.1400
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0077 - val_loss: 0.1364
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0096 - val_loss: 0.1367
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0073 - val_loss: 0.1346
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0081 - val_loss: 0.1346
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0105 - val_loss: 0.1345
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0097 - val_loss: 0.1339
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0083 - val_loss: 0.1418
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0098 - val_loss: 0.1371
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0102 - val_loss: 0.1492
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0112 - val_loss: 0.1409
# Epoch 161/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0071 - val_loss: 0.1353
# Epoch 162/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0076 - val_loss: 0.1381
# Epoch 163/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0070 - val_loss: 0.1353
# Epoch 164/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0104 - val_loss: 0.1447
# Epoch 165/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0087 - val_loss: 0.1319
# Epoch 166/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0075 - val_loss: 0.1366
# Epoch 167/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0061 - val_loss: 0.1339
# Epoch 168/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0050 - val_loss: 0.1422
# Epoch 169/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0117 - val_loss: 0.1372
# Epoch 170/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0065 - val_loss: 0.1376
# Epoch 171/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0112 - val_loss: 0.1421
# Epoch 172/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0059 - val_loss: 0.1355
# Epoch 173/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0062 - val_loss: 0.1373
# Epoch 174/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0070 - val_loss: 0.1359
# Epoch 175/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0050 - val_loss: 0.1353
# Epoch 176/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0061 - val_loss: 0.1349
# Epoch 177/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0082 - val_loss: 0.1368
# Epoch 178/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0072 - val_loss: 0.1436
# Epoch 179/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0081 - val_loss: 0.1362
# Epoch 180/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0050 - val_loss: 0.1403
# Epoch 181/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0065 - val_loss: 0.1467
# Epoch 182/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0147 - val_loss: 0.1362
# Epoch 183/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0059 - val_loss: 0.1364
# Epoch 184/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0045 - val_loss: 0.1409
# Epoch 185/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0056 - val_loss: 0.1385
# Epoch 186/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0043 - val_loss: 0.1371
# Epoch 187/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0055 - val_loss: 0.1357
# Epoch 188/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0083 - val_loss: 0.1398
# Epoch 189/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0087 - val_loss: 0.1351
# Epoch 190/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0045 - val_loss: 0.1385
# Epoch 191/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0090 - val_loss: 0.1354
# Epoch 192/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0047 - val_loss: 0.1380
# Epoch 193/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1371
# Epoch 194/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0055 - val_loss: 0.1378
# Epoch 195/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0052 - val_loss: 0.1343
# Epoch 196/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0056 - val_loss: 0.1370
# Epoch 197/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0057 - val_loss: 0.1371
# Epoch 198/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0055 - val_loss: 0.1391
# Epoch 199/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0067 - val_loss: 0.1461
# Epoch 200/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0084 - val_loss: 0.1350
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step
# MSE for distance 12: 1.7803362128638553
# RMSE for distance 12: 1.3342924015611628
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 17s 32ms/step - loss: 0.1188 - val_loss: 0.1218
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0654 - val_loss: 0.1188
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0507 - val_loss: 0.1124
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0419 - val_loss: 0.1239
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0345 - val_loss: 0.1110
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0301 - val_loss: 0.1265
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0289 - val_loss: 0.1152
# Epoch 8/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0273 - val_loss: 0.1127
# Epoch 9/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0218 - val_loss: 0.1174
# Epoch 10/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0244 - val_loss: 0.1214
# Epoch 11/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0179 - val_loss: 0.1302
# Epoch 12/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0174 - val_loss: 0.1215
# Epoch 13/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0204 - val_loss: 0.1194
# Epoch 14/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0163 - val_loss: 0.1200
# Epoch 15/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0183 - val_loss: 0.1220
# Epoch 16/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0186 - val_loss: 0.1173
# Epoch 17/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0129 - val_loss: 0.1252
# Epoch 18/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0182 - val_loss: 0.1201
# Epoch 19/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0125 - val_loss: 0.1190
# Epoch 20/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0112 - val_loss: 0.1164
# Epoch 21/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0102 - val_loss: 0.1209
# Epoch 22/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0103 - val_loss: 0.1221
# Epoch 23/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0096 - val_loss: 0.1191
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0122 - val_loss: 0.1233
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0127 - val_loss: 0.1232
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0108 - val_loss: 0.1164
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0080 - val_loss: 0.1201
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0120 - val_loss: 0.1220
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0104 - val_loss: 0.1169
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0096 - val_loss: 0.1287
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0086 - val_loss: 0.1190
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0077 - val_loss: 0.1165
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0079 - val_loss: 0.1161
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0082 - val_loss: 0.1232
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0088 - val_loss: 0.1249
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0082 - val_loss: 0.1153
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0088 - val_loss: 0.1216
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0125 - val_loss: 0.1181
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0076 - val_loss: 0.1210
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0059 - val_loss: 0.1191
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0071 - val_loss: 0.1155
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0057 - val_loss: 0.1198
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0068 - val_loss: 0.1173
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0051 - val_loss: 0.1154
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0053 - val_loss: 0.1215
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0068 - val_loss: 0.1176
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0072 - val_loss: 0.1150
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0061 - val_loss: 0.1199
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0058 - val_loss: 0.1199
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0058 - val_loss: 0.1196
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0066 - val_loss: 0.1205
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0073 - val_loss: 0.1152
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0046 - val_loss: 0.1314
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0086 - val_loss: 0.1153
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0062 - val_loss: 0.1169
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1196
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0073 - val_loss: 0.1189
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0054 - val_loss: 0.1182
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1194
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0045 - val_loss: 0.1170
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0051 - val_loss: 0.1204
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0049 - val_loss: 0.1158
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0043 - val_loss: 0.1173
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0062 - val_loss: 0.1238
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0054 - val_loss: 0.1193
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0098 - val_loss: 0.1189
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0059 - val_loss: 0.1164
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0057 - val_loss: 0.1201
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0057 - val_loss: 0.1172
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1186
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1172
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1182
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0032 - val_loss: 0.1186
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0043 - val_loss: 0.1191
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0043 - val_loss: 0.1207
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0053 - val_loss: 0.1183
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0056 - val_loss: 0.1239
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0075 - val_loss: 0.1176
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0047 - val_loss: 0.1194
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0057 - val_loss: 0.1187
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0037 - val_loss: 0.1190
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0043 - val_loss: 0.1204
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0036 - val_loss: 0.1238
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1206
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0031 - val_loss: 0.1209
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0054 - val_loss: 0.1172
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1201
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0072 - val_loss: 0.1180
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0041 - val_loss: 0.1191
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0036 - val_loss: 0.1221
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0036 - val_loss: 0.1216
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0038 - val_loss: 0.1198
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1197
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0032 - val_loss: 0.1195
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0048 - val_loss: 0.1168
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0040 - val_loss: 0.1207
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0059 - val_loss: 0.1194
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0038 - val_loss: 0.1192
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.1198
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1218
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1190
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1239
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0045 - val_loss: 0.1215
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1241
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0036 - val_loss: 0.1224
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1208
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0043 - val_loss: 0.1207
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1201
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0037 - val_loss: 0.1205
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1201
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1224
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1191
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1283
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1282
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0037 - val_loss: 0.1251
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0041 - val_loss: 0.1218
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0063 - val_loss: 0.1222
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0036 - val_loss: 0.1265
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1226
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1264
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1219
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.1223
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1218
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1252
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0037 - val_loss: 0.1222
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0043 - val_loss: 0.1229
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1211
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1251
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1219
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1241
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1208
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0026 - val_loss: 0.1229
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1215
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1229
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1234
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0026 - val_loss: 0.1256
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0032 - val_loss: 0.1216
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0028 - val_loss: 0.1247
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1235
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1226
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1255
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0036 - val_loss: 0.1217
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1244
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0032 - val_loss: 0.1286
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0031 - val_loss: 0.1203
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1238
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1289
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0028 - val_loss: 0.1212
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1252
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1197
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0026 - val_loss: 0.1244
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1235
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0031 - val_loss: 0.1245
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1205
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.1220
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1225
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1216
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1241
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1230
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0028 - val_loss: 0.1236
# Epoch 161/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0041 - val_loss: 0.1221
# Epoch 162/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0026 - val_loss: 0.1262
# Epoch 163/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1222
# Epoch 164/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1245
# Epoch 165/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1233
# Epoch 166/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0031 - val_loss: 0.1270
# Epoch 167/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0031 - val_loss: 0.1283
# Epoch 168/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0031 - val_loss: 0.1291
# Epoch 169/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1235
# Epoch 170/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.1240
# Epoch 171/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1234
# Epoch 172/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0016 - val_loss: 0.1257
# Epoch 173/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0026 - val_loss: 0.1238
# Epoch 174/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0037 - val_loss: 0.1263
# Epoch 175/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1261
# Epoch 176/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1297
# Epoch 177/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1233
# Epoch 178/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.1229
# Epoch 179/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.1230
# Epoch 180/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0016 - val_loss: 0.1240
# Epoch 181/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1271
# Epoch 182/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1307
# Epoch 183/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1275
# Epoch 184/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1277
# Epoch 185/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1263
# Epoch 186/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.1262
# Epoch 187/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1273
# Epoch 188/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1289
# Epoch 189/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.1271
# Epoch 190/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1254
# Epoch 191/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1259
# Epoch 192/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0026 - val_loss: 0.1274
# Epoch 193/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.1316
# Epoch 194/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0050 - val_loss: 0.1272
# Epoch 195/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0017 - val_loss: 0.1277
# Epoch 196/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1248
# Epoch 197/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1248
# Epoch 198/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.1272
# Epoch 199/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1293
# Epoch 200/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1322
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# MSE for distance 13: 2.043544893264858
# RMSE for distance 13: 1.4295261079339747
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 18s 34ms/step - loss: 0.0809 - val_loss: 0.1423
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0477 - val_loss: 0.1376
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0352 - val_loss: 0.1232
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0260 - val_loss: 0.1187
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0204 - val_loss: 0.1247
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0176 - val_loss: 0.1227
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0137 - val_loss: 0.1240
# Epoch 8/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0124 - val_loss: 0.1182
# Epoch 9/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0121 - val_loss: 0.1232
# Epoch 10/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0094 - val_loss: 0.1215
# Epoch 11/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0085 - val_loss: 0.1246
# Epoch 12/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0082 - val_loss: 0.1187
# Epoch 13/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0079 - val_loss: 0.1218
# Epoch 14/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0087 - val_loss: 0.1189
# Epoch 15/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0068 - val_loss: 0.1188
# Epoch 16/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0077 - val_loss: 0.1197
# Epoch 17/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0068 - val_loss: 0.1262
# Epoch 18/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0071 - val_loss: 0.1216
# Epoch 19/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0063 - val_loss: 0.1195
# Epoch 20/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0066 - val_loss: 0.1218
# Epoch 21/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0063 - val_loss: 0.1233
# Epoch 22/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0078 - val_loss: 0.1212
# Epoch 23/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0053 - val_loss: 0.1204
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0048 - val_loss: 0.1223
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0047 - val_loss: 0.1177
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0045 - val_loss: 0.1197
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0047 - val_loss: 0.1222
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0056 - val_loss: 0.1214
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0075 - val_loss: 0.1217
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0059 - val_loss: 0.1218
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0046 - val_loss: 0.1239
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1216
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1215
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0043 - val_loss: 0.1204
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0044 - val_loss: 0.1221
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0041 - val_loss: 0.1237
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0052 - val_loss: 0.1268
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0050 - val_loss: 0.1213
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1228
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0042 - val_loss: 0.1191
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0050 - val_loss: 0.1223
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1210
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0044 - val_loss: 0.1217
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1209
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0037 - val_loss: 0.1236
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1202
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0037 - val_loss: 0.1208
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1253
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1243
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0084 - val_loss: 0.1253
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0045 - val_loss: 0.1227
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0040 - val_loss: 0.1229
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1207
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1210
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1251
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1224
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1227
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1249
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0031 - val_loss: 0.1247
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1228
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0038 - val_loss: 0.1244
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1247
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0041 - val_loss: 0.1211
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0035 - val_loss: 0.1248
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1198
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0037 - val_loss: 0.1220
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1250
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0028 - val_loss: 0.1233
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1233
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1247
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1225
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1264
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1246
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1246
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0032 - val_loss: 0.1260
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0032 - val_loss: 0.1273
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1222
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1265
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.1236
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1252
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0028 - val_loss: 0.1225
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1242
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.1228
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1262
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1251
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0028 - val_loss: 0.1250
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.1247
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1238
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.1241
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.1240
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0026 - val_loss: 0.1285
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0052 - val_loss: 0.1236
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0034 - val_loss: 0.1245
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1220
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.1256
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.1248
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.1241
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0028 - val_loss: 0.1258
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0027 - val_loss: 0.1259
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1266
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1241
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1247
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1284
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1260
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1268
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1284
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1306
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0039 - val_loss: 0.1290
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0028 - val_loss: 0.1282
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1258
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1307
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1294
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0032 - val_loss: 0.1272
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1266
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.1298
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1280
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0036 - val_loss: 0.1277
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.1251
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.1266
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1259
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1254
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.1279
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1280
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1341
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0029 - val_loss: 0.1266
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.1326
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.1284
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.1304
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1282
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0017 - val_loss: 0.1285
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1281
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.1296
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.1259
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0032 - val_loss: 0.1311
# Epoch 135/200
# ...
# Epoch 188/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.8568e-04 - val_loss: 0.0972
# Epoch 189/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.0251e-04 - val_loss: 0.0981
# Epoch 190/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.1007e-04 - val_loss: 0.0966
# Epoch 191/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.2642e-04 - val_loss: 0.0981
# Epoch 192/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.5928e-04 - val_loss: 0.0986
# Epoch 193/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.4039e-04 - val_loss: 0.0967
# Epoch 194/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.8866e-04 - val_loss: 0.1004
# Epoch 195/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.1681e-04 - val_loss: 0.0977
# Epoch 196/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.8093e-04 - val_loss: 0.0993
# Epoch 197/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.0335e-04 - val_loss: 0.0962
# Epoch 198/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.3164e-04 - val_loss: 0.0984
# Epoch 199/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.7178e-04 - val_loss: 0.0972
# Epoch 200/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.1098e-04 - val_loss: 0.0980
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# MSE for distance 24: 1.4371427092203504
# RMSE for distance 24: 1.1988088710133697
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - loss: 0.0445 - val_loss: 0.0872
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0233 - val_loss: 0.0896
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0153 - val_loss: 0.0846
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0105 - val_loss: 0.0889
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0073 - val_loss: 0.0878
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0051 - val_loss: 0.0877
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0040 - val_loss: 0.0884
# Epoch 8/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0033 - val_loss: 0.0885
# Epoch 9/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.0873
# Epoch 10/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0026 - val_loss: 0.0895
# Epoch 11/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.0893
# Epoch 12/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.0890
# Epoch 13/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.0899
# Epoch 14/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.0892
# Epoch 15/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.0894
# Epoch 16/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0030 - val_loss: 0.0911
# Epoch 17/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0025 - val_loss: 0.0904
# Epoch 18/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.0887
# Epoch 19/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.0888
# Epoch 20/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.0872
# Epoch 21/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0900
# Epoch 22/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0017 - val_loss: 0.0902
# Epoch 23/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0024 - val_loss: 0.0903
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.0886
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0023 - val_loss: 0.0893
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0022 - val_loss: 0.0906
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.0866
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.0892
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0020 - val_loss: 0.0886
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0017 - val_loss: 0.0874
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0896
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0021 - val_loss: 0.0890
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.0883
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.0879
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0017 - val_loss: 0.0887
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0857
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0871
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0898
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0869
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0897
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0016 - val_loss: 0.0874
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.0867
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0019 - val_loss: 0.0873
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0016 - val_loss: 0.0862
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0869
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0866
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0866
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0010 - val_loss: 0.0874
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0863
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0875
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0017 - val_loss: 0.0868
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0016 - val_loss: 0.0853
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0854
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0858
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0862
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0862
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0863
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0851
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0864
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0849
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0865
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0871
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0858
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0867
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0011 - val_loss: 0.0841
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0010 - val_loss: 0.0857
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0849
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0015 - val_loss: 0.0841
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0018 - val_loss: 0.0867
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0875
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0856
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0866
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0854
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.5530e-04 - val_loss: 0.0854
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.2276e-04 - val_loss: 0.0845
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.7932e-04 - val_loss: 0.0854
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.5401e-04 - val_loss: 0.0872
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0855
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0860
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0886
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0867
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0853
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.4115e-04 - val_loss: 0.0862
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.5555e-04 - val_loss: 0.0859
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.0921e-04 - val_loss: 0.0851
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.5574e-04 - val_loss: 0.0846
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.3613e-04 - val_loss: 0.0871
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0861
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0017 - val_loss: 0.0860
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0016 - val_loss: 0.0853
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0872
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0861
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.0625e-04 - val_loss: 0.0843
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.7817e-04 - val_loss: 0.0865
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.6678e-04 - val_loss: 0.0849
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.0174e-04 - val_loss: 0.0853
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.9952e-04 - val_loss: 0.0857
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0861
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0856
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0010 - val_loss: 0.0869
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.5309e-04 - val_loss: 0.0869
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.8610e-04 - val_loss: 0.0868
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.4996e-04 - val_loss: 0.0855
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.0897e-04 - val_loss: 0.0857
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.1950e-04 - val_loss: 0.0874
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0013 - val_loss: 0.0879
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0871
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.4291e-04 - val_loss: 0.0872
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.1471e-04 - val_loss: 0.0868
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.2596e-04 - val_loss: 0.0871
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.2451e-04 - val_loss: 0.0873
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0875
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.7893e-04 - val_loss: 0.0862
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.9190e-04 - val_loss: 0.0862
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 0.0882
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0873
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.0143e-04 - val_loss: 0.0869
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 3.8195e-04 - val_loss: 0.0876
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 4.0858e-04 - val_loss: 0.0871
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 3.6297e-04 - val_loss: 0.0878
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.7458e-04 - val_loss: 0.0873
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.5735e-04 - val_loss: 0.0886
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 0.0879
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0879
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0885
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.6585e-04 - val_loss: 0.0874
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.0894e-04 - val_loss: 0.0870
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.7390e-04 - val_loss: 0.0865
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.6985e-04 - val_loss: 0.0898
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0885
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.7952e-04 - val_loss: 0.0882
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.5850e-04 - val_loss: 0.0880
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.0238e-04 - val_loss: 0.0877
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.5540e-04 - val_loss: 0.0881
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.7850e-04 - val_loss: 0.0870
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.7146e-04 - val_loss: 0.0858
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 9.6002e-04 - val_loss: 0.0870
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0012 - val_loss: 0.0892
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0865
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.8907e-04 - val_loss: 0.0867
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 4.9370e-04 - val_loss: 0.0872
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 4.2973e-04 - val_loss: 0.0858
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 4.2709e-04 - val_loss: 0.0876
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.4382e-04 - val_loss: 0.0887
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.5287e-04 - val_loss: 0.0877
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0874
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0010 - val_loss: 0.0871
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0011 - val_loss: 0.0875
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.9407e-04 - val_loss: 0.0847
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.6428e-04 - val_loss: 0.0861
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.2922e-04 - val_loss: 0.0876
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 5.2722e-04 - val_loss: 0.0860
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.4601e-04 - val_loss: 0.0852
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.2601e-04 - val_loss: 0.0871
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 8.7078e-04 - val_loss: 0.0858
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.8586e-04 - val_loss: 0.0894
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.0367e-04 - val_loss: 0.0883
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 6.7585e-04 - val_loss: 0.0859
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.4159e-04 - val_loss: 0.0869
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 7.4721e-04 - val_loss: 0.0892
# Epoch 161/200
#  16/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 6.7945e-04
