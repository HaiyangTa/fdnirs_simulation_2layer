# %% [markdown]
# ## FD ANN SINGLE DISTANCE (Hb2)

# %%
import sys
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
import pickle
from tqdm import tqdm
! pip install pmcx
from concurrent.futures import ThreadPoolExecutor
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)

# %% [markdown]
# ### Read the saved CSV

# %%
import pandas as pd
import glob
import numpy as np
import sys
! pip install pmcx
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pickle
from sklearn.preprocessing import StandardScaler
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_path = '/content/drive/MyDrive/MCX_data/stage2_train.csv'
final_array = np.loadtxt(csv_path, delimiter=',')
print(final_array.shape)
X_train = final_array
#
csv_path_test = '/content/drive/MyDrive/MCX_data/stage2_test.csv'
final_array = np.loadtxt(csv_path_test, delimiter=',')
print(final_array.shape)
X_test = final_array
# Out:
# (10000, 192)
# (1000, 192)

# %% [markdown]
# ### GT

# %%
GT_folder_train = '/content/drive/MyDrive/MCX_data/stage2_csv/'
GT_folder_test = '/content/drive/MyDrive/MCX_data/test_csv/'

# %%
csv_files_train = glob.glob(os.path.join(GT_folder_train, '*.csv'))
GT_all_train = pd.concat([pd.read_csv(f) for f in csv_files_train], ignore_index=True)
csv_files_test = glob.glob(os.path.join(GT_folder_test, '*.csv'))
GT_all_test = pd.concat([pd.read_csv(f) for f in csv_files_test], ignore_index=True)

# %%
sorted_ids = [i+1 for i in range(10000)]
# Ensure ID column is integer
GT_all_train['ID'] = GT_all_train['ID'].astype(int)

# Filter and sort GT_all to match the sorted_ids order
GT_filtered = GT_all_train[GT_all_train['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()

# Extract HHB2 as Y
Y = GT_filtered['HHB2'].values
y_train = Y.reshape(-1, 1)

# %%
sorted_ids = [i+1 for i in range(1000)]
# Ensure ID column is integer
GT_all_test['ID'] = GT_all_test['ID'].astype(int)

# Filter and sort GT_all to match the sorted_ids order
GT_filtered = GT_all_test[GT_all_test['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()

# Extract HHB2 as Y
Y = GT_filtered['HHB2'].values
y_test = Y.reshape(-1, 1)

# %%
# fit only on training data
scaler_X = StandardScaler().fit(X_train)
scaler_y = StandardScaler().fit(y_train)

# apply (same μ,σ) everywhere
X_train = scaler_X.transform(X_train)
X_test  = scaler_X.transform(X_test)
Y_train = scaler_y.transform(y_train)
Y_test = scaler_y.transform(y_test)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (10000, 192) (1000, 192) (10000, 1) (1000, 1)

# %% [markdown]
# ### Seperate

# %%
import numpy as np
import itertools
from typing import Dict, List, Tuple

def split_24x8_distance_pairs(
    X_train: np.ndarray,         # (N_train, 192)
    X_test:  np.ndarray          # (N_test , 192)
) -> Dict[int, List[np.ndarray]]:
    """
    Build a dictionary for *all two-distance* combinations.
    Each entry contains a 48-feature slice (24 + 24).

    Key convention
    --------------
    12 → distances 1 & 2      (cols 0–23  + 24–47)
    13 → distances 1 & 3      (cols 0–23  + 48–71)
    …
    78 → distances 7 & 8      (cols 144–167 + 168–191)

    Returns
    -------
    pair_dict[key] = [ X_train_pair , X_test_pair ]
        where each array has shape (N, 48)
        and len(pair_dict) == 28  (C(8,2))
    """
    if X_train.shape[1] != 192 or X_test.shape[1] != 192:
        raise ValueError("Expect 192 columns = 8 distances × 24 features.")

    # first slice each single-distance block (N, 24)
    single: Dict[int, Tuple[np.ndarray, np.ndarray]] = {}
    for d in range(1, 9):
        s, e = (d - 1) * 24, d * 24
        single[d] = (X_train[:, s:e], X_test[:, s:e])

    # now build every 2-distance combination
    pair_dict: Dict[int, List[np.ndarray]] = {}
    for a, b in itertools.combinations(range(1, 9), 2):
        key = int(f"{a}{b}")                      # e.g. 12, 37, 78
        Xtr_pair = np.concatenate([single[a][0], single[b][0]], axis=1)  # (N, 48)
        Xte_pair = np.concatenate([single[a][1], single[b][1]], axis=1)  # (N, 48)
        pair_dict[key] = [Xtr_pair, Xte_pair]

    return pair_dict

distance_data = split_24x8_distance_pairs(X_train, X_test)

# %%
len(distance_data)
# Out:
# 28

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.losses import Huber
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint
from pathlib import Path
import joblib, tensorflow as tf
WEIGHT_DIR = Path("/content/drive/MyDrive/MCX_data/weights")

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
Path = '/content/drive/MyDrive/MCX_data/distance_2/'
for idx, (k, v) in enumerate(distance_data.items()):
     model = Sequential([
    Input(shape=(48,)),
    Dense(1000, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(8192*2, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(2048, activation='relu'),
    Dropout(0.2),

    Dense(1024, activation='relu'),
    Dropout(0.2),

    Dense(512, activation='relu'),
    Dropout(0.1),

    Dense(256, activation='relu'),
    Dropout(0.1),

    Dense(64, activation='relu'),
    Dropout(0.1),

    Dense(32, activation='relu'),
    Dropout(0.0),

    Dense(1)
])
     checkpoint_cb = ModelCheckpoint(
    "FD_hhb2_ANN.keras",        # filepath to save to
    monitor="val_loss",     # quantity to monitor
    mode="min",             # we want to minimize val_loss
    save_best_only=True,    # only save when val_loss decreases
    save_weights_only=False # set True if you only want weights
)
     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-5), loss="mse")

     history = model.fit( v[0], Y_train, epochs=200, batch_size=32, validation_split=0.1, verbose=1, callbacks=[checkpoint_cb])
     model = tf.keras.models.load_model("FD_hhb2_ANN.keras")
     y_pred = model.predict(v[1])
     y_pred = np.clip(y_pred, scaler_y.transform(np.array([[15]]))[0][0], scaler_y.transform(np.array([[35]]))[0][0])
     ### rescale
     y_pred = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
     y_test = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()
     mse = mean_squared_error(y_test, y_pred)
     print(f"MSE for distance {k}: {mse}")
     print(f"RMSE for distance {k}: {np.sqrt(mse)}")
     df = pd.DataFrame({
        "y_test" : y_test,
        "y_pred" : y_pred
    })
     df.to_csv(Path + f"distance_{k}_hhb2_FD.csv", index=False)
# Out:
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 67s 199ms/step - loss: 1.0034 - val_loss: 1.0002
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.9812 - val_loss: 0.9996
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 1.0008 - val_loss: 0.9987
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.9887 - val_loss: 0.9984
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 94ms/step - loss: 1.0210 - val_loss: 0.9908
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.9958 - val_loss: 0.9776
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.9641 - val_loss: 1.0426
# Epoch 8/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.9736 - val_loss: 0.9204
# Epoch 9/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.9271 - val_loss: 0.9230
# Epoch 10/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.9323 - val_loss: 0.9297
# Epoch 11/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.9207 - val_loss: 0.9299
# Epoch 12/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.8981 - val_loss: 0.9092
# Epoch 13/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.8991 - val_loss: 0.8873
# Epoch 14/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.8861 - val_loss: 0.9261
# Epoch 15/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.8902 - val_loss: 0.9129
# Epoch 16/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.8659 - val_loss: 0.8912
# Epoch 17/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.8848 - val_loss: 0.8753
# Epoch 18/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.8681 - val_loss: 0.8622
# Epoch 19/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.8390 - val_loss: 0.8560
# Epoch 20/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.8416 - val_loss: 0.8728
# Epoch 21/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.8581 - val_loss: 0.8686
# Epoch 22/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.8294 - val_loss: 0.8067
# Epoch 23/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.8243 - val_loss: 0.7945
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.7985 - val_loss: 0.8016
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.7933 - val_loss: 0.8090
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 87ms/step - loss: 0.8022 - val_loss: 0.7908
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.7818 - val_loss: 0.7674
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.7507 - val_loss: 0.7773
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 94ms/step - loss: 0.7556 - val_loss: 0.7364
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.7419 - val_loss: 0.7495
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.7539 - val_loss: 0.6968
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.7166 - val_loss: 0.7560
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.7186 - val_loss: 0.7100
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.7118 - val_loss: 0.7170
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.7264 - val_loss: 0.7287
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.6997 - val_loss: 0.6872
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6986 - val_loss: 0.6984
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.7185 - val_loss: 0.6747
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.6968 - val_loss: 0.6609
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6752 - val_loss: 0.7052
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 27s 94ms/step - loss: 0.7284 - val_loss: 0.6490
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.6913 - val_loss: 0.6482
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6842 - val_loss: 0.6890
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6666 - val_loss: 0.6977
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6775 - val_loss: 0.6866
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6605 - val_loss: 0.7049
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6522 - val_loss: 0.6633
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.6566 - val_loss: 0.6313
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6627 - val_loss: 0.7249
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.6489 - val_loss: 0.6279
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6295 - val_loss: 0.6495
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6301 - val_loss: 0.6732
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6331 - val_loss: 0.6789
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.6260 - val_loss: 0.6209
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6244 - val_loss: 0.6345
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6211 - val_loss: 0.6732
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6841 - val_loss: 0.7039
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6557 - val_loss: 0.6831
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6140 - val_loss: 0.6713
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6317 - val_loss: 0.6325
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.6263 - val_loss: 0.6202
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6117 - val_loss: 0.6364
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.5970 - val_loss: 0.6134
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6236 - val_loss: 0.6633
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6053 - val_loss: 0.6438
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6053 - val_loss: 0.6574
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6098 - val_loss: 0.6499
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6114 - val_loss: 0.6648
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6051 - val_loss: 0.6136
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5935 - val_loss: 0.6173
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 93ms/step - loss: 0.5919 - val_loss: 0.5957
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5882 - val_loss: 0.6524
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5837 - val_loss: 0.6358
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5860 - val_loss: 0.6050
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.6034 - val_loss: 0.6160
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5827 - val_loss: 0.6017
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5793 - val_loss: 0.6855
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5798 - val_loss: 0.6497
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5812 - val_loss: 0.6092
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5893 - val_loss: 0.6003
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.5744 - val_loss: 0.5938
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5636 - val_loss: 0.6146
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5596 - val_loss: 0.6196
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5681 - val_loss: 0.6090
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.5582 - val_loss: 0.5801
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5332 - val_loss: 0.6045
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5425 - val_loss: 0.6782
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5759 - val_loss: 0.6106
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 87ms/step - loss: 0.5435 - val_loss: 0.5702
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5320 - val_loss: 0.6152
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5450 - val_loss: 0.6182
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5387 - val_loss: 0.6619
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5660 - val_loss: 0.5767
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5350 - val_loss: 0.6128
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5542 - val_loss: 0.6028
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5256 - val_loss: 0.5902
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5287 - val_loss: 0.6173
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5197 - val_loss: 0.5946
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5227 - val_loss: 0.6027
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5265 - val_loss: 0.6051
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5173 - val_loss: 0.5820
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5128 - val_loss: 0.6302
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 29s 103ms/step - loss: 0.5142 - val_loss: 0.5634
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5186 - val_loss: 0.5970
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5095 - val_loss: 0.6369
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5145 - val_loss: 0.6135
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5156 - val_loss: 0.6456
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5218 - val_loss: 0.5956
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4913 - val_loss: 0.6131
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4981 - val_loss: 0.6390
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5046 - val_loss: 0.5978
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5194 - val_loss: 0.6142
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5178 - val_loss: 0.6007
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5003 - val_loss: 0.6689
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4974 - val_loss: 0.5767
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4821 - val_loss: 0.6399
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4764 - val_loss: 0.5915
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4814 - val_loss: 0.6089
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4909 - val_loss: 0.5791
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4795 - val_loss: 0.5976
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4768 - val_loss: 0.5969
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4908 - val_loss: 0.5783
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4774 - val_loss: 0.5965
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4785 - val_loss: 0.5910
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4791 - val_loss: 0.6097
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4566 - val_loss: 0.6194
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5002 - val_loss: 0.6254
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4674 - val_loss: 0.6033
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4795 - val_loss: 0.5822
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4731 - val_loss: 0.6112
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4581 - val_loss: 0.6466
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4527 - val_loss: 0.5856
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4590 - val_loss: 0.6018
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4747 - val_loss: 0.6461
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4751 - val_loss: 0.5991
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4511 - val_loss: 0.6344
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4554 - val_loss: 0.6393
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4578 - val_loss: 0.6195
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4402 - val_loss: 0.6139
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4568 - val_loss: 0.6111
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4622 - val_loss: 0.6138
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4396 - val_loss: 0.6024
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4578 - val_loss: 0.5997
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4596 - val_loss: 0.6866
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4449 - val_loss: 0.5824
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4369 - val_loss: 0.6186
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4756 - val_loss: 0.6521
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4527 - val_loss: 0.6259
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4527 - val_loss: 0.6116
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4253 - val_loss: 0.6890
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4422 - val_loss: 0.6177
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4316 - val_loss: 0.6174
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4451 - val_loss: 0.6077
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4376 - val_loss: 0.5869
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4163 - val_loss: 0.6721
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4310 - val_loss: 0.6072
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4941 - val_loss: 0.6162
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4169 - val_loss: 0.6151
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4230 - val_loss: 0.6189
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4248 - val_loss: 0.6266
# Epoch 161/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4081 - val_loss: 0.6760
# Epoch 162/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4209 - val_loss: 0.6260
# Epoch 163/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3980 - val_loss: 0.6118
# Epoch 164/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3983 - val_loss: 0.6127
# Epoch 165/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4138 - val_loss: 0.6849
# Epoch 166/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4025 - val_loss: 0.6061
# Epoch 167/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4167 - val_loss: 0.6314
# Epoch 168/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4118 - val_loss: 0.6350
# Epoch 169/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.
200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4465 - val_loss: 0.5384
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4629 - val_loss: 0.5565
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4497 - val_loss: 0.5017
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.4587 - val_loss: 0.4884
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.4346 - val_loss: 0.5083
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4480 - val_loss: 0.5046
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4383 - val_loss: 0.5059
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4418 - val_loss: 0.5681
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4435 - val_loss: 0.5576
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4357 - val_loss: 0.5190
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4344 - val_loss: 0.5180
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4240 - val_loss: 0.4900
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4258 - val_loss: 0.5192
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4404 - val_loss: 0.5464
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4436 - val_loss: 0.5254
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4266 - val_loss: 0.5269
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4143 - val_loss: 0.5256
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4234 - val_loss: 0.5036
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4132 - val_loss: 0.5774
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4201 - val_loss: 0.5615
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4060 - val_loss: 0.5777
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4281 - val_loss: 0.5058
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4182 - val_loss: 0.5383
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4105 - val_loss: 0.5222
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3904 - val_loss: 0.5227
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4125 - val_loss: 0.5115
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4145 - val_loss: 0.5006
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4025 - val_loss: 0.5571
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4365 - val_loss: 0.5248
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4073 - val_loss: 0.5244
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4094 - val_loss: 0.5461
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3789 - val_loss: 0.5525
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3953 - val_loss: 0.5227
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4063 - val_loss: 0.5343
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3910 - val_loss: 0.5227
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3696 - val_loss: 0.5367
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3827 - val_loss: 0.5321
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3783 - val_loss: 0.5240
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3803 - val_loss: 0.5416
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3611 - val_loss: 0.5231
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3887 - val_loss: 0.5350
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3681 - val_loss: 0.5022
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3585 - val_loss: 0.5448
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3805 - val_loss: 0.5414
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4202 - val_loss: 0.6167
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4035 - val_loss: 0.5395
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3730 - val_loss: 0.5172
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3865 - val_loss: 0.5587
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3536 - val_loss: 0.5289
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3607 - val_loss: 0.5473
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3535 - val_loss: 0.5554
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3883 - val_loss: 0.5184
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3506 - val_loss: 0.5584
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3494 - val_loss: 0.5199
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3456 - val_loss: 0.5262
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3424 - val_loss: 0.5458
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3339 - val_loss: 0.5550
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3426 - val_loss: 0.5320
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3340 - val_loss: 0.5827
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3354 - val_loss: 0.5655
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3464 - val_loss: 0.5327
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3314 - val_loss: 0.5407
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3527 - val_loss: 0.5991
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3375 - val_loss: 0.5632
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3279 - val_loss: 0.5207
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3192 - val_loss: 0.5938
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3478 - val_loss: 0.5725
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3384 - val_loss: 0.5174
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3022 - val_loss: 0.5554
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3168 - val_loss: 0.5626
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3101 - val_loss: 0.5754
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3080 - val_loss: 0.6120
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3185 - val_loss: 0.5782
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3036 - val_loss: 0.5527
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3219 - val_loss: 0.5852
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2992 - val_loss: 0.5596
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2967 - val_loss: 0.5612
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2981 - val_loss: 0.6062
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2989 - val_loss: 0.5728
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2881 - val_loss: 0.5869
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3022 - val_loss: 0.5618
# Epoch 161/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2846 - val_loss: 0.6045
# Epoch 162/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2929 - val_loss: 0.5914
# Epoch 163/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2956 - val_loss: 0.5359
# Epoch 164/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2870 - val_loss: 0.5823
# Epoch 165/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2802 - val_loss: 0.5706
# Epoch 166/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2806 - val_loss: 0.5938
# Epoch 167/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3048 - val_loss: 0.5739
# Epoch 168/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2781 - val_loss: 0.6158
# Epoch 169/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2605 - val_loss: 0.6266
# Epoch 170/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2520 - val_loss: 0.6019
# Epoch 171/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2641 - val_loss: 0.6240
# Epoch 172/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2734 - val_loss: 0.5909
# Epoch 173/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2589 - val_loss: 0.5799
# Epoch 174/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2433 - val_loss: 0.6017
# Epoch 175/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2790 - val_loss: 0.6042
# Epoch 176/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2757 - val_loss: 0.5687
# Epoch 177/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2570 - val_loss: 0.5799
# Epoch 178/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2983 - val_loss: 0.6005
# Epoch 179/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2567 - val_loss: 0.6099
# Epoch 180/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2801 - val_loss: 0.6130
# Epoch 181/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2420 - val_loss: 0.5980
# Epoch 182/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2550 - val_loss: 0.6437
# Epoch 183/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2903 - val_loss: 0.5980
# Epoch 184/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2590 - val_loss: 0.5868
# Epoch 185/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2376 - val_loss: 0.5879
# Epoch 186/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2598 - val_loss: 0.5789
# Epoch 187/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2175 - val_loss: 0.6108
# Epoch 188/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2550 - val_loss: 0.6209
# Epoch 189/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2915 - val_loss: 0.5926
# Epoch 190/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2467 - val_loss: 0.6060
# Epoch 191/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2618 - val_loss: 0.6954
# Epoch 192/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3693 - val_loss: 0.6000
# Epoch 193/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2545 - val_loss: 0.6097
# Epoch 194/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2372 - val_loss: 0.6178
# Epoch 195/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2414 - val_loss: 0.5984
# Epoch 196/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2125 - val_loss: 0.6300
# Epoch 197/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2231 - val_loss: 0.6246
# Epoch 198/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2527 - val_loss: 0.6396
# Epoch 199/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2422 - val_loss: 0.6106
# Epoch 200/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2213 - val_loss: 0.6356
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step
# MSE for distance 13: 12.598104030245464
# RMSE for distance 13: 3.5493807953283154
# Epoch 1/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 49s 139ms/step - loss: 1.0122 - val_loss: 0.9974
# Epoch 2/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 1.0001 - val_loss: 0.9978
# Epoch 3/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.9811 - val_loss: 0.9825
# Epoch 4/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.9799 - val_loss: 0.9802
# Epoch 5/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.9401 - val_loss: 0.9484
# Epoch 6/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 92ms/step - loss: 0.9012 - val_loss: 0.9004
# Epoch 7/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━
200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4462 - val_loss: 0.4672
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4493 - val_loss: 0.4723
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.4684 - val_loss: 0.4497
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4177 - val_loss: 0.5087
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4257 - val_loss: 0.4991
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4258 - val_loss: 0.5130
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4436 - val_loss: 0.4891
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4266 - val_loss: 0.5085
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4195 - val_loss: 0.4749
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4195 - val_loss: 0.4899
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4172 - val_loss: 0.4813
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4267 - val_loss: 0.4716
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4260 - val_loss: 0.4822
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4150 - val_loss: 0.5147
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4308 - val_loss: 0.5063
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 87ms/step - loss: 0.4089 - val_loss: 0.4445
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4016 - val_loss: 0.5077
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3983 - val_loss: 0.4765
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4101 - val_loss: 0.4875
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4114 - val_loss: 0.4912
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3897 - val_loss: 0.4554
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4013 - val_loss: 0.4548
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4102 - val_loss: 0.4817
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.3973 - val_loss: 0.4436
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3964 - val_loss: 0.4917
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3906 - val_loss: 0.4693
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3823 - val_loss: 0.4728
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3910 - val_loss: 0.5232
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3888 - val_loss: 0.4615
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3835 - val_loss: 0.5006
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3854 - val_loss: 0.4560
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3851 - val_loss: 0.4735
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3722 - val_loss: 0.5004
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3824 - val_loss: 0.4618
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3752 - val_loss: 0.4565
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3694 - val_loss: 0.4578
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3721 - val_loss: 0.4514
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3516 - val_loss: 0.4468
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3590 - val_loss: 0.4652
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3792 - val_loss: 0.4878
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3622 - val_loss: 0.4882
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3640 - val_loss: 0.4560
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3713 - val_loss: 0.4718
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3592 - val_loss: 0.4664
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 89ms/step - loss: 0.3559 - val_loss: 0.4412
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3409 - val_loss: 0.4494
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3214 - val_loss: 0.4899
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3354 - val_loss: 0.4761
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3488 - val_loss: 0.4438
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3451 - val_loss: 0.4678
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3479 - val_loss: 0.5103
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3466 - val_loss: 0.5315
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3542 - val_loss: 0.5037
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3598 - val_loss: 0.4491
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3215 - val_loss: 0.4840
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3295 - val_loss: 0.4912
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3426 - val_loss: 0.4616
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3250 - val_loss: 0.4893
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3169 - val_loss: 0.5038
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3337 - val_loss: 0.4745
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3096 - val_loss: 0.5159
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3075 - val_loss: 0.4846
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3107 - val_loss: 0.4625
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3177 - val_loss: 0.4551
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2998 - val_loss: 0.4558
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2923 - val_loss: 0.4992
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3127 - val_loss: 0.5196
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3326 - val_loss: 0.4850
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3070 - val_loss: 0.4755
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3078 - val_loss: 0.4996
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2948 - val_loss: 0.5395
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2934 - val_loss: 0.4848
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3345 - val_loss: 0.4678
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2761 - val_loss: 0.5080
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3131 - val_loss: 0.4803
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3002 - val_loss: 0.5003
# ...
# Epoch 24/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 24s 87ms/step - loss: 0.5915 - val_loss: 0.5412
# Epoch 25/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5774 - val_loss: 0.7629
# Epoch 26/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.6069 - val_loss: 0.5017
# Epoch 27/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5397 - val_loss: 0.5334
# Epoch 28/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5694 - val_loss: 0.5439
# Epoch 29/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 90ms/step - loss: 0.5691 - val_loss: 0.5012
# Epoch 30/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5393 - val_loss: 0.5134
# Epoch 31/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5373 - val_loss: 0.5081
# Epoch 32/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.4980 - val_loss: 0.4418
# Epoch 33/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5098 - val_loss: 0.4619
# Epoch 34/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5068 - val_loss: 0.4588
# Epoch 35/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4858 - val_loss: 0.4574
# Epoch 36/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.5001 - val_loss: 0.5347
# Epoch 37/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4865 - val_loss: 0.4840
# Epoch 38/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4908 - val_loss: 0.4605
# Epoch 39/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4892 - val_loss: 0.4602
# Epoch 40/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4815 - val_loss: 0.4533
# Epoch 41/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 91ms/step - loss: 0.4628 - val_loss: 0.4122
# Epoch 42/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4569 - val_loss: 0.4300
# Epoch 43/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4498 - val_loss: 0.4123
# Epoch 44/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4418 - val_loss: 0.4940
# Epoch 45/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4642 - val_loss: 0.4394
# Epoch 46/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4411 - val_loss: 0.4158
# Epoch 47/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4138 - val_loss: 0.4284
# Epoch 48/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.4348 - val_loss: 0.4120
# Epoch 49/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4280 - val_loss: 0.4487
# Epoch 50/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4195 - val_loss: 0.4162
# Epoch 51/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4147 - val_loss: 0.4975
# Epoch 52/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.4230 - val_loss: 0.4097
# Epoch 53/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3949 - val_loss: 0.5147
# Epoch 54/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4295 - val_loss: 0.4343
# Epoch 55/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.4135 - val_loss: 0.3917
# Epoch 56/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3925 - val_loss: 0.4131
# Epoch 57/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4138 - val_loss: 0.4291
# Epoch 58/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4037 - val_loss: 0.3939
# Epoch 59/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3992 - val_loss: 0.3953
# Epoch 60/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3926 - val_loss: 0.4240
# Epoch 61/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4074 - val_loss: 0.4785
# Epoch 62/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.4085 - val_loss: 0.4167
# Epoch 63/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3849 - val_loss: 0.4197
# Epoch 64/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3891 - val_loss: 0.4081
# Epoch 65/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3830 - val_loss: 0.4088
# Epoch 66/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3607 - val_loss: 0.4161
# Epoch 67/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3873 - val_loss: 0.4191
# Epoch 68/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - loss: 0.3793 - val_loss: 0.3646
# Epoch 69/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3644 - val_loss: 0.4256
# Epoch 70/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3814 - val_loss: 0.3726
# Epoch 71/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3601 - val_loss: 0.3807
# Epoch 72/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3769 - val_loss: 0.3846
# Epoch 73/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3562 - val_loss: 0.3772
# Epoch 74/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3703 - val_loss: 0.3776
# Epoch 75/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3655 - val_loss: 0.4067
# Epoch 76/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 25s 88ms/step - loss: 0.3761 - val_loss: 0.3591
# Epoch 77/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3464 - val_loss: 0.3800
# Epoch 78/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3442 - val_loss: 0.4007
# Epoch 79/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3595 - val_loss: 0.3919
# Epoch 80/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3506 - val_loss: 0.3814
# Epoch 81/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3604 - val_loss: 0.3905
# Epoch 82/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3613 - val_loss: 0.4217
# Epoch 83/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3393 - val_loss: 0.3901
# Epoch 84/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3432 - val_loss: 0.3878
# Epoch 85/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3445 - val_loss: 0.3718
# Epoch 86/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3421 - val_loss: 0.3850
# Epoch 87/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3561 - val_loss: 0.4050
# Epoch 88/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3479 - val_loss: 0.4850
# Epoch 89/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3578 - val_loss: 0.4287
# Epoch 90/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3429 - val_loss: 0.3802
# Epoch 91/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3367 - val_loss: 0.3844
# Epoch 92/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3274 - val_loss: 0.3890
# Epoch 93/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3649 - val_loss: 0.4071
# Epoch 94/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3216 - val_loss: 0.4186
# Epoch 95/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3349 - val_loss: 0.3721
# Epoch 96/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3134 - val_loss: 0.3942
# Epoch 97/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3202 - val_loss: 0.3822
# Epoch 98/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3229 - val_loss: 0.4004
# Epoch 99/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3183 - val_loss: 0.3898
# Epoch 100/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3287 - val_loss: 0.4188
# Epoch 101/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3233 - val_loss: 0.4017
# Epoch 102/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3240 - val_loss: 0.3984
# Epoch 103/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3141 - val_loss: 0.3667
# Epoch 104/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3272 - val_loss: 0.3825
# Epoch 105/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3135 - val_loss: 0.4641
# Epoch 106/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3167 - val_loss: 0.4128
# Epoch 107/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3244 - val_loss: 0.3959
# Epoch 108/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3092 - val_loss: 0.3846
# Epoch 109/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3017 - val_loss: 0.4330
# Epoch 110/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3058 - val_loss: 0.3986
# Epoch 111/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3039 - val_loss: 0.4094
# Epoch 112/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3031 - val_loss: 0.4036
# Epoch 113/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 24s 87ms/step - loss: 0.3077 - val_loss: 0.3515
# Epoch 114/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2864 - val_loss: 0.3736
# Epoch 115/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2994 - val_loss: 0.4168
# Epoch 116/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2924 - val_loss: 0.4164
# Epoch 117/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2904 - val_loss: 0.3858
# Epoch 118/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3176 - val_loss: 0.4556
# Epoch 119/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2833 - val_loss: 0.3940
# Epoch 120/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2744 - val_loss: 0.3803
# Epoch 121/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2735 - val_loss: 0.4079
# Epoch 122/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2763 - val_loss: 0.4041
# Epoch 123/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2782 - val_loss: 0.3937
# Epoch 124/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2744 - val_loss: 0.4150
# Epoch 125/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2629 - val_loss: 0.3964
# Epoch 126/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2593 - val_loss: 0.3904
# Epoch 127/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3000 - val_loss: 0.4066
# Epoch 128/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2694 - val_loss: 0.4487
# Epoch 129/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2554 - val_loss: 0.3841
# Epoch 130/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2539 - val_loss: 0.4022
# Epoch 131/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2611 - val_loss: 0.3906
# Epoch 132/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2663 - val_loss: 0.4250
# Epoch 133/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2665 - val_loss: 0.3934
# Epoch 134/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2717 - val_loss: 0.3932
# Epoch 135/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2435 - val_loss: 0.4399
# Epoch 136/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2504 - val_loss: 0.4140
# Epoch 137/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2452 - val_loss: 0.4181
# Epoch 138/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2635 - val_loss: 0.3948
# Epoch 139/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2609 - val_loss: 0.4102
# Epoch 140/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2514 - val_loss: 0.4538
# Epoch 141/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2497 - val_loss: 0.4252
# Epoch 142/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2458 - val_loss: 0.3867
# Epoch 143/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2425 - val_loss: 0.4500
# Epoch 144/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2419 - val_loss: 0.4483
# Epoch 145/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2373 - val_loss: 0.4290
# Epoch 146/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2268 - val_loss: 0.4578
# Epoch 147/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2547 - val_loss: 0.4083
# Epoch 148/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2341 - val_loss: 0.4133
# Epoch 149/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2695 - val_loss: 0.4051
# Epoch 150/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2439 - val_loss: 0.3983
# Epoch 151/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2219 - val_loss: 0.3958
# Epoch 152/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2137 - val_loss: 0.4118
# Epoch 153/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2328 - val_loss: 0.4266
# Epoch 154/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2267 - val_loss: 0.4141
# Epoch 155/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2182 - val_loss: 0.4649
# Epoch 156/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2347 - val_loss: 0.4525
# Epoch 157/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2256 - val_loss: 0.4020
# Epoch 158/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2246 - val_loss: 0.4396
# Epoch 159/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2211 - val_loss: 0.4510
# Epoch 160/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2235 - val_loss: 0.4095
# Epoch 161/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2260 - val_loss: 0.4394
# Epoch 162/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2574 - val_loss: 0.4306
# Epoch 163/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2280 - val_loss: 0.4106
# Epoch 164/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2034 - val_loss: 0.4052
# Epoch 165/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2163 - val_loss: 0.3973
# Epoch 166/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2048 - val_loss: 0.4033
# Epoch 167/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1992 - val_loss: 0.4231
# Epoch 168/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2021 - val_loss: 0.4174
# Epoch 169/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1924 - val_loss: 0.4201
# Epoch 170/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2010 - val_loss: 0.4114
# Epoch 171/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1903 - val_loss: 0.4313
# Epoch 172/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2007 - val_loss: 0.4209
# Epoch 173/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2061 - val_loss: 0.4524
# Epoch 174/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2178 - val_loss: 0.4263
# Epoch 175/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1870 - val_loss: 0.4216
# Epoch 176/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2549 - val_loss: 0.4582
# Epoch 177/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1853 - val_loss: 0.4216
# Epoch 178/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1855 - val_loss: 0.4401
# Epoch 179/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1847 - val_loss: 0.4652
# Epoch 180/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2060 - val_loss: 0.4657
# Epoch 181/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2136 - val_loss: 0.5867
# Epoch 182/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2881 - val_loss: 0.4237
# Epoch 183/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2116 - val_loss: 0.4543
# Epoch 184/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1909 - val_loss: 0.4358
# Epoch 185/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1752 - val_loss: 0.4458
# Epoch 186/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1849 - val_loss: 0.4485
# Epoch 187/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1792 - val_loss: 0.4256
# Epoch 188/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2009 - val_loss: 0.4688
# Epoch 189/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1911 - val_loss: 0.4554
# Epoch 190/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2035 - val_loss: 0.4374
# Epoch 191/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1823 - val_loss: 0.5546
# Epoch 192/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.3038 - val_loss: 0.4468
# Epoch 193/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1930 - val_loss: 0.4459
# Epoch 194/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1662 - val_loss: 0.4620
# Epoch 195/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1688 - val_loss: 0.5436
# Epoch 196/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2775 - val_loss: 0.4958
# Epoch 197/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2242 - val_loss: 0.4274
# Epoch 198/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.1836 - val_loss: 0.5347
# Epoch 199/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2220 - val_loss: 0.4379
# Epoch 200/200
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - loss: 0.2388 - val_loss: 0.4832
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step
# MSE for distance 15: 8.359607785778122
# RMSE for distance 15: 2.891298633102109
