# %% [markdown]
# ## TD Abs[HHB2] Fitting

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
! pip install pmcx
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# Collecting pmcx
#   Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Downloading pmcx-0.4.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 41.2 MB/s eta 0:00:00
# Installing collected packages: pmcx
# Successfully installed pmcx-0.4.2

# %%
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Mounted at /content/drive

# %%
from FD_msNIRS_2layers import extract_freq as ef

# %% [markdown]
# ### Read Simulation data

# %%
import os
import pickle
import numpy as np
from pathlib import Path
import os, re

# %%
def matrix_construct(dictt):
    re = np.zeros((64, 1000))
    di = 0
    for k, v in dictt.items():  # eight distances
        TPSF_list = v
        for i in range(8):
            re[di, :] = TPSF_list[i]
            di += 1
    return re

# %%
def load_and_process_all(result_folders):
    """
    Collect every *.pkl* file inside one or many folders, sort them by the
    numeric ID in the filename, and return

        • all_rows  : stacked (n_samples × 96) NumPy array
        • sorted_ids: list[int] with the same order as all_rows

    A filename can be “123.pkl”, “123 (1).pkl”, “123_dup2.pkl”, etc.
    Only the **first** file encountered for each numeric ID is kept.
    """
    # --- 1.  Normalise the input ------------------------------------------------
    if isinstance(result_folders, (str, Path)):
        result_folders = [result_folders]            # allow a single path
    result_folders = [Path(p) for p in result_folders]

    # --- 2.  Collect full paths to every .pkl file ------------------------------
    pkl_paths = []
    for folder in result_folders:
        pkl_paths.extend([p for p in folder.iterdir() if p.suffix == ".pkl"])

    # --- 3.  Build a mapping {numeric_id: first_path_seen} ----------------------
    id_to_path = {}
    for p in pkl_paths:
        # Extract the leading integer part of the filename
        stem = p.stem.split()[0].split("_")[0]       # handles “123”, “123 (1)”, “123_dup2”
        try:
            id_num = int(stem)
        except ValueError:
            continue                                 # skip files like “model.pkl” etc.

        # Keep the first file we see for each ID
        id_to_path.setdefault(id_num, p)

    # --- 4.  Sort by ID ----------------------------------------------------------
    sorted_ids = sorted(id_to_path.keys())
    sorted_paths = [id_to_path[i] for i in sorted_ids]

    # --- 5.  Load & convert each file -------------------------------------------
    rows = []
    for path in sorted_paths:
        with open(path, "rb") as f:
            data_dict = pickle.load(f)
        row = matrix_construct(data_dict)
        rows.append(row)

    #all_rows = np.vstack(rows)
    return rows, sorted_ids

# %%
train_rf = ['/content/drive/MyDrive/MCX_data/stage2_results/']
train_final_array, train_sorted_ids = load_and_process_all(train_rf)
test_rf = ['/content/drive/MyDrive/MCX_data/test_files/']
test_final_array, test_sorted_ids = load_and_process_all(test_rf)

# %%
X_train = np.stack(train_final_array)
X_test = np.stack(test_final_array)
print(X_train.shape, X_test.shape)
# Out:
# (10000, 64, 1000) (1000, 64, 1000)

# %% [markdown]
# ### GT

# %%
GT_folder_train = '/content/drive/MyDrive/MCX_data/stage2_csv/'
csv_files = glob.glob(os.path.join(GT_folder_train, '*.csv'))
GT_all_train = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# Ensure ID column is integer
GT_all_train['ID'] = GT_all_train['ID'].astype(int)

# Filter and sort GT_all to match the sorted_ids order
GT_filtered = GT_all_train[GT_all_train['ID'].isin(train_sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[train_sorted_ids].reset_index()

# Extract HHB2 as Y
Y_train = GT_filtered['HHB2'].values  # numpy array (n_samples,)
Y_train = Y_train.reshape(-1, 1)
print(Y_train.shape)
# Out:
# (10000, 1)

# %%
GT_folder_test = '/content/drive/MyDrive/MCX_data/test_csv/'
csv_files = glob.glob(os.path.join(GT_folder_test, '*.csv'))
GT_all_test = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

GT_all_test['ID'] = GT_all_test['ID'].astype(int)

GT_filtered = GT_all_test[GT_all_test['ID'].isin(test_sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[test_sorted_ids].reset_index()

Y_test = GT_filtered['HHB2'].values  # numpy array (n_samples,)
Y_test = Y_test.reshape(-1, 1)
print(Y_test.shape)
# Out:
# (1000, 1)

# %% [markdown]
# #### scale X and Y

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import joblib                      # ← optional: to save the scalers

# ---------------------------------------------------------------
# X_train, X_test  shape : (N, 64, 1000)
# Y_train, Y_test  shape : (N,)  or  (N,1)
# ---------------------------------------------------------------

# 1️⃣  flatten along the last two dims → 2-D matrix
Ntr, C, L = X_train.shape
Nte       = X_test.shape[0]

scaler_X = StandardScaler()

X_train = scaler_X.fit_transform(X_train.reshape(Ntr, -1)) \
                  .reshape(Ntr, C, L)

X_test  = scaler_X.transform(X_test.reshape(Nte, -1)) \
                  .reshape(Nte, C, L)

# 2️⃣  scale targets  (make them 2-D for the scaler)
scaler_y  = StandardScaler()

Y_train = scaler_y.fit_transform(Y_train.reshape(-1, 1)).ravel()
Y_test  = scaler_y.transform(Y_test.reshape(-1, 1)).ravel()

# %%
import numpy as np
from pathlib import Path

pth = '/content/drive/MyDrive/MCX_data/weights_td/'

joblib.dump(scaler_X, pth+"scaler_X.pkl")
joblib.dump(scaler_y, pth+"scaler_y.pkl")


SAVE_DIR = Path("/content/drive/MyDrive/MCX_data/splits")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

# ------------------------------------------------------------------
# Option A – single compressed file  (recommended)
# ------------------------------------------------------------------
np.savez_compressed(
    SAVE_DIR / "train_test_split.npz",
    X_train=X_train,
    X_test=X_test,
    Y_train=Y_train,
    Y_test=Y_test,
)
print("Arrays saved →", SAVE_DIR / "train_test_split.npz")

# ---- load later ----
data    = np.load(SAVE_DIR / "train_test_split.npz", allow_pickle=False)
X_train = data["X_train"]
X_test  = data["X_test"]
Y_train = data["Y_train"]
Y_test  = data["Y_test"]

# ------------------------------------------------------------------
# Option B – four separate .npy files
# ------------------------------------------------------------------
# np.save(SAVE_DIR / "X_train.npy", X_train)
# np.save(SAVE_DIR / "X_test.npy",  X_test)
# np.save(SAVE_DIR / "Y_train.npy", Y_train)
# np.save(SAVE_DIR / "Y_test.npy",  Y_test)

# ---- load later ----
# X_train = np.load(SAVE_DIR / "X_train.npy")
# X_test  = np.load(SAVE_DIR / "X_test.npy")
# Y_train = np.load(SAVE_DIR / "Y_train.npy")
# Y_test  = np.load(SAVE_DIR / "Y_test.npy")
# Out:
# Arrays saved → /content/drive/MyDrive/MCX_data/splits/train_test_split.npz

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (10000, 64, 1000) (1000, 64, 1000) (10000,) (1000,)

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Add,
    MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
)
from pathlib import Path
import joblib, tensorflow as tf


def residual_block(x, filters, kernel_size=(5, 5), downsample=False, dropout_rate=0.0):
    shortcut = x

    # First conv
    x = Conv2D(filters, kernel_size, padding='same', strides=(2, 2) if downsample else (1, 1))(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    # Second conv
    x = Conv2D(filters, kernel_size, padding='same')(x)

    # Shortcut path
    if downsample or shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, (1, 1), strides=(2, 2) if downsample else (1, 1), padding='same')(shortcut)

    # Merge
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# Input
input_tensor = Input(shape=(64, 1000, 1))

# Initial Conv Layer
x = Conv2D(32, (3, 3), padding='same', activation='relu')(input_tensor)
x = MaxPooling2D(pool_size=(2, 2))(x)

# Residual Blocks
x = residual_block(x, 128, downsample=True, dropout_rate=0.0)
x = residual_block(x, 128)

x = residual_block(x, 128, downsample=True, dropout_rate=0.0)
x = residual_block(x, 128)

x = residual_block(x, 256, downsample=True, dropout_rate=0.0)
x = residual_block(x, 256)

# Global Average Pooling
x = GlobalAveragePooling2D()(x)

# Dense Head
x = Dense(128, activation='relu')(x)
x = Dropout(0.0)(x)
x = Dense(64, activation='relu')(x)
x = Dense(1)(x)

# Build model
resnet_model = Model(inputs=input_tensor, outputs=x)

# 1) Create a checkpoint callback that saves the best model:
checkpoint_cb = ModelCheckpoint(
    "TD_hhb2_CNN.keras",        # filepath to save to
    monitor="val_loss",     # quantity to monitor
    mode="min",             # we want to minimize val_loss
    save_best_only=True,    # only save when val_loss decreases
    save_weights_only=False # set True if you only want weights
)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
resnet_model.compile(optimizer=optimizer, loss="mse")

# 3) Fit with the checkpoint callback
history = resnet_model.fit(
    X_train, Y_train,
    epochs=200,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    callbacks=[checkpoint_cb]
)

# 4) Later on (or in a new script), load the best model:
model = tf.keras.models.load_model("TD_hhb2_CNN.keras")
# Out:
# Epoch 1/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 38s 72ms/step - loss: 0.8540 - val_loss: 0.5573
# Epoch 2/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.4576 - val_loss: 0.3556
# Epoch 3/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.3466 - val_loss: 0.2840
# Epoch 4/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.2666 - val_loss: 0.2676
# Epoch 5/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.2400 - val_loss: 0.1754
# Epoch 6/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.1850 - val_loss: 0.1844
# Epoch 7/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.1470 - val_loss: 0.1391
# Epoch 8/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.1228 - val_loss: 0.1221
# Epoch 9/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.1257 - val_loss: 0.1955
# Epoch 10/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.1158 - val_loss: 0.0960
# Epoch 11/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.0973 - val_loss: 0.0943
# Epoch 12/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.1074 - val_loss: 0.1033
# Epoch 13/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0856 - val_loss: 0.1801
# Epoch 14/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0874 - val_loss: 0.1022
# Epoch 15/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.0856 - val_loss: 0.0888
# Epoch 16/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0726 - val_loss: 0.1295
# Epoch 17/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.0785 - val_loss: 0.0833
# Epoch 18/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - loss: 0.0648 - val_loss: 0.0798
# Epoch 19/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0600 - val_loss: 0.1712
# Epoch 20/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0678 - val_loss: 0.0960
# Epoch 21/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.0612 - val_loss: 0.0683
# Epoch 22/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0537 - val_loss: 0.0891
# Epoch 23/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0715 - val_loss: 0.1531
# Epoch 24/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0643 - val_loss: 0.0810
# Epoch 25/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 34ms/step - loss: 0.0513 - val_loss: 0.0650
# Epoch 26/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0443 - val_loss: 0.0722
# Epoch 27/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0462 - val_loss: 0.0697
# Epoch 28/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0457 - val_loss: 0.0708
# Epoch 29/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0520 - val_loss: 0.0832
# Epoch 30/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0444 - val_loss: 0.0673
# Epoch 31/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0395 - val_loss: 0.0659
# Epoch 32/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.0430 - val_loss: 0.0625
# Epoch 33/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0380 - val_loss: 0.0787
# Epoch 34/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0422 - val_loss: 0.0631
# Epoch 35/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.0342 - val_loss: 0.0608
# Epoch 36/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0363 - val_loss: 0.0989
# Epoch 37/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0420 - val_loss: 0.0657
# Epoch 38/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0339 - val_loss: 0.0614
# Epoch 39/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0359 - val_loss: 0.0758
# Epoch 40/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0370 - val_loss: 0.0714
# Epoch 41/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0319 - val_loss: 0.0676
# Epoch 42/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0290 - val_loss: 0.0956
# Epoch 43/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0361 - val_loss: 0.0804
# Epoch 44/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0293 - val_loss: 0.0725
# Epoch 45/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0333 - val_loss: 0.0631
# Epoch 46/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0292 - val_loss: 0.0688
# Epoch 47/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0243 - val_loss: 0.0736
# Epoch 48/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0285 - val_loss: 0.0640
# Epoch 49/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0271 - val_loss: 0.0665
# Epoch 50/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0286 - val_loss: 0.0629
# Epoch 51/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0284 - val_loss: 0.0609
# Epoch 52/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0256 - val_loss: 0.0638
# Epoch 53/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0283 - val_loss: 0.0688
# Epoch 54/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0225 - val_loss: 0.0705
# Epoch 55/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0255 - val_loss: 0.0649
# Epoch 56/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0231 - val_loss: 0.0639
# Epoch 57/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0282 - val_loss: 0.0648
# Epoch 58/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 33ms/step - loss: 0.0200 - val_loss: 0.0551
# Epoch 59/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0196 - val_loss: 0.0659
# Epoch 60/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0249 - val_loss: 0.0627
# Epoch 61/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0233 - val_loss: 0.0617
# Epoch 62/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0192 - val_loss: 0.0639
# Epoch 63/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0179 - val_loss: 0.0883
# Epoch 64/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0200 - val_loss: 0.0691
# Epoch 65/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0193 - val_loss: 0.0586
# Epoch 66/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0160 - val_loss: 0.0667
# Epoch 67/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0177 - val_loss: 0.0616
# Epoch 68/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0177 - val_loss: 0.0619
# Epoch 69/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0170 - val_loss: 0.0643
# Epoch 70/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0157 - val_loss: 0.0639
# Epoch 71/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0157 - val_loss: 0.0784
# Epoch 72/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0178 - val_loss: 0.0599
# Epoch 73/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0120 - val_loss: 0.0625
# Epoch 74/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0173 - val_loss: 0.0727
# Epoch 75/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0199 - val_loss: 0.0574
# Epoch 76/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0126 - val_loss: 0.0655
# Epoch 77/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0110 - val_loss: 0.0636
# Epoch 78/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0141 - val_loss: 0.0605
# Epoch 79/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0142 - val_loss: 0.0627
# Epoch 80/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0130 - val_loss: 0.0664
# Epoch 81/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0160 - val_loss: 0.0642
# Epoch 82/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0124 - val_loss: 0.0606
# Epoch 83/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0102 - val_loss: 0.0680
# Epoch 84/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0111 - val_loss: 0.0649
# Epoch 85/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0114 - val_loss: 0.0631
# Epoch 86/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0126 - val_loss: 0.0650
# Epoch 87/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0115 - val_loss: 0.0579
# Epoch 88/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0089 - val_loss: 0.0769
# Epoch 89/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0107 - val_loss: 0.0669
# Epoch 90/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0116 - val_loss: 0.0663
# Epoch 91/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0099 - val_loss: 0.0680
# Epoch 92/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0095 - val_loss: 0.0736
# Epoch 93/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0088 - val_loss: 0.0686
# Epoch 94/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0124 - val_loss: 0.0664
# Epoch 95/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0106 - val_loss: 0.0604
# Epoch 96/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0083 - val_loss: 0.0640
# Epoch 97/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0082 - val_loss: 0.0717
# Epoch 98/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0103 - val_loss: 0.0672
# Epoch 99/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0081 - val_loss: 0.0672
# Epoch 100/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0092 - val_loss: 0.0627
# Epoch 101/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0074 - val_loss: 0.0768
# Epoch 102/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0105 - val_loss: 0.0646
# Epoch 103/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0068 - val_loss: 0.0649
# Epoch 104/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0076 - val_loss: 0.0725
# Epoch 105/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0088 - val_loss: 0.0672
# Epoch 106/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0088 - val_loss: 0.0680
# Epoch 107/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0061 - val_loss: 0.0644
# Epoch 108/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0071 - val_loss: 0.0639
# Epoch 109/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0074 - val_loss: 0.0649
# Epoch 110/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0073 - val_loss: 0.0668
# Epoch 111/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0079 - val_loss: 0.0652
# Epoch 112/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0060 - val_loss: 0.0614
# Epoch 113/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0083 - val_loss: 0.0669
# Epoch 114/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0060 - val_loss: 0.0657
# Epoch 115/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0076 - val_loss: 0.0635
# Epoch 116/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0061 - val_loss: 0.0637
# Epoch 117/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0076 - val_loss: 0.0683
# Epoch 118/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0052 - val_loss: 0.0681
# Epoch 119/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0079 - val_loss: 0.0753
# Epoch 120/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0086 - val_loss: 0.0688
# Epoch 121/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0077 - val_loss: 0.0632
# Epoch 122/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0046 - val_loss: 0.0650
# Epoch 123/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0040 - val_loss: 0.0669
# Epoch 124/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0057 - val_loss: 0.0655
# Epoch 125/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0055 - val_loss: 0.0695
# Epoch 126/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0066 - val_loss: 0.0690
# Epoch 127/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0066 - val_loss: 0.0758
# Epoch 128/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0074 - val_loss: 0.0707
# Epoch 129/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0059 - val_loss: 0.0688
# Epoch 130/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0046 - val_loss: 0.0677
# Epoch 131/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0050 - val_loss: 0.0658
# Epoch 132/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0049 - val_loss: 0.0661
# Epoch 133/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0053 - val_loss: 0.0650
# Epoch 134/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0047 - val_loss: 0.0683
# Epoch 135/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0044 - val_loss: 0.0688
# Epoch 136/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0044 - val_loss: 0.0670
# Epoch 137/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0075 - val_loss: 0.0675
# Epoch 138/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0045 - val_loss: 0.0709
# Epoch 139/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0065 - val_loss: 0.0656
# Epoch 140/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0035 - val_loss: 0.0683
# Epoch 141/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0043 - val_loss: 0.0682
# Epoch 142/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0065 - val_loss: 0.0674
# Epoch 143/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0040 - val_loss: 0.0689
# Epoch 144/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0031 - val_loss: 0.0676
# Epoch 145/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0067 - val_loss: 0.0655
# Epoch 146/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0040 - val_loss: 0.0762
# Epoch 147/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0063 - val_loss: 0.0692
# Epoch 148/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0040 - val_loss: 0.0679
# Epoch 149/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0039 - val_loss: 0.0735
# Epoch 150/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0081 - val_loss: 0.0708
# Epoch 151/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0062 - val_loss: 0.0691
# Epoch 152/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0037 - val_loss: 0.0647
# Epoch 153/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0026 - val_loss: 0.0702
# Epoch 154/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0041 - val_loss: 0.0674
# Epoch 155/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0032 - val_loss: 0.0679
# Epoch 156/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0040 - val_loss: 0.0758
# Epoch 157/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0057 - val_loss: 0.0714
# Epoch 158/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0050 - val_loss: 0.0713
# Epoch 159/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0037 - val_loss: 0.0696
# Epoch 160/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0038 - val_loss: 0.0693
# Epoch 161/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0039 - val_loss: 0.0694
# Epoch 162/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0036 - val_loss: 0.0731
# Epoch 163/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0066 - val_loss: 0.0733
# Epoch 164/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0052 - val_loss: 0.0682
# Epoch 165/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0041 - val_loss: 0.0653
# Epoch 166/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0028 - val_loss: 0.0690
# Epoch 167/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0032 - val_loss: 0.0705
# Epoch 168/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0048 - val_loss: 0.0687
# Epoch 169/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0071 - val_loss: 0.0664
# Epoch 170/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0031 - val_loss: 0.0698
# Epoch 171/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0058 - val_loss: 0.0734
# Epoch 172/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0034 - val_loss: 0.0674
# Epoch 173/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0031 - val_loss: 0.0735
# Epoch 174/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0039 - val_loss: 0.0697
# Epoch 175/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0028 - val_loss: 0.0676
# Epoch 176/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0034 - val_loss: 0.0679
# Epoch 177/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0032 - val_loss: 0.0675
# Epoch 178/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0032 - val_loss: 0.0691
# Epoch 179/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0037 - val_loss: 0.0701
# Epoch 180/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0054 - val_loss: 0.0680
# Epoch 181/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0040 - val_loss: 0.0679
# Epoch 182/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0031 - val_loss: 0.0705
# Epoch 183/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0042 - val_loss: 0.0690
# Epoch 184/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0029 - val_loss: 0.0685
# Epoch 185/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0025 - val_loss: 0.0681
# Epoch 186/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0033 - val_loss: 0.0715
# Epoch 187/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0040 - val_loss: 0.0680
# Epoch 188/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0036 - val_loss: 0.0708
# Epoch 189/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0041 - val_loss: 0.0710
# Epoch 190/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0035 - val_loss: 0.0701
# Epoch 191/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0023 - val_loss: 0.0695
# Epoch 192/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0030 - val_loss: 0.0725
# Epoch 193/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0032 - val_loss: 0.0728
# Epoch 194/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0039 - val_loss: 0.0690
# Epoch 195/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0028 - val_loss: 0.0736
# Epoch 196/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0040 - val_loss: 0.0741
# Epoch 197/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0027 - val_loss: 0.0685
# Epoch 198/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0024 - val_loss: 0.0702
# Epoch 199/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0040 - val_loss: 0.0709
# Epoch 200/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0036 - val_loss: 0.0717
# Epoch 201/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0027 - val_loss: 0.0700
# Epoch 202/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0067 - val_loss: 0.0697
# Epoch 203/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0039 - val_loss: 0.0722
# Epoch 204/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0020 - val_loss: 0.0699
# Epoch 205/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0018 - val_loss: 0.0715
# Epoch 206/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0019 - val_loss: 0.0715
# Epoch 207/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0021 - val_loss: 0.0738
# Epoch 208/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0032 - val_loss: 0.0707
# Epoch 209/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0037 - val_loss: 0.0713
# Epoch 210/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0030 - val_loss: 0.0706
# Epoch 211/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0029 - val_loss: 0.0710
# Epoch 212/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0022 - val_loss: 0.0713
# Epoch 213/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0036 - val_loss: 0.0705
# Epoch 214/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0036 - val_loss: 0.0741
# Epoch 215/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0033 - val_loss: 0.0690
# Epoch 216/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0023 - val_loss: 0.0720
# Epoch 217/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0018 - val_loss: 0.0702
# Epoch 218/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0017 - val_loss: 0.0717
# Epoch 219/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0032 - val_loss: 0.0701
# Epoch 220/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0035 - val_loss: 0.0688
# Epoch 221/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0026 - val_loss: 0.0686
# Epoch 222/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0019 - val_loss: 0.0703
# Epoch 223/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0020 - val_loss: 0.0696
# Epoch 224/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0029 - val_loss: 0.0712
# Epoch 225/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0031 - val_loss: 0.0738
# Epoch 226/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0035 - val_loss: 0.0748
# Epoch 227/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0026 - val_loss: 0.0747
# Epoch 228/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0027 - val_loss: 0.0734
# Epoch 229/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0025 - val_loss: 0.0704
# Epoch 230/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0024 - val_loss: 0.0713
# Epoch 231/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0015 - val_loss: 0.0714
# Epoch 232/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0030 - val_loss: 0.0722
# Epoch 233/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0021 - val_loss: 0.0734
# Epoch 234/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0029 - val_loss: 0.0723
# Epoch 235/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0026 - val_loss: 0.0768
# Epoch 236/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0038 - val_loss: 0.0719
# Epoch 237/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0024 - val_loss: 0.0729
# Epoch 238/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0020 - val_loss: 0.0735
# Epoch 239/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0041 - val_loss: 0.0733
# Epoch 240/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0027 - val_loss: 0.0716
# Epoch 241/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0020 - val_loss: 0.0726
# Epoch 242/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0038 - val_loss: 0.0733
# Epoch 243/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0025 - val_loss: 0.0730
# Epoch 244/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0016 - val_loss: 0.0730
# Epoch 245/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0018 - val_loss: 0.0730
# Epoch 246/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0022 - val_loss: 0.0747
# Epoch 247/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0031 - val_loss: 0.0749
# Epoch 248/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0035 - val_loss: 0.0713
# Epoch 249/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0021 - val_loss: 0.0727
# Epoch 250/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0029 - val_loss: 0.0776
# Epoch 251/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0030 - val_loss: 0.0777
# Epoch 252/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0025 - val_loss: 0.0746
# Epoch 253/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0018 - val_loss: 0.0792
# Epoch 254/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0027 - val_loss: 0.0736
# Epoch 255/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0016 - val_loss: 0.0752
# Epoch 256/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0045 - val_loss: 0.0735
# Epoch 257/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0026 - val_loss: 0.0719
# Epoch 258/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0022 - val_loss: 0.0755
# Epoch 259/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0023 - val_loss: 0.0727
# Epoch 260/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0018 - val_loss: 0.0737
# Epoch 261/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0018 - val_loss: 0.0723
# Epoch 262/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0013 - val_loss: 0.0742
# Epoch 263/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0031 - val_loss: 0.0716
# Epoch 264/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0029 - val_loss: 0.0741
# Epoch 265/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0027 - val_loss: 0.0765
# Epoch 266/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0029 - val_loss: 0.0735
# Epoch 267/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0016 - val_loss: 0.0742
# Epoch 268/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0018 - val_loss: 0.0748
# Epoch 269/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0028 - val_loss: 0.0741
# Epoch 270/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0027 - val_loss: 0.0762
# Epoch 271/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0019 - val_loss: 0.0759
# Epoch 272/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0023 - val_loss: 0.0728
# Epoch 273/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0015 - val_loss: 0.0732
# Epoch 274/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0017 - val_loss: 0.0724
# Epoch 275/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0020 - val_loss: 0.0729
# Epoch 276/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0026 - val_loss: 0.0761
# Epoch 277/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0024 - val_loss: 0.0731
# Epoch 278/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0020 - val_loss: 0.0768
# Epoch 279/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0022 - val_loss: 0.0744
# Epoch 280/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0022 - val_loss: 0.0772
# Epoch 281/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0025 - val_loss: 0.0749
# Epoch 282/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0017 - val_loss: 0.0752
# Epoch 283/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0016 - val_loss: 0.0738
# Epoch 284/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0015 - val_loss: 0.0750
# Epoch 285/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0018 - val_loss: 0.0755
# Epoch 286/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0020 - val_loss: 0.0758
# Epoch 287/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0022 - val_loss: 0.0772
# Epoch 288/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0027 - val_loss: 0.0749
# Epoch 289/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0020 - val_loss: 0.0729
# Epoch 290/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0014 - val_loss: 0.0759
# Epoch 291/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0020 - val_loss: 0.0740
# Epoch 292/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0013 - val_loss: 0.0735
# Epoch 293/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0017 - val_loss: 0.0746
# Epoch 294/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0019 - val_loss: 0.0741
# Epoch 295/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0025 - val_loss: 0.0760
# Epoch 296/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0018 - val_loss: 0.0748
# Epoch 297/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0018 - val_loss: 0.0755
# Epoch 298/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 31ms/step - loss: 0.0043 - val_loss: 0.0768
# Epoch 299/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0020 - val_loss: 0.0757
# Epoch 300/300
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 9s 32ms/step - loss: 0.0014 - val_loss: 0.0733

# %%
WEIGHT_DIR = Path("/content/drive/MyDrive/MCX_data/weights_td/")
WEIGHT_DIR.mkdir(parents=True, exist_ok=True)
model_path = WEIGHT_DIR / "TD_hhb2_CNN.keras"
model.save(model_path)

print("model file exists:", model_path.exists(),
      "size =", model_path.stat().st_size/1e6, "MB")
# Out:
# model file exists: True size = 105.794187 MB

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 1000,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 1000,  │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 500,   │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 250,   │    102,528 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 16, 250,   │          0 │ conv2d_1[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16, 250,   │          0 │ activation[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 250,   │    409,728 │ dropout[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 250,   │      4,224 │ max_pooling2d[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 250,   │          0 │ conv2d_2[0][0],   │
# │                     │ 128)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 16, 250,   │          0 │ add[0][0]         │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 250,   │    409,728 │ activation_1[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 16, 250,   │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16, 250,   │          0 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 250,   │    409,728 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 250,   │          0 │ conv2d_5[0][0],   │
# │                     │ 128)              │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 16, 250,   │          0 │ add_1[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 125,    │    409,728 │ activation_3[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 8, 125,    │          0 │ conv2d_6[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, 125,    │          0 │ activation_4[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 125,    │    409,728 │ dropout_2[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 125,    │     16,512 │ activation_3[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 8, 125,    │          0 │ conv2d_7[0][0],   │
# │                     │ 128)              │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 8, 125,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 125,    │    409,728 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 8, 125,    │          0 │ conv2d_9[0][0]    │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 8, 125,    │          0 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 8, 125,    │    409,728 │ dropout_3[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 8, 125,    │          0 │ conv2d_10[0][0],  │
# │                     │ 128)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 8, 125,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 4, 63,     │    819,456 │ activation_7[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 4, 63,     │          0 │ conv2d_11[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 4, 63,     │          0 │ activation_8[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 4, 63,     │  1,638,656 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 4, 63,     │     33,024 │ activation_7[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 4, 63,     │          0 │ conv2d_12[0][0],  │
# │                     │ 256)              │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 4, 63,     │          0 │ add_4[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 4, 63,     │  1,638,656 │ activation_9[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 4, 63,     │          0 │ conv2d_14[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 4, 63,     │          0 │ activation_10[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 4, 63,     │  1,638,656 │ dropout_5[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 4, 63,     │          0 │ conv2d_15[0][0],  │
# │                     │ 256)              │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 4, 63,     │          0 │ add_5[0][0]       │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_11[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │         65 │ dense_1[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,404,037 (100.72 MB)
#  Trainable params: 8,801,345 (33.57 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 17,602,692 (67.15 MB)

# %%
# Predict and evaluate
y_pred = resnet_model.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)
print(f"Test MSE: {mse:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step
# Test MSE: 2.3120

# %%
# Randomly select 100 indices
import numpy as np
import matplotlib.pyplot as plt

indices = np.random.choice(len(Y_test), size=100, replace=False)
indices = np.sort(indices)

y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
y_test_rescaled = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()

# Extract corresponding values
y_test_sampled = y_test_rescaled[indices]
y_pred_sampled = y_pred_rescaled[indices]

# Plot with circular markers
plt.figure(figsize=(16, 8))
plt.plot(y_test_sampled, 'r-o', label='Ground Truth (Hb2)', linewidth=2, markersize=5)
plt.plot(y_pred_sampled, 'b--o', label='Predicted (Hb2)', linewidth=2, markersize=5)
plt.xlabel('Random Sample Index')
plt.ylabel('Hb2')
plt.title('Randomly Sampled Predictions vs Ground Truth')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Compute residuals in original scale
residuals = y_pred_rescaled - y_test_rescaled

mse_rescaled = mean_squared_error(y_pred_rescaled, y_test_rescaled)
print(f"Test MSE (original scale): {mse_rescaled:.4f}")

# Plot residuals
plt.figure(figsize=(16, 8))
plt.scatter(range(len(residuals)), residuals, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.title("Residuals (Predicted - Ground Truth)")
plt.ylabel("Residual")
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE (original scale): 77.0670

# %%
# Compute relative error (percentage)
relative_error = ((y_pred_rescaled - y_test_rescaled) / y_test_rescaled) * 100

# Plot relative error
plt.figure(figsize=(16, 8))
plt.scatter(range(len(relative_error)), relative_error, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.ylabel("Relative Error (%)")
plt.yticks(np.arange(-100, 101, 10))
plt.ylim(-100, 100)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Prepare DataFrame for seaborn
df_plot = pd.DataFrame({
    'Relative Error (%)': relative_error.flatten()
})

plt.figure(figsize=(10, 10))
sns.violinplot(data=df_plot, y='Relative Error (%)', inner=None, linewidth=1.2)
sns.stripplot(data=df_plot, y='Relative Error (%)', color='black', alpha=0.4, jitter=0.2, size=3)

plt.axhline(0, color='r', linestyle='--', linewidth=1)
plt.ylim(-100, 100)
plt.title('Distribution of Relative Error (%)')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_percentage_error

plt.figure(figsize=(10,10))
plt.scatter(y_test_rescaled, y_pred_rescaled, alpha=0.6)
lims = [min(y_test_rescaled.min(), y_pred_rescaled.min()),
        max(y_test_rescaled.max(), y_pred_rescaled.max())]
plt.plot(lims, lims, 'k--')              # identity line
plt.xlabel('Ground-truth Hb2'); plt.ylabel('Predicted Hb2')
plt.title('Parity plot')
plt.axis('square'); plt.xlim(lims); plt.ylim(lims)
plt.grid()
print("R² =", r2_score(y_test_rescaled, y_pred_rescaled))
print("MAPE =", mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)*100, "%")
plt.show()
# Out:
# R² = -1.311598820363506
# MAPE = 3.186186155809755 %

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_percentage_error

# ------------------------------------------------------------------
# original arrays
x = y_test_rescaled.ravel()     # ground-truth
y = y_pred_rescaled.ravel()     # prediction
# ------------------------------------------------------------------

# 1️⃣  3-sigma filter on residuals
mask = np.abs(zscore(y - x)) < 3
x_in, y_in = x[mask], y[mask]

# 2️⃣  parity plot
fig, ax = plt.subplots(figsize=(10, 10), dpi=300)   # ← 10×10 inches

rmse = np.sqrt(mean_squared_error(x, y))
mare = mean_absolute_percentage_error(x, y) * 100
ax.text(0.05, 0.95,
        f'RMSE = {rmse:.2e}\nMARE = {mare:.2f} %',
        transform=ax.transAxes, ha='left', va='top',
        fontsize=12, color='darkred')

ax.scatter(x_in, y_in, s=14, alpha=0.7)
lims = [min(x_in.min(), y_in.min()), max(x_in.max(), y_in.max())]
ax.plot(lims, lims, 'k--', lw=1)
ax.set_xlim(lims); ax.set_ylim(lims)
ax.set_aspect('equal', adjustable='box')
ax.set_xlabel('Ground-truth Hb2')
ax.set_ylabel('Predicted Hb2')
ax.grid(alpha=0.3)

# 3️⃣  metrics on filtered set
print("kept", mask.sum(), "of", len(x), "points")
print("R²   =", r2_score(x_in, y_in))
print("MAPE =", mean_absolute_percentage_error(x_in, y_in)*100, "%")

fig.tight_layout()
plt.show()
# Out:
# kept 998 of 1000 points
# R²   = 0.9804626303000036
# MAPE = 1.8028871385974272 %

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(10, 6))
sns.violinplot(y=relative_error, inner=None, color='skyblue', cut=0)
sns.stripplot(y=relative_error, color='black', alpha=0.05, jitter=0.3, size=2)

plt.axhline(0, color='red', linestyle='--', linewidth=1.2)
plt.title('Distribution of Relative Error (%)')
plt.ylabel('Relative Error (%)')
plt.grid()
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# ── Sort by ground-truth values (ascending) ───────────────────────────────
sorted_idx       = np.argsort(y_test_rescaled)         # indices that sort y_test
y_test_sorted    = y_test_rescaled[sorted_idx]
y_pred_sorted    = y_pred_rescaled[sorted_idx]

# ── Plot both curves with matching order ──────────────────────────────────
plt.figure(figsize=(16, 8))
plt.plot(y_test_sorted, 'r-o',  label='Ground Truth (Hb2)', linewidth=2, markersize=5)
plt.plot(y_pred_sorted, 'b--o', label='Predicted (Hb2)',   linewidth=2, markersize=5)
plt.xlabel('Sample (sorted by ground-truth Hb2)')
plt.ylabel('Hb2')
plt.title('Predictions vs Ground Truth (sorted by Hb2)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# Ensure y_true and y_pred are 1D numpy arrays
y_true = np.asarray(y_test_rescaled).ravel()
y_pred =np.asarray(y_pred_rescaled).ravel()

# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# Plot
plt.figure(figsize=(10, 10))
plt.hist2d(y_true, y_pred, bins=100, cmap='Blues', cmin=1)

# Plot identity line
plt.plot([min(y_true), max(y_true)],
         [min(y_true), max(y_true)],
         'k--', lw=1)

# Labels and title
plt.xlabel('Expected $[Hb2]$')
plt.ylabel('Predicted $[Hb2]$')
plt.title(r'$S$')

# Annotate RMSE
plt.text(0.05, 0.95, f'RMSE: {rmse:.2e}', color='darkred',
         fontsize=14, transform=plt.gca().transAxes, va='top')

plt.colorbar(label='Density')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib.ticker import FuncFormatter
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from scipy.stats import zscore

# ── 0 │  flatten + 3-σ outlier filter  ─────────────────────────────────────────
y_true = np.asarray(y_test_rescaled).ravel()   # ground truth
y_pred = np.asarray(y_pred_rescaled).ravel()   # model prediction

mask   = np.abs(zscore(y_pred - y_true)) < 3   # keep inliers only
x, y   = y_true[mask], y_pred[mask]            # filtered data for the plot

# ── 1 │  metrics (use full set or filtered—here full)  ─────────────────────────
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mare = mean_absolute_percentage_error(y_true, y_pred) * 100    # %

# ── 2 │  parity plot with 2-D log-density  ─────────────────────────────────────
fig, ax = plt.subplots(figsize=(8, 8), dpi=300)

h = ax.hist2d(
        x, y,
        bins=120,
        cmap="viridis",
        norm=LogNorm(vmin=1)                    # log colour scale
    )

# identity line
lims = [min(x.min(), y.min()), max(x.max(), y.max())]
ax.plot(lims, lims, 'k--', lw=1)
ax.set_xlim(lims); ax.set_ylim(lims)
ax.set_aspect('equal', adjustable='box')

# labels / title
ax.set_xlabel(r'Expected $[Hb2]$')
ax.set_ylabel(r'Predicted $[Hb2]$')
ax.set_title(r'$S$')

# metrics annotation
ax.text(0.05, 0.95,
        f'RMSE = {rmse:.2e}\nMARE = {mare:.2f} %',
        transform=ax.transAxes,
        ha='left', va='top',
        fontsize=11, color='darkred')

# ── 3 │  colour bar same height as square, plain-number ticks  ────────────────
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="4%", pad=0.05)
cb  = fig.colorbar(h[3], cax=cax)

# plain numbers (1, 2, 5, 10 ...), no “×10⁰”
cb.ax.yaxis.set_major_formatter(FuncFormatter(lambda v, _: f'{v:g}'))
cb.set_label('Pixel counts', rotation=270, labelpad=12)

fig.tight_layout()
plt.show()

# %%
# Small epsilon to avoid division by zero
eps = 1e-8

# Relative error (%)
relative_error = (y_pred - y_true) / (y_true + eps) * 100
absolute_relative_error = np.abs(relative_error)

# Compute metrics
mre = np.mean(relative_error)
mape = np.mean(absolute_relative_error)

# Print
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 3.1862%

# %%
lower, upper = np.percentile(relative_error, [16, 84])
print(f"68% CI of HHb₂ % error: {lower:.2f}% to {upper:.2f}%")
# Out:
# 68% CI of HHb₂ % error: -1.70% to 1.41%

# %%
# Plot training & validation loss values
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
