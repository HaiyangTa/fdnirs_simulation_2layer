# %% [markdown]
# ## FD_abs[hhb2] ANN Fitting

# %%
import pandas as pd
import glob
import os
import numpy as np
import sys
! pip install pmcx
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from FD_msNIRS_2layers import extract_freq as ef

# %% [markdown]
# ### Read Simulation data

# %%
import os
import pickle
import numpy as np

# %%
result_folder1 = '/content/drive/MyDrive/MCX_data/stage1_results/'
#result_folder2 = '/content/drive/MyDrive/MCX_data/result_folder/part2/'
#result_folder3 = '/content/drive/MyDrive/MCX_data/result_folder/part3/'
#result_folder4 = '/content/drive/MyDrive/MCX_data/result_folder/part4/'
#result_folder5 = '/content/drive/MyDrive/MCX_data/MCX_sim_data/1-4/Results/'
result_folders = [result_folder1]

# %%
def row_construct(dictt):
    re = np.zeros((1, 96))
    col = 0
    for k, v in dictt.items():  # four distances
        TPSF_list = v
        uac_i, udc_i, p1 = ef(1e4, TPSF_list, tend=1e-08, devf=1000)  # 8 wavelengths
        combined = []
        for i in range(8):
            combined.extend([uac_i[i], udc_i[i], p1[i]])  # Interleave the values
        re[0, col:col+24] = combined  # Each set contributes 24 values
        col += 24
    return re

# %%
import os
import pickle
import numpy as np
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor

def extract_id_from_path(path):
    filename = os.path.basename(path)
    return int(filename.replace('.pkl', ''))

def load_and_construct(path):
    with open(path, 'rb') as f:
        dictt = pickle.load(f)
    return row_construct(dictt)

def load_and_process_all(result_folders):
    # Collect all file paths
    file_paths = []
    for folder in result_folders:
        for f in os.listdir(folder):
            if f.endswith('.pkl'):
                file_paths.append(os.path.join(folder, f))

    # Sort by numeric filename
    sorted_paths = sorted(file_paths, key=extract_id_from_path)
    sorted_ids = [extract_id_from_path(p) for p in sorted_paths]

    # Load and process in parallel (with progress bar)
    all_rows = []
    with ThreadPoolExecutor() as executor:
        results = list(tqdm(executor.map(load_and_construct, sorted_paths), total=len(sorted_paths), desc="Loading and processing files"))

    result_array = np.vstack(results)
    return result_array, sorted_ids

# %%
final_array, sorted_ids = load_and_process_all(result_folders)
# Out:
# Loading and processing files: 100%|██████████| 2000/2000 [01:03<00:00, 31.43it/s]

# %%
final_array.shape
# Out:
# (2000, 96)
# (2000, 96)

# %%
# Save to CSV
output_csv_path = '/content/drive/MyDrive/MCX_data/stage1.csv'
pd.DataFrame(final_array).to_csv(output_csv_path, index=False, header=False)

# %%
final_array.shape
# Out:
# (2000, 96)
# (2000, 96)

# %% [markdown]
# ### Read the saved CSV

# %%
import pandas as pd
import glob
import numpy as np
import sys
! pip install pmcx
from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/MCX_data'
sys.path.append(folder_path)
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
import pickle
# Out:
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Requirement already satisfied: pmcx in /usr/local/lib/python3.11/dist-packages (0.4.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
csv_path = '/content/drive/MyDrive/MCX_data/stage1.csv'
final_array = np.loadtxt(csv_path, delimiter=',')
print(final_array.shape)
X = final_array
# Out:
# (2000, 96)
# (2000, 96)

# %% [markdown]
# ### GT

# %%
GT_folder = '/content/drive/MyDrive/MCX_data/stage1_csv/'

# %%
csv_files = glob.glob(os.path.join(GT_folder, '*.csv'))
GT_all = pd.concat([pd.read_csv(f) for f in csv_files], ignore_index=True)

# %%
GT_all.head()
# Out:
#         HBO1      HHB1       HBO2       HHB2    d1        a1        a2  \
# 0   8.801696  3.218081  29.967631  30.957545  11.0  3.171905  1.437481
# 1  16.301696  8.218081  44.967631  20.957545  16.0  6.171905  2.987481
# 2  14.426696  4.468081  48.717631  33.457545  20.0  5.421905  4.149981
# 3   6.926696  9.468081  33.717631  23.457545  15.0  2.421905  2.599981
# 4  18.176696  6.968081  41.217631  28.457545  12.0  0.921905  1.824981
#
#          b1        b2   ID
# 0  2.281948  1.083814  251
# 1  1.081948  2.583814  252
# 2  1.981948  1.458814  253
# 3  0.781948  2.958814  254
# 4  1.381948  0.708814  255
#         HBO1      HHB1       HBO2       HHB2    d1        a1        a2  \
# 0   8.801696  3.218081  29.967631  30.957545  11.0  3.171905  1.437481
# 1  16.301696  8.218081  44.967631  20.957545  16.0  6.171905  2.987481
# 2  14.426696  4.468081  48.717631  33.457545  20.0  5.421905  4.149981
# 3   6.926696  9.468081  33.717631  23.457545  15.0  2.421905  2.599981
# 4  18.176696  6.968081  41.217631  28.457545  12.0  0.921905  1.824981
#
#          b1        b2   ID
# 0  2.281948  1.083814  251
# 1  1.081948  2.583814  252
# 2  1.981948  1.458814  253
# 3  0.781948  2.958814  254
# 4  1.381948  0.708814  255

# %%
sorted_ids = [i+1 for i in range(2000)]

# %%
sorted_ids[-1]
# Out:
# 2000
# 2000

# %%
# Ensure ID column is integer
GT_all['ID'] = GT_all['ID'].astype(int)

# Filter and sort GT_all to match the sorted_ids order
GT_filtered = GT_all[GT_all['ID'].isin(sorted_ids)].copy()
GT_filtered = GT_filtered.set_index('ID').loc[sorted_ids].reset_index()

# Extract HHB2 as Y
Y = GT_filtered['HHB2'].values  # numpy array (n_samples,)
Y = Y.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Scale X
scaler_X = StandardScaler()
X = scaler_X.fit_transform(X)

# Scale Y
scaler_y = StandardScaler()
Y = scaler_y.fit_transform(Y)

# %%
X.shape
# Out:
# (2000, 96)
# (2000, 96)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (1800, 96) (200, 96)
# (1800, 96) (200, 96)

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.losses import Huber
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

model = Sequential([
    Input(shape=(96,)),
    Dense(1000, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.1),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(8192*2, activation='relu'),
    Dropout(0.2),

    Dense(8192, activation='relu'),
    Dropout(0.2),

    Dense(4096, activation='relu'),
    Dropout(0.2),

    Dense(2048, activation='relu'),
    Dropout(0.2),

    Dense(1024, activation='relu'),
    Dropout(0.2),

    Dense(512, activation='relu'),
    Dropout(0.1),

    Dense(256, activation='relu'),
    Dropout(0.1),

    Dense(64, activation='relu'),
    Dropout(0.1),

    Dense(32, activation='relu'),
    Dropout(0.0),

    Dense(1)  # Output layer for regression
])


# 1) Create a checkpoint callback that saves the best model:
checkpoint_cb = ModelCheckpoint(
    "best_model.keras",        # filepath to save to
    monitor="val_loss",     # quantity to monitor
    mode="min",             # we want to minimize val_loss
    save_best_only=True,    # only save when val_loss decreases
    save_weights_only=False # set True if you only want weights
)

optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model.compile(optimizer=optimizer, loss="mse")

# 3) Fit with the checkpoint callback
history = model.fit(
    X_train, Y_train,
    epochs=300,
    batch_size=32,
    validation_split=0.1,
    verbose=1,
    callbacks=[checkpoint_cb]
)

# 4) Later on (or in a new script), load the best model:
model = tf.keras.models.load_model("best_model.keras")
# Out:
# Epoch 1/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - loss: 0.9791 - val_loss: 1.0408
# Epoch 2/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 417ms/step - loss: 1.0294 - val_loss: 1.0198
# Epoch 3/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 420ms/step - loss: 0.9902 - val_loss: 1.0191
# Epoch 4/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 437ms/step - loss: 1.0060 - val_loss: 1.0114
# Epoch 5/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9709 - val_loss: 1.0163
# Epoch 6/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 418ms/step - loss: 1.0066 - val_loss: 0.9885
# Epoch 7/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9730 - val_loss: 1.0252
# Epoch 8/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9616 - val_loss: 1.0236
# Epoch 9/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0110 - val_loss: 1.0085
# Epoch 10/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0209 - val_loss: 1.0174
# Epoch 11/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9698 - val_loss: 1.0346
# Epoch 12/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9903 - val_loss: 1.0292
# Epoch 13/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0001 - val_loss: 1.0245
# Epoch 14/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0525 - val_loss: 1.0231
# Epoch 15/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0398 - val_loss: 1.0107
# Epoch 16/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - loss: 1.0056 - val_loss: 0.9685
# Epoch 17/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0154 - val_loss: 0.9792
# Epoch 18/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0094 - val_loss: 0.9974
# Epoch 19/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 416ms/step - loss: 0.9811 - val_loss: 0.9555
# Epoch 20/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9408 - val_loss: 0.9908
# Epoch 21/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9499 - val_loss: 1.0066
# Epoch 22/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0049 - val_loss: 0.9922
# Epoch 23/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 445ms/step - loss: 0.9549 - val_loss: 0.8867
# Epoch 24/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9274 - val_loss: 0.9576
# Epoch 25/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.9107 - val_loss: 0.9388
# Epoch 26/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8614 - val_loss: 1.0287
# Epoch 27/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 436ms/step - loss: 0.8582 - val_loss: 0.8779
# Epoch 28/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 435ms/step - loss: 0.8797 - val_loss: 0.8623
# Epoch 29/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.8312 - val_loss: 0.9378
# Epoch 30/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8129 - val_loss: 0.9058
# Epoch 31/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8228 - val_loss: 0.9325
# Epoch 32/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8518 - val_loss: 0.9182
# Epoch 33/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 428ms/step - loss: 0.8193 - val_loss: 0.8374
# Epoch 34/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 422ms/step - loss: 0.7762 - val_loss: 0.8283
# Epoch 35/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7786 - val_loss: 0.8515
# Epoch 36/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 434ms/step - loss: 0.7951 - val_loss: 0.8079
# Epoch 37/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7844 - val_loss: 0.8349
# Epoch 38/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7651 - val_loss: 0.8424
# Epoch 39/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7665 - val_loss: 0.8956
# Epoch 40/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7268 - val_loss: 0.8144
# Epoch 41/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7586 - val_loss: 0.8480
# Epoch 42/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6991 - val_loss: 0.8608
# Epoch 43/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7946 - val_loss: 0.8770
# Epoch 44/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7906 - val_loss: 0.8830
# Epoch 45/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7585 - val_loss: 0.8152
# Epoch 46/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7428 - val_loss: 0.8331
# Epoch 47/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7466 - val_loss: 0.8127
# Epoch 48/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7184 - val_loss: 0.8535
# Epoch 49/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7560 - val_loss: 0.8123
# Epoch 50/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7412 - val_loss: 0.8471
# Epoch 51/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 423ms/step - loss: 0.7485 - val_loss: 0.7578
# Epoch 52/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 416ms/step - loss: 0.7189 - val_loss: 0.7072
# Epoch 53/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7237 - val_loss: 0.8355
# Epoch 54/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7195 - val_loss: 0.8243
# Epoch 55/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.6871 - val_loss: 0.7274
# Epoch 56/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7024 - val_loss: 0.7621
# Epoch 57/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6905 - val_loss: 0.8371
# Epoch 58/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6827 - val_loss: 0.7650
# Epoch 59/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6998 - val_loss: 0.8118
# Epoch 60/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6732 - val_loss: 0.7960
# Epoch 61/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 414ms/step - loss: 0.7147 - val_loss: 0.6971
# Epoch 62/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 442ms/step - loss: 0.6820 - val_loss: 0.6794
# Epoch 63/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.6653 - val_loss: 0.7173
# Epoch 64/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.6480 - val_loss: 0.7307
# Epoch 65/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - loss: 0.6465 - val_loss: 0.6442
# Epoch 66/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.6872 - val_loss: 0.7036
# Epoch 67/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.6195 - val_loss: 0.6977
# Epoch 68/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.7412 - val_loss: 0.7237
# Epoch 69/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6200 - val_loss: 0.6511
# Epoch 70/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6232 - val_loss: 0.6610
# Epoch 71/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6068 - val_loss: 0.7206
# Epoch 72/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6215 - val_loss: 0.7188
# Epoch 73/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6150 - val_loss: 0.7086
# Epoch 74/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6043 - val_loss: 0.6772
# Epoch 75/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 419ms/step - loss: 0.6210 - val_loss: 0.6422
# Epoch 76/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 425ms/step - loss: 0.5793 - val_loss: 0.5800
# Epoch 77/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5607 - val_loss: 0.6360
# Epoch 78/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.5600 - val_loss: 0.5938
# Epoch 79/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5688 - val_loss: 0.6715
# Epoch 80/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5439 - val_loss: 0.6448
# Epoch 81/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5830 - val_loss: 0.6180
# Epoch 82/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 446ms/step - loss: 0.5459 - val_loss: 0.5731
# Epoch 83/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5412 - val_loss: 0.6807
# Epoch 84/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5603 - val_loss: 0.6119
# Epoch 85/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5917 - val_loss: 0.5845
# Epoch 86/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5703 - val_loss: 0.7606
# Epoch 87/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.6163 - val_loss: 0.7102
# Epoch 88/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5809 - val_loss: 0.6390
# Epoch 89/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5046 - val_loss: 0.6987
# Epoch 90/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4973 - val_loss: 0.6734
# Epoch 91/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5119 - val_loss: 0.6646
# Epoch 92/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5118 - val_loss: 0.5967
# Epoch 93/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5346 - val_loss: 0.6201
# Epoch 94/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5015 - val_loss: 0.6411
# Epoch 95/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 423ms/step - loss: 0.5346 - val_loss: 0.5322
# Epoch 96/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5243 - val_loss: 0.6244
# Epoch 97/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4847 - val_loss: 0.5615
# Epoch 98/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5205 - val_loss: 0.5450
# Epoch 99/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5194 - val_loss: 0.5746
# Epoch 100/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4765 - val_loss: 0.6258
# Epoch 101/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4768 - val_loss: 0.7458
# Epoch 102/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5088 - val_loss: 0.6616
# Epoch 103/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5035 - val_loss: 0.5887
# Epoch 104/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4711 - val_loss: 0.5971
# Epoch 105/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4547 - val_loss: 0.7118
# Epoch 106/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4882 - val_loss: 0.5586
# Epoch 107/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4734 - val_loss: 0.7043
# Epoch 108/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.5343 - val_loss: 0.5842
# Epoch 109/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4425 - val_loss: 0.5841
# Epoch 110/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 417ms/step - loss: 0.4321 - val_loss: 0.5263
# Epoch 111/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4442 - val_loss: 0.5515
# Epoch 112/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4151 - val_loss: 0.5435
# Epoch 113/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4189 - val_loss: 0.5286
# Epoch 114/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4359 - val_loss: 0.6556
# Epoch 115/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3875 - val_loss: 0.5386
# Epoch 116/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4117 - val_loss: 0.6493
# Epoch 117/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4402 - val_loss: 0.5908
# Epoch 118/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 415ms/step - loss: 0.4258 - val_loss: 0.5028
# Epoch 119/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4011 - val_loss: 0.6626
# Epoch 120/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3983 - val_loss: 0.5570
# Epoch 121/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4017 - val_loss: 0.6118
# Epoch 122/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3818 - val_loss: 0.5628
# Epoch 123/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4048 - val_loss: 0.5915
# Epoch 124/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3856 - val_loss: 0.5654
# Epoch 125/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3692 - val_loss: 0.5782
# Epoch 126/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3917 - val_loss: 0.5749
# Epoch 127/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4162 - val_loss: 0.7861
# Epoch 128/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3921 - val_loss: 0.6053
# Epoch 129/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3872 - val_loss: 0.6064
# Epoch 130/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4293 - val_loss: 0.5592
# Epoch 131/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3994 - val_loss: 0.5446
# Epoch 132/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4234 - val_loss: 0.5368
# Epoch 133/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3952 - val_loss: 0.5984
# Epoch 134/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4176 - val_loss: 0.5646
# Epoch 135/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3531 - val_loss: 0.5579
# Epoch 136/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 421ms/step - loss: 0.3417 - val_loss: 0.4897
# Epoch 137/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3420 - val_loss: 0.5357
# Epoch 138/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3157 - val_loss: 0.6575
# Epoch 139/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3772 - val_loss: 0.5558
# Epoch 140/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3325 - val_loss: 0.5390
# Epoch 141/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3291 - val_loss: 0.6340
# Epoch 142/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3549 - val_loss: 0.5193
# Epoch 143/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3705 - val_loss: 0.5869
# Epoch 144/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3515 - val_loss: 0.5076
# Epoch 145/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3105 - val_loss: 0.5837
# Epoch 146/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3392 - val_loss: 0.5457
# Epoch 147/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3017 - val_loss: 0.5015
# Epoch 148/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3196 - val_loss: 0.6757
# Epoch 149/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3735 - val_loss: 0.5456
# Epoch 150/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3361 - val_loss: 0.5066
# Epoch 151/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3361 - val_loss: 0.5269
# Epoch 152/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2851 - val_loss: 0.5526
# Epoch 153/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3467 - val_loss: 0.5488
# Epoch 154/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3070 - val_loss: 0.5310
# Epoch 155/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3272 - val_loss: 0.5662
# Epoch 156/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3094 - val_loss: 0.5319
# Epoch 157/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2909 - val_loss: 0.5511
# Epoch 158/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3001 - val_loss: 0.5275
# Epoch 159/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4061 - val_loss: 0.5016
# Epoch 160/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3342 - val_loss: 0.7022
# Epoch 161/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3676 - val_loss: 0.5054
# Epoch 162/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3181 - val_loss: 0.5090
# Epoch 163/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3058 - val_loss: 0.6062
# Epoch 164/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3553 - val_loss: 0.6082
# Epoch 165/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2968 - val_loss: 0.6156
# Epoch 166/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2905 - val_loss: 0.5058
# Epoch 167/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2495 - val_loss: 0.5715
# Epoch 168/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2621 - val_loss: 0.5450
# Epoch 169/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2958 - val_loss: 0.5443
# Epoch 170/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2776 - val_loss: 0.5629
# Epoch 171/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2881 - val_loss: 0.5235
# Epoch 172/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2764 - val_loss: 0.6707
# Epoch 173/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2867 - val_loss: 0.6232
# Epoch 174/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2897 - val_loss: 0.5681
# Epoch 175/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3840 - val_loss: 0.6196
# Epoch 176/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3213 - val_loss: 0.5490
# Epoch 177/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3377 - val_loss: 0.5775
# Epoch 178/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2868 - val_loss: 0.4975
# Epoch 179/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2690 - val_loss: 0.7088
# Epoch 180/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2661 - val_loss: 0.5469
# Epoch 181/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2499 - val_loss: 0.5086
# Epoch 182/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2396 - val_loss: 0.5281
# Epoch 183/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2203 - val_loss: 0.5439
# Epoch 184/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2308 - val_loss: 0.4918
# Epoch 185/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2340 - val_loss: 0.5162
# Epoch 186/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3104 - val_loss: 0.5327
# Epoch 187/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2364 - val_loss: 0.5767
# Epoch 188/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2286 - val_loss: 0.6784
# Epoch 189/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2680 - val_loss: 0.5602
# Epoch 190/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2354 - val_loss: 0.5262
# Epoch 191/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2538 - val_loss: 0.6446
# Epoch 192/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3423 - val_loss: 0.5090
# Epoch 193/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2738 - val_loss: 0.5837
# Epoch 194/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2322 - val_loss: 0.5934
# Epoch 195/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2555 - val_loss: 0.5961
# Epoch 196/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2001 - val_loss: 0.6655
# Epoch 197/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3091 - val_loss: 0.5685
# Epoch 198/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2510 - val_loss: 0.5572
# Epoch 199/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2232 - val_loss: 0.6394
# Epoch 200/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2405 - val_loss: 0.5464
# Epoch 201/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2277 - val_loss: 0.5854
# Epoch 202/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1968 - val_loss: 0.5595
# Epoch 203/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2091 - val_loss: 0.5665
# Epoch 204/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2022 - val_loss: 0.5876
# Epoch 205/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2113 - val_loss: 0.5661
# Epoch 206/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2408 - val_loss: 0.6633
# Epoch 207/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2800 - val_loss: 0.7409
# Epoch 208/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3135 - val_loss: 0.6446
# Epoch 209/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2703 - val_loss: 0.5741
# Epoch 210/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2381 - val_loss: 0.6369
# Epoch 211/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2550 - val_loss: 0.6771
# Epoch 212/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1945 - val_loss: 0.5519
# Epoch 213/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1763 - val_loss: 0.5872
# Epoch 214/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1822 - val_loss: 0.6202
# Epoch 215/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2004 - val_loss: 0.6194
# Epoch 216/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1779 - val_loss: 0.6011
# Epoch 217/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1965 - val_loss: 0.6011
# Epoch 218/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1862 - val_loss: 0.5869
# Epoch 219/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1724 - val_loss: 0.5407
# Epoch 220/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2001 - val_loss: 0.6071
# Epoch 221/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3105 - val_loss: 0.5788
# Epoch 222/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2716 - val_loss: 0.6022
# Epoch 223/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2048 - val_loss: 0.6129
# Epoch 224/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1881 - val_loss: 0.6377
# Epoch 225/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1653 - val_loss: 0.5559
# Epoch 226/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2120 - val_loss: 0.6208
# Epoch 227/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2093 - val_loss: 0.6223
# Epoch 228/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1889 - val_loss: 0.6050
# Epoch 229/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1754 - val_loss: 0.6054
# Epoch 230/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2418 - val_loss: 0.6489
# Epoch 231/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2764 - val_loss: 0.7471
# Epoch 232/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.4284 - val_loss: 0.6404
# Epoch 233/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2221 - val_loss: 0.6455
# Epoch 234/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2179 - val_loss: 0.6467
# Epoch 235/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1647 - val_loss: 0.5902
# Epoch 236/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1638 - val_loss: 0.6724
# Epoch 237/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1523 - val_loss: 0.6186
# Epoch 238/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1720 - val_loss: 0.6881
# Epoch 239/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1596 - val_loss: 0.6256
# Epoch 240/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1867 - val_loss: 0.5821
# Epoch 241/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1614 - val_loss: 0.6466
# Epoch 242/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2302 - val_loss: 0.7606
# Epoch 243/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1621 - val_loss: 0.5847
# Epoch 244/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1384 - val_loss: 0.6085
# Epoch 245/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1565 - val_loss: 0.6661
# Epoch 246/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1514 - val_loss: 0.6408
# Epoch 247/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1474 - val_loss: 0.6848
# Epoch 248/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1436 - val_loss: 0.6459
# Epoch 249/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2689 - val_loss: 0.6974
# Epoch 250/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1611 - val_loss: 0.7745
# Epoch 251/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2461 - val_loss: 0.6223
# Epoch 252/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3097 - val_loss: 0.6712
# Epoch 253/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3295 - val_loss: 0.6691
# Epoch 254/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1840 - val_loss: 0.6749
# Epoch 255/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1802 - val_loss: 0.7119
# Epoch 256/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2069 - val_loss: 0.6627
# Epoch 257/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1900 - val_loss: 0.6182
# Epoch 258/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1204 - val_loss: 0.6326
# Epoch 259/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1263 - val_loss: 0.6041
# Epoch 260/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1681 - val_loss: 0.6467
# Epoch 261/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1289 - val_loss: 0.7473
# Epoch 262/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1949 - val_loss: 0.6740
# Epoch 263/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1700 - val_loss: 0.6523
# Epoch 264/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1704 - val_loss: 0.6922
# Epoch 265/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1463 - val_loss: 0.8185
# Epoch 266/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1540 - val_loss: 0.6141
# Epoch 267/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1804 - val_loss: 0.7885
# Epoch 268/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2547 - val_loss: 0.7522
# Epoch 269/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1604 - val_loss: 0.6594
# Epoch 270/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1503 - val_loss: 0.6572
# Epoch 271/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2120 - val_loss: 0.6242
# Epoch 272/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1876 - val_loss: 0.6794
# Epoch 273/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1688 - val_loss: 0.6211
# Epoch 274/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1269 - val_loss: 0.6652
# Epoch 275/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1133 - val_loss: 0.6659
# Epoch 276/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1102 - val_loss: 0.6661
# Epoch 277/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1267 - val_loss: 0.7101
# Epoch 278/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1295 - val_loss: 0.7260
# Epoch 279/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1383 - val_loss: 0.6668
# Epoch 280/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1418 - val_loss: 0.8611
# Epoch 281/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2219 - val_loss: 0.7119
# Epoch 282/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1514 - val_loss: 0.7003
# Epoch 283/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2589 - val_loss: 0.6989
# Epoch 284/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1623 - val_loss: 0.7624
# Epoch 285/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1865 - val_loss: 0.8071
# Epoch 286/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2729 - val_loss: 0.7042
# Epoch 287/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2245 - val_loss: 0.6745
# Epoch 288/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1323 - val_loss: 0.7239
# Epoch 289/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1419 - val_loss: 0.5873
# Epoch 290/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1012 - val_loss: 0.7621
# Epoch 291/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1637 - val_loss: 0.7056
# Epoch 292/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1941 - val_loss: 0.5984
# Epoch 293/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1145 - val_loss: 0.6549
# Epoch 294/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0891 - val_loss: 0.6702
# Epoch 295/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0873 - val_loss: 0.6690
# Epoch 296/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0837 - val_loss: 0.6640
# Epoch 297/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1434 - val_loss: 0.7598
# Epoch 298/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1202 - val_loss: 0.6938
# Epoch 299/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0838 - val_loss: 0.6760
# Epoch 300/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1265 - val_loss: 0.7281
# Epoch 1/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 41s 614ms/step - loss: 1.0026 - val_loss: 1.0207
# Epoch 2/300
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0485 - val_loss: 1.0259
# Epoch 3/300

# %%
# Predict and evaluate
y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, y_pred)
print(f"Test MSE: {mse:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step
# Test MSE: 0.5377

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │        97,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1000)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │     4,100,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8192)           │    33,562,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 16384)          │   134,234,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8192)           │   134,225,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4096)           │    33,558,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2048)           │     8,390,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,103,169,341 (4.11 GB)
#  Trainable params: 367,723,113 (1.37 GB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 735,446,228 (2.74 GB)

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Randomly select 100 indices
import matplotlib.pyplot as plt
indices = np.random.choice(len(Y_test), size=100, replace=False)
indices = np.sort(indices)

y_pred_rescaled = scaler_y.inverse_transform(y_pred.reshape(-1, 1)).flatten()
y_test_rescaled = scaler_y.inverse_transform(Y_test.reshape(-1, 1)).flatten()
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
print(f"Test MSE: {mse:.4f}")


# Extract corresponding values
y_test_sampled = y_test_rescaled[indices]
y_pred_sampled = y_pred_rescaled[indices]

# Plot with circular markers
plt.figure(figsize=(16, 8))
plt.plot(y_test_sampled, 'r-o', label='Ground Truth (HHB2)', linewidth=2, markersize=5)
plt.plot(y_pred_sampled, 'b--o', label='Predicted (HHB2)', linewidth=2, markersize=5)
plt.xlabel('Random Sample Index')
plt.ylabel('HHB2')
plt.title('Randomly Sampled Predictions vs Ground Truth')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE: 17.9238

# %%
# Inverse-transform predictions and ground truth
y_pred_orig = scaler_y.inverse_transform(y_pred)       # shape (n, 1)
y_test_orig = scaler_y.inverse_transform(Y_test)     # shape (n, 1)

# Compute residuals in original scale
residuals = y_pred_orig - y_test_orig

mse_rescaled = mean_squared_error(y_test_orig, y_pred_orig)
print(f"Test MSE (original scale): {mse_rescaled:.4f}")

# Plot residuals
plt.figure(figsize=(16, 8))
plt.scatter(range(len(residuals)), residuals, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.title("Residuals (Predicted - Ground Truth)")
plt.ylabel("Residual")
plt.ylim(-10, 10)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Test MSE (original scale): 17.9238

# %%
# Inverse-transform predictions and ground truth
y_pred_orig = scaler_y.inverse_transform(y_pred)       # shape (n, 1)
y_test_orig = scaler_y.inverse_transform(Y_test)     # shape (n, 1)

# Compute relative error (percentage)
relative_error = ((y_pred_orig - y_test_orig) / y_test_orig) * 100

# Plot relative error
plt.figure(figsize=(16, 8))
plt.scatter(range(len(relative_error)), relative_error, s=10, alpha=0.5)
plt.axhline(0, color='r', linestyle='--')
plt.ylabel("Relative Error (%)")
plt.ylim(-100, 100)
plt.xlabel("Sample Index")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Prepare DataFrame for seaborn
df_plot = pd.DataFrame({
    'Relative Error (%)': relative_error.flatten()
})

plt.figure(figsize=(10, 10))
sns.violinplot(data=df_plot, y='Relative Error (%)', inner=None, linewidth=1.2)
sns.stripplot(data=df_plot, y='Relative Error (%)', color='black', alpha=0.4, jitter=0.2, size=3)

plt.axhline(0, color='r', linestyle='--', linewidth=1)
plt.ylim(-100, 100)
plt.title('Distribution of Relative Error (%)')
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %%
relative_error = relative_error.squeeze()

plt.figure(figsize=(10, 6))
sns.boxplot(y=relative_error, color='lightgray', width=0.3)
sns.stripplot(y=relative_error, color='black', alpha=0.03, jitter=0.4, size=1.5)

plt.axhline(0, color='red', linestyle='--', linewidth=1)
plt.title('Relative Error Distribution (%)')
plt.ylabel('Relative Error (%)')
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(10, 6))
sns.violinplot(y=relative_error, inner=None, color='skyblue', cut=0)
sns.stripplot(y=relative_error, color='black', alpha=0.05, jitter=0.3, size=2)

plt.axhline(0, color='red', linestyle='--', linewidth=1.2)
plt.title('Distribution of Relative Error (%)')
plt.ylabel('Relative Error (%)')
plt.grid()
plt.xticks([])
plt.ylim(-100, 100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(relative_error, kde=True, bins=1000, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Histogram + KDE of Relative Error (%)")
plt.xlabel("Relative Error (%)")
plt.ylabel("Frequency")
plt.grid()
plt.xlim(-100, 100)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 6))

# Subplot 1: Ground truth
plt.subplot(1, 2, 1)
sns.histplot(np.asarray(y_test_orig).ravel(), kde=True, bins=100, color='steelblue', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Ground Truth (Y_test) Distribution")
plt.xlabel("Y_test")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

# Subplot 2: Prediction
plt.subplot(1, 2, 2)
sns.histplot( np.asarray(y_pred_orig).ravel(), kde=True, bins=100, color='darkorange', alpha=0.7)
plt.axvline(0, color='red', linestyle='--')
plt.title("Prediction (Y_pred) Distribution")
plt.xlabel("Y_pred")
plt.ylabel("Frequency")
plt.grid(True)
plt.xlim(-100, 100)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# Ensure y_true and y_pred are 1D numpy arrays
y_true = np.asarray(y_test_orig).ravel()
y_pred =np.asarray(y_pred_orig).ravel()

# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_true, y_pred))

# Plot
plt.figure(figsize=(10, 10))
plt.hist2d(y_true, y_pred, bins=100, cmap='Blues', cmin=1)

# Plot identity line
plt.plot([min(y_true), max(y_true)],
         [min(y_true), max(y_true)],
         'k--', lw=1)

# Labels and title
plt.xlabel('Expected $\Delta[HHB2]$')
plt.ylabel('Predicted $\Delta[HHB2]$')
plt.title(r'$S$')

# Annotate RMSE
plt.text(0.05, 0.95, f'RMSE: {rmse:.2e}', color='darkred',
         fontsize=14, transform=plt.gca().transAxes, va='top')

plt.colorbar(label='Density')
plt.tight_layout()
plt.show()

# %%
# Small epsilon to avoid division by zero
eps = 1e-8

# Relative error (%)
relative_error = (y_pred - y_true) / (y_true + eps) * 100
absolute_relative_error = np.abs(relative_error)

# Compute metrics
mre = np.mean(relative_error)
mape = np.mean(absolute_relative_error)

# Print
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 15.0286%

# %%
lower, upper = np.percentile(relative_error, [16, 84])
print(f"68% CI of HHb₂ % error: {lower:.2f}% to {upper:.2f}%")
# Out:
# 68% CI of HHb₂ % error: -12.54% to 24.52%
